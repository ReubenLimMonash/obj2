# %% [markdown]
# Date: 12/06/2024 <br>
# Desc: To plot figures for results section in Journal 2

# %% [markdown]
# ## Plots for Reliability Class Classification (Section 3.1)

# %% [markdown]
# ### Plot Accuracy Only (Both Reliability and Failure Mode Classification)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Reliability_Prediction_Results_Obj2.csv"

results_df = pd.read_csv(RESULTS_FILE)

# For x-ticks
ind = np.arange(len(results_df), dtype=float)  
width = 0.2
x = np.insert(ind, 2, 1.1) 
x = np.insert(x, 6, 4.1)
x = np.insert(x, 10, 7.1)

# PLOT RELIABILITY CLASSIFICATION ACCURACY
plt.figure(figsize=(10,3))
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_class_accuracy"].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_reliability_class_accuracy"].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_reliability_class_accuracy"].values, width, edgecolor='black', color = '0') 
plt.ylabel('Classification Accuracy') 
plt.ylim(0.95, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

# PLOT FAILURE MODE CLASSIFICATION ACCURACY
plt.figure(figsize=(10,3))
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_failure_mode_accuracy"].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_failure_mode_accuracy"].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_failure_mode_accuracy"].values, width, edgecolor='black', color = '0') 
plt.ylabel('Classification Accuracy') 
plt.ylim(0.95, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend((bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3)

# %% [markdown]
# ### Plot Accuracy, Specificity, and Sensitivity

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Reliability_Prediction_Results_Obj2.csv"
METRIC = "failure_mode" # reliability_class / failure_mode

results_df = pd.read_csv(RESULTS_FILE)

# For x-ticks
ind = np.arange(len(results_df), dtype=float)  
width = 0.2
x = np.insert(ind, 2, 1.1) 
x = np.insert(x, 6, 4.1)
x = np.insert(x, 10, 7.1)

# PLOT RELIABILITY CLASSIFICATION ACCURACY
plt.figure(figsize=(7,3))
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_{}_accuracy".format(METRIC)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_{}_accuracy".format(METRIC)].values, width, edgecolor='black', color = '0.6') 
plt.ylabel('Accuracy (%)') 
plt.ylim(0.95, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn), ('BN', 'NN'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_{}_specificity".format(METRIC)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_{}_specificity".format(METRIC)].values, width, edgecolor='black', color = '0.6') 
plt.ylabel('Specificity (%)') 
plt.ylim(0.95, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn), ('BN', 'NN'), bbox_to_anchor=(0.6, 1.05, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

plt.subplot(1,2,2)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_{}_sensitivity".format(METRIC)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_{}_sensitivity".format(METRIC)].values, width, edgecolor='black', color = '0.6') 
plt.ylabel('Sensitivity (%)') 
plt.ylim(0.90, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
# plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3)

# %% [markdown]
# ## Plot Results for Reliability Requirement Classification

# %% [markdown]
# ### For Single Required Reliability Level

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Reliability_Prediction_Results_Obj2_temp.csv"
RELIABILITY_TH = 90 # Either 90 or 99 or 999

results_df = pd.read_csv(RESULTS_FILE)

# For x-ticks
ind = np.arange(len(results_df), dtype=float)  
width = 0.2
x = np.insert(ind, 2, 1.1) 
x = np.insert(x, 6, 4.1)
x = np.insert(x, 10, 7.1)

# PLOT RELIABILITY REQUIREMENT CLASSIFICATION ACCURACY 
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_accuracy_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_reliability_state_accuracy_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_reliability_state_accuracy_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Accuracy') 
plt.ylim(0.9, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Accuracy)'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
# Duplicating for subplot to display in consistent size
plt.subplot(1,2,2)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_specificity_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Accuracy') 
plt.ylim(0.9, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Accuracy)'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

# PLOT RELIABILITY REQUIREMENT CLASSIFICATION SPECIFICITY 
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_specificity_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Specificity') 
plt.ylim(0.95, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Specificity)'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
# Duplicating for subplot to display in consistent size
plt.subplot(1,2,2)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_specificity_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Specificity') 
plt.ylim(0.95, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Specificity)'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

# PLOT RELIABILITY REQUIREMENT CLASSIFICATION SENSITIVITY
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_recall_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Sensitivity') 
plt.ylim(0.79, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Sensitivity)'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
# Duplicating for subplot to display in consistent size
plt.subplot(1,2,2)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width, results_df["nn_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_recall_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Sensitivity') 
plt.ylim(0.79, 1.0)
plt.xticks(x+width,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Sensitivity)'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3)

# %% [markdown]
# ### In sub-plots for Each Required Reliability Level

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Reliability_Prediction_Results_Obj2.csv"
RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Reliability_Prediction_Results_Obj2_temp.csv"

results_df = pd.read_csv(RESULTS_FILE)

# For x-ticks
ind = np.arange(len(results_df), dtype=float)  
width = 0.25
x = np.insert(ind, 2, 1.1) 
x = np.insert(x, 6, 4.1)
x = np.insert(x, 10, 7.1)

# PLOT RELIABILITY REQUIREMENT CLASSIFICATION ACCURACY
plt.figure(figsize=(15,3))
RELIABILITY_TH = 99 # Either 99 or 999
plt.subplot(1,2,1)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_accuracy_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width * 1.1, results_df["nn_reliability_state_accuracy_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_reliability_state_accuracy_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Accuracy') 
plt.ylim(0.9, 1.0)
plt.xticks(x+width*1.1,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Accuracy)'), bbox_to_anchor=(0.6, 1.05, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

RELIABILITY_TH = 999 # Either 99 or 999
plt.subplot(1,2,2)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_accuracy_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width * 1.1, results_df["nn_reliability_state_accuracy_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_reliability_state_accuracy_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Accuracy') 
plt.ylim(0.9, 1.0)
plt.xticks(x+width * 1.1,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
# plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (F1)'), loc='lower left') 

# PLOT RELIABILITY REQUIREMENT CLASSIFICATION SPECIFICITY 
plt.figure(figsize=(15,3))
RELIABILITY_TH = 99 # Either 99 or 999
plt.subplot(1,2,1)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width * 1.1, results_df["nn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_specificity_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Specificity') 
plt.ylim(0.95, 1.0)
plt.xticks(x+width * 1.1,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Specificity)'), bbox_to_anchor=(0.6, 1.05, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

RELIABILITY_TH = 999 # Either 99 or 999
plt.subplot(1,2,2)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width * 1.1, results_df["nn_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_specificity_reliability_state_specificity_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Specificity') 
plt.ylim(0.95, 1.0)
plt.xticks(x+width * 1.1,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
# plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Specificity)'), loc='lower right') 

# PLOT RELIABILITY REQUIREMENT CLASSIFICATION SENSITIVITY
plt.figure(figsize=(15,3))
RELIABILITY_TH = 99 # Either 99 or 999
plt.subplot(1,2,1)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width * 1.1, results_df["nn_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_recall_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Sensitivity') 
plt.ylim(0.79, 1.0)
plt.xticks(x+width * 1.1,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Sensitivity)'), bbox_to_anchor=(0.6, 1.05, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

RELIABILITY_TH = 999 # Either 99 or 999
plt.subplot(1,2,2)
plt.rcParams.update({'font.size': 12})
bar_bn = plt.bar(ind, results_df["bn_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width * 1.1, results_df["nn_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2, results_df["calibnn_recall_reliability_state_recall_{}".format(RELIABILITY_TH)].values, width, edgecolor='black', color = '0') 
plt.ylabel('Sensitivity') 
plt.ylim(0.79, 1.0)
plt.xticks(x+width * 1.1,['UL', 'DL', '\nDJI Spark', 'VID', 'UL', 'DL', '\nDJI Mavic Air', 'VID', 'UL', 'DL', '\nParrot AR 2', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
# plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', 'Cal. NN (Sensitivity)'), loc='center right')

# %% [markdown]
# ### Plot trend of averages over all links for different UAV models

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Reliability_Prediction_Results_Obj2_temp.csv"
METRIC = "accuracy" # accuracy / sensitivity / specificity

results_df = pd.read_csv(RESULTS_FILE)

if METRIC == "accuracy":
    bn_column = "bn_reliability_state_accuracy_{}"
    nn_column = "nn_reliability_state_accuracy_{}"
    cal_nn_column = "calibnn_reliability_state_accuracy_{}"
    metric = "Accuracy"
    ylim_bottom = 0.96
    ylim_top = 1.0
elif METRIC == "sensitivity":
    bn_column = "bn_reliability_state_recall_{}"
    nn_column = "nn_reliability_state_recall_{}"
    cal_nn_column = "calibnn_recall_reliability_state_recall_{}"
    metric = "Sensitivity"
    ylim_bottom = 0.86
    ylim_top = 1.005
elif METRIC == "specificity":
    bn_column = "bn_reliability_state_specificity_{}"
    nn_column = "nn_reliability_state_specificity_{}"
    cal_nn_column = "calibnn_specificity_reliability_state_specificity_{}"
    metric = "Specificity"
    ylim_bottom = 0.98
    ylim_top = 1.0005

"""Plot trend for DJI Spark"""
dji_spark_df = results_df[0:3]
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
plt.plot(["90.0", "99.0", "99.9"], [dji_spark_df[bn_column.format(90)].mean(), dji_spark_df[bn_column.format(99)].mean(), dji_spark_df[bn_column.format(999)].mean()], '-o', color='b', label='BN')
plt.plot(["90.0", "99.0", "99.9"], [dji_spark_df[nn_column.format(90)].mean(), dji_spark_df[nn_column.format(99)].mean(), dji_spark_df[nn_column.format(999)].mean()], '-s', color='g', label='NN')
plt.plot(["90.0", "99.0", "99.9"], [dji_spark_df[cal_nn_column.format(90)].mean(), dji_spark_df[cal_nn_column.format(99)].mean(), dji_spark_df[cal_nn_column.format(999)].mean()], '-x', color='r', label='Cal. NN')
plt.legend( bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
plt.ylabel(metric)
plt.xlabel("Required Reliability Level (%)")
plt.ylim(bottom=ylim_bottom,top=ylim_top)
# Repeat for subplot
plt.subplot(1,2,2)
plt.plot(["90.0", "99.0", "99.9"], [dji_spark_df[bn_column.format(90)].mean(), dji_spark_df[bn_column.format(99)].mean(), dji_spark_df[bn_column.format(999)].mean()], '-o', color='b', label='BN')
plt.plot(["90.0", "99.0", "99.9"], [dji_spark_df[nn_column.format(90)].mean(), dji_spark_df[nn_column.format(99)].mean(), dji_spark_df[nn_column.format(999)].mean()], '-s', color='g', label='NN')
plt.plot(["90.0", "99.0", "99.9"], [dji_spark_df[cal_nn_column.format(90)].mean(), dji_spark_df[cal_nn_column.format(99)].mean(), dji_spark_df[cal_nn_column.format(999)].mean()], '-x', color='r', label='Cal. NN')
plt.legend( bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
plt.ylabel(metric)
plt.xlabel("Required Reliability Level (%)")
plt.ylim(bottom=ylim_bottom,top=ylim_top)

"""Plot trend for DJI Mavic Air"""
dji_mavicair_df = results_df[4:6]
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
plt.plot(["90.0", "99.0", "99.9"], [dji_mavicair_df[bn_column.format(90)].mean(), dji_mavicair_df[bn_column.format(99)].mean(), dji_mavicair_df[bn_column.format(999)].mean()], '-o', color='b', label='BN')
plt.plot(["90.0", "99.0", "99.9"], [dji_mavicair_df[nn_column.format(90)].mean(), dji_mavicair_df[nn_column.format(99)].mean(), dji_mavicair_df[nn_column.format(999)].mean()], '-s', color='g', label='NN')
plt.plot(["90.0", "99.0", "99.9"], [dji_mavicair_df[cal_nn_column.format(90)].mean(), dji_mavicair_df[cal_nn_column.format(99)].mean(), dji_mavicair_df[cal_nn_column.format(999)].mean()], '-x', color='r', label='Cal. NN')
plt.legend( bbox_to_anchor=(0.6, 1.05, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
plt.ylabel(metric)
plt.xlabel("Required Reliability Level (%)")
plt.ylim(bottom=ylim_bottom,top=ylim_top)
"""Plot trend for Parrot AR 2"""
parrot_ar2_df = results_df[7:9]
plt.subplot(1,2,2)
plt.plot(["90.0", "99.0", "99.9"], [results_df[bn_column.format(90)].mean(), results_df[bn_column.format(99)].mean(), results_df[bn_column.format(999)].mean()], '-o', color='b', label='BN')
plt.plot(["90.0", "99.0", "99.9"], [results_df[nn_column.format(90)].mean(), results_df[nn_column.format(99)].mean(), results_df[nn_column.format(999)].mean()], '-s', color='g', label='NN')
plt.plot(["90.0", "99.0", "99.9"], [results_df[cal_nn_column.format(90)].mean(), results_df[cal_nn_column.format(99)].mean(), results_df[cal_nn_column.format(999)].mean()], '-x', color='r', label='Cal. NN')
plt.ylabel(metric)
plt.xlabel("Required Reliability Level (%)")
plt.ylim(bottom=ylim_bottom,top=ylim_top)
# Out:
# (0.96, 1.0)

# %% [markdown]
# ### Sub-plots, Bar Chart with Mean Trend

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import numpy as np

# RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Reliability_Prediction_Results_Obj2.csv"
RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Reliability_Prediction_Results_Obj2_final_model.csv"
METRIC = "recall" # accuracy / recall / specificity
UAV = "parrot_ar2" # dji_spark / dji_mavicair / parrot_ar2
results_df = pd.read_csv(RESULTS_FILE)

if METRIC == "accuracy":
    metric = "Accuracy"
    cal_nn_column = "calibnn_reliability_state"
    ylim_bottom = 0.95*100
    ylim_top = 1.0005*100
elif METRIC == "recall":
    metric = "Sensitivity"
    cal_nn_column = "calibnn_recall_reliability_state"
    ylim_bottom = 0.78*100
    ylim_top = 1.005*100
elif METRIC == "specificity":
    metric = "Specificity"
    cal_nn_column = "calibnn_specificity_reliability_state"
    ylim_bottom = 0.90*100
    ylim_top = 1.005*100

if UAV == "dji_spark":
    results_df = results_df[0:3]
elif UAV == "dji_mavicair":
    results_df = results_df[3:6]
elif UAV == "parrot_ar2":
    results_df = results_df[6:9]

plt.figure(figsize=(16,4))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 2]) 
plt.rcParams.update({'font.size': 14})

result_bn = [results_df["bn_reliability_state_{}_90".format(METRIC)], results_df["bn_reliability_state_{}_99".format(METRIC)], results_df["bn_reliability_state_{}_999".format(METRIC)]]
result_nn = [results_df["nn_reliability_state_{}_90".format(METRIC)], results_df["nn_reliability_state_{}_99".format(METRIC)], results_df["nn_reliability_state_{}_999".format(METRIC)]]
result_cnn = [results_df["{}_{}_90".format(cal_nn_column, METRIC)], results_df["{}_{}_99".format(cal_nn_column, METRIC)], results_df["{}_{}_999".format(cal_nn_column, METRIC)]]

'''Plot Bar'''
# For x-ticks
plt.subplot(gs[0])
ind = np.arange(11, dtype=float)  
width = 0.25
x = np.insert(ind, 2, 1.1) 
x = np.insert(x, 7, 5.1)
x = np.insert(x, 12, 9.1)

bn_res = np.concatenate([res.values.tolist() for res in result_bn])
nn_res = np.concatenate([res.values.tolist() for res in result_nn])
cnn_res = np.concatenate([res.values.tolist() for res in result_cnn])

bn_res = np.insert(bn_res, 3, 0)
bn_res = np.insert(bn_res, 7, 0)
nn_res = np.insert(nn_res, 3, 0)
nn_res = np.insert(nn_res, 7, 0)
cnn_res = np.insert(cnn_res, 3, 0)
cnn_res = np.insert(cnn_res, 7, 0)
# Get bar results to plot
bar_bn = plt.bar(ind, bn_res*100, width, edgecolor='black', color = '0.9') 
bar_nn = plt.bar(ind + width * 1.1, nn_res*100, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2.2, cnn_res*100, width, edgecolor='black', color = '0') 

plt.ylabel("{} (%)".format(metric)) 
plt.xlabel("Required Reliability Level (%)")
plt.ylim(bottom=ylim_bottom,top=ylim_top)
plt.xticks(x+width * 1.1,['UL', 'DL', '\n90.0%', 'VID', '', 'UL', 'DL', '\n99.0%', 'VID', '', 'UL', 'DL', '\n99.9%', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
# plt.legend( (bar_bn, bar_nn, bar_cnn), ('BN', 'NN', '{}-Calibrated NN'.format(metric)), bbox_to_anchor=(0, 1.05, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
plt.locator_params(axis='y', nbins=5)
# plt.title("{} for Different Required Reliability Levels".format(metric))

'''Plot Mean Trend'''
plt.subplot(gs[1])
# result_bn = [results_df["bn_reliability_state_{}_90".format(METRIC)].mean(), results_df["bn_reliability_state_{}_99".format(METRIC)].mean(), results_df["bn_reliability_state_{}_999".format(METRIC)].mean()]
# result_nn = [results_df["nn_reliability_state_{}_90".format(METRIC)].mean(), results_df["nn_reliability_state_{}_99".format(METRIC)].mean(), results_df["nn_reliability_state_{}_999".format(METRIC)].mean()]
# result_cnn = [results_df["{}_{}_90".format(cal_nn_column, METRIC)].mean(), results_df["{}_{}_99".format(cal_nn_column, METRIC)].mean(), results_df["{}_{}_999".format(cal_nn_column, METRIC)].mean()]
plt.plot(["90.0", "99.0", "99.9"], [res.mean()*100 for res in result_bn], '-o', color='0.3', markerfacecolor='none', markersize=6)
plt.plot(["90.0", "99.0", "99.9"], [res.mean()*100 for res in result_nn], ':x', color='0', markerfacecolor='none', markersize=9)
plt.plot(["90.0", "99.0", "99.9"], [res.mean()*100 for res in result_cnn], '--s', color='0.2', markerfacecolor='none', markersize=6)
# plt.legend( ('BN', 'NN', '{}-Calibrated NN'.format(metric)), bbox_to_anchor=(0, 1.05, 0.85, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
plt.ylabel("Average {} (%)".format(metric))
plt.xlabel("Required Reliability Level (%)")
plt.ylim(bottom=ylim_bottom,top=ylim_top)
plt.locator_params(axis='y', nbins=5)
# plt.title("Mean {} for Different Required Reliability Levels".format(metric))

# Save as SVG
plt.savefig("/home/research-student/journal_2_fig/fig5_c_f.svg", format="svg", bbox_inches='tight')

# %%
#TEMP 11/09/2025

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import numpy as np

# RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Reliability_Prediction_Results_Obj2.csv"
RESULTS_FILE = "/media/research-student/KingstonSSD/FANET_Dataset/Dataset_NP100000_DJISpark/Revised_Reliability_Prediction_Results_Obj2_final_model.csv"
METRIC = "specificity" # accuracy / recall / specificity
results_df = pd.read_csv(RESULTS_FILE)

if METRIC == "accuracy":
    metric = "Accuracy"
    cal_nn_column = "calibnn_reliability_state"
    ylim_bottom = 0.95*100
    ylim_top = 1.0005*100
elif METRIC == "recall":
    metric = "Sensitivity"
    cal_nn_column = "calibnn_specificity_reliability_state"
    ylim_bottom = 0
    ylim_top = 1.005*100
elif METRIC == "specificity":
    metric = "Specificity"
    cal_nn_column = "calibnn_specificity_reliability_state"
    ylim_bottom = 0.90*100
    ylim_top = 1.005*100

plt.figure(figsize=(16,4))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 2]) 
plt.rcParams.update({'font.size': 14})

result_nn = [results_df["nn_reliability_state_{}_90".format(METRIC)], results_df["nn_reliability_state_{}_99".format(METRIC)], results_df["nn_reliability_state_{}_999".format(METRIC)]]
result_cnn = [results_df["{}_{}_90".format(cal_nn_column, METRIC)], results_df["{}_{}_99".format(cal_nn_column, METRIC)], results_df["{}_{}_999".format(cal_nn_column, METRIC)]]

'''Plot Bar'''
# For x-ticks
plt.subplot(gs[0])
ind = np.arange(11, dtype=float)  
width = 0.25
x = np.insert(ind, 2, 1.1) 
x = np.insert(x, 7, 5.1)
x = np.insert(x, 12, 9.1)

nn_res = np.concatenate([res.values.tolist() for res in result_nn])
cnn_res = np.concatenate([res.values.tolist() for res in result_cnn])

nn_res = np.insert(nn_res, 3, 0)
nn_res = np.insert(nn_res, 7, 0)
cnn_res = np.insert(cnn_res, 3, 0)
cnn_res = np.insert(cnn_res, 7, 0)
# Get bar results to plot
bar_nn = plt.bar(ind + width, nn_res*100, width, edgecolor='black', color = '0.6') 
bar_cnn = plt.bar(ind + width * 2.2, cnn_res*100, width, edgecolor='black', color = '0') 

plt.ylabel("{} (%)".format("Sensitivity")) 
plt.xlabel("Required Reliability Level (%)")
plt.ylim(bottom=ylim_bottom,top=ylim_top)
plt.xticks(x+width * 1.1,['UL', 'DL', '\n90.0%', 'VID', '', 'UL', 'DL', '\n99.0%', 'VID', '', 'UL', 'DL', '\n99.9%', 'VID'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_nn, bar_cnn), ('NN', '{}-Calibrated NN'.format("Sensitivity")), bbox_to_anchor=(0, 1.05, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
plt.locator_params(axis='y', nbins=5)
# plt.title("{} for Different Required Reliability Levels".format(metric))

'''Plot Mean Trend'''
plt.subplot(gs[1])
# result_bn = [results_df["bn_reliability_state_{}_90".format(METRIC)].mean(), results_df["bn_reliability_state_{}_99".format(METRIC)].mean(), results_df["bn_reliability_state_{}_999".format(METRIC)].mean()]
# result_nn = [results_df["nn_reliability_state_{}_90".format(METRIC)].mean(), results_df["nn_reliability_state_{}_99".format(METRIC)].mean(), results_df["nn_reliability_state_{}_999".format(METRIC)].mean()]
# result_cnn = [results_df["{}_{}_90".format(cal_nn_column, METRIC)].mean(), results_df["{}_{}_99".format(cal_nn_column, METRIC)].mean(), results_df["{}_{}_999".format(cal_nn_column, METRIC)].mean()]
plt.plot(["90.0", "99.0", "99.9"], [res.mean()*100 for res in result_nn], ':x', color='0', markerfacecolor='none', markersize=9)
plt.plot(["90.0", "99.0", "99.9"], [res.mean()*100 for res in result_cnn], '--s', color='0.2', markerfacecolor='none', markersize=6)
plt.legend( ('NN', '{}-Calibrated NN'.format("Sensitivity")), bbox_to_anchor=(0, 1.05, 0.85, 0.2), loc="lower center", borderaxespad=0, ncol=2) 
plt.ylabel("Average {} (%)".format("Sensitivity"))
plt.xlabel("Required Reliability Level (%)")
plt.ylim(bottom=ylim_bottom,top=ylim_top)
plt.locator_params(axis='y', nbins=5)
# plt.title("Mean {} for Different Required Reliability Levels".format(metric))

# Save as SVG
# plt.savefig("/home/research-student/journal_2_fig/fig5_c_f.svg", format="svg", bbox_inches='tight')

# %% [markdown]
# ## Plot Percentage of Test Cases whose Average Reliability Meets Requirement for Maintenance

# %% [markdown]
# ### For MCS Adaptation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

RESULTS_ROOT = "/media/research-student/KingstonSSD/mcs_adaptation_results"
RELIABILITY_TH = 0.999 # Either 0.9 or 0.99 or 0.999
FILE_NAME_TYPE = 999 # Either 90 or 99 or 999

bn_results_df = pd.read_csv(RESULTS_ROOT + "/bn_proposed_{}_processed_results.csv".format(FILE_NAME_TYPE))
nn_results_df = pd.read_csv(RESULTS_ROOT + "/nn_proposed_{}_processed_results.csv".format(FILE_NAME_TYPE))
# calnn_f1_results_df = pd.read_csv(RESULTS_ROOT + "/OLD_13062024/proposed_calibrated_f1_{}_processed_results.csv".format(FILE_NAME_TYPE))
calnn_specificity_results_df = pd.read_csv(RESULTS_ROOT + "/nn_calibrated_specificity_{}_processed_results.csv".format(FILE_NAME_TYPE))
snr_max_pkt_results_df = pd.read_csv(RESULTS_ROOT + "/OLD_13062024/snr_based_max_pkt_size_{}_processed_results.csv".format(FILE_NAME_TYPE))
snr_min_pkt_results_df = pd.read_csv(RESULTS_ROOT + "/OLD_13062024/snr_based_min_pkt_size_{}_processed_results.csv".format(FILE_NAME_TYPE))
intel_mcs_results_df = pd.read_csv(RESULTS_ROOT + "/intel_mcs_scaling_{}_processed_results.csv".format(FILE_NAME_TYPE))

if RELIABILITY_TH == 0.999:
    # Exclude the following test cases: {USI:10ms, Height:255}, {USI:10ms, Height:285}
    bn_results_df = bn_results_df.loc[~((bn_results_df["UAV_Sending_Interval"]==10) & (bn_results_df["Height"]==255))]
    bn_results_df = bn_results_df.loc[~((bn_results_df["UAV_Sending_Interval"]==10) & (bn_results_df["Height"]==285))]
    nn_results_df = nn_results_df.loc[~((nn_results_df["UAV_Sending_Interval"]==10) & (nn_results_df["Height"]==255))]
    nn_results_df = nn_results_df.loc[~((nn_results_df["UAV_Sending_Interval"]==10) & (nn_results_df["Height"]==285))]
    # calnn_f1_results_df = calnn_f1_results_df.loc[~((calnn_f1_results_df["UAV_Sending_Interval"]==10) & (calnn_f1_results_df["Height"]==255))]
    # calnn_f1_results_df = calnn_f1_results_df.loc[~((calnn_f1_results_df["UAV_Sending_Interval"]==10) & (calnn_f1_results_df["Height"]==285))]
    calnn_specificity_results_df = calnn_specificity_results_df.loc[~((calnn_specificity_results_df["UAV_Sending_Interval"]==10) & (calnn_specificity_results_df["Height"]==255))]
    calnn_specificity_results_df = calnn_specificity_results_df.loc[~((calnn_specificity_results_df["UAV_Sending_Interval"]==10) & (calnn_specificity_results_df["Height"]==285))]
    snr_max_pkt_results_df = snr_max_pkt_results_df.loc[~((snr_max_pkt_results_df["UAV_Sending_Interval"]==10) & (snr_max_pkt_results_df["Height"]==255))]
    snr_max_pkt_results_df = snr_max_pkt_results_df.loc[~((snr_max_pkt_results_df["UAV_Sending_Interval"]==10) & (snr_max_pkt_results_df["Height"]==285))]
    snr_min_pkt_results_df = snr_min_pkt_results_df.loc[~((snr_min_pkt_results_df["UAV_Sending_Interval"]==10) & (snr_min_pkt_results_df["Height"]==255))]
    snr_min_pkt_results_df = snr_min_pkt_results_df.loc[~((snr_min_pkt_results_df["UAV_Sending_Interval"]==10) & (snr_min_pkt_results_df["Height"]==285))]
    intel_mcs_results_df = intel_mcs_results_df.loc[~((intel_mcs_results_df["UAV_Sending_Interval"]==10) & (intel_mcs_results_df["Height"]==255))]
    intel_mcs_results_df = intel_mcs_results_df.loc[~((intel_mcs_results_df["UAV_Sending_Interval"]==10) & (intel_mcs_results_df["Height"]==285))]
    
NUM_TEST_CASES = len(bn_results_df.loc[(bn_results_df["UAV_Speed"]==6)])

# Get results for UAV speed 6 m/s
bn_results_df = bn_results_df.loc[(bn_results_df["UAV_Speed"]==6) & (bn_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
                                  & (bn_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (bn_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]
nn_results_df = nn_results_df.loc[(nn_results_df["UAV_Speed"]==6) & (nn_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
                                  & (nn_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (nn_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]
# calnn_f1_results_df = calnn_f1_results_df.loc[(calnn_f1_results_df["UAV_Speed"]==6) & (calnn_f1_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
#                                   & (calnn_f1_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (calnn_f1_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]
calnn_specificity_results_df = calnn_specificity_results_df.loc[(calnn_specificity_results_df["UAV_Speed"]==6) & (calnn_specificity_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
                                  & (calnn_specificity_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (calnn_specificity_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]
snr_max_pkt_results_df = snr_max_pkt_results_df.loc[(snr_max_pkt_results_df["UAV_Speed"]==6) & (snr_max_pkt_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
                                  & (snr_max_pkt_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (snr_max_pkt_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]
snr_min_pkt_results_df = snr_min_pkt_results_df.loc[(snr_min_pkt_results_df["UAV_Speed"]==6) & (snr_min_pkt_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
                                  & (snr_min_pkt_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (snr_min_pkt_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]
intel_mcs_results_df = intel_mcs_results_df.loc[(intel_mcs_results_df["UAV_Speed"]==6) & (intel_mcs_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
                                  & (intel_mcs_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (intel_mcs_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]

# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]+0.05, "%.2f" % round(y[i], 2), ha = 'center')

# PLOT RESULTS
# For x-ticks
ind = np.arange(6, dtype=float)  
width = 0.4
percentages = [len(bn_results_df)/NUM_TEST_CASES, len(nn_results_df)/NUM_TEST_CASES, len(calnn_specificity_results_df)/NUM_TEST_CASES,
               len(snr_max_pkt_results_df)/NUM_TEST_CASES, len(snr_min_pkt_results_df)/NUM_TEST_CASES, len(intel_mcs_results_df)/NUM_TEST_CASES]
# xlabels = ["BN", "NN", "Cal. NN\n(F1)", "Cal. NN\n(Specificity)", "SNR-Based\nMax Packet Size", "SNR-Based\nMin Packet Size", "Intel MCS\nAdaptation"]
xlabels = ["BN", "NN", "Cal. NN\n(Specificity)", "SNR-Based\nMax Packet Size", "SNR-Based\nMin Packet Size", "Intel MCS\nAdaptation"]
# PLOT RELIABILITY REQUIREMENT CLASSIFICATION SPECIFICITY 
plt.figure(figsize=(14,4))
plt.rcParams.update({'font.size': 12})
bar_maintenance = plt.bar(ind, percentages, width, edgecolor='black', color = '0.5')
addlabels(xlabels,[np.round(p, decimals=2) for p in percentages]) 
plt.ylabel('Percentage Test Cases\nwhere Reliability Maintained') 
# plt.ylim(0.85, 1.0)
plt.xticks(ind,xlabels)
plt.tick_params(axis='x', which='both',length=0)

# %% [markdown]
# ### For USI Adaptation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

RESULTS_ROOT = "/media/research-student/KingstonSSD/usi_adaptation_results"
RELIABILITY_TH = 0.99 # Either 0.99 or 0.999
FILE_NAME_TYPE = 99 # Either 99 or 999
# NUM_TEST_CASES = 39

bn_results_df = pd.read_csv(RESULTS_ROOT + "/bn_proposed_{}_processed_results.csv".format(FILE_NAME_TYPE))
nn_results_df = pd.read_csv(RESULTS_ROOT + "/nn_proposed_{}_processed_results.csv".format(FILE_NAME_TYPE))
calnn_specificity_results_df = pd.read_csv(RESULTS_ROOT + "/nn_calibrated_specificity_{}_processed_results.csv".format(FILE_NAME_TYPE))

NUM_TEST_CASES = len(bn_results_df.loc[(bn_results_df["UAV_Speed"]==6)])
# Get results for UAV speed 6 m/s
bn_results_df = bn_results_df.loc[(bn_results_df["UAV_Speed"]==6) & (bn_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
                                  & (bn_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (bn_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]
nn_results_df = nn_results_df.loc[(nn_results_df["UAV_Speed"]==6) & (nn_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
                                  & (nn_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (nn_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]
calnn_specificity_results_df = calnn_specificity_results_df.loc[(calnn_specificity_results_df["UAV_Speed"]==6) & (calnn_specificity_results_df["Mean_Reliability_DL"]>=RELIABILITY_TH) 
                                  & (calnn_specificity_results_df["Mean_Reliability_UL"]>=RELIABILITY_TH) & (calnn_specificity_results_df["Mean_Reliability_VID"]>=RELIABILITY_TH)]

# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]+0.05, "%.2f" % round(y[i], 2), ha = 'center')

# PLOT RESULTS
# For x-ticks
ind = np.arange(3, dtype=float)  
width = 0.4
percentages = [len(bn_results_df)/NUM_TEST_CASES, len(nn_results_df)/NUM_TEST_CASES, len(calnn_specificity_results_df)/NUM_TEST_CASES]
xlabels = ["BN", "NN", "Cal. NN\n(Specificity)"]
# xlabels = ["BN", "NN", "Cal. NN\n(Specificity)", "SNR-Based\nMax Packet Size", "SNR-Based\nMin Packet Size", "Intel MCS\nAdaptation"]
# PLOT RELIABILITY REQUIREMENT CLASSIFICATION SPECIFICITY 
plt.figure(figsize=(10,4))
plt.rcParams.update({'font.size': 12})
bar_maintenance = plt.bar(ind, percentages, width, color = 'blue')
addlabels(xlabels,[np.round(p, decimals=2) for p in percentages]) 
plt.ylabel('Percentage Test Cases\nwhere Reliability Maintained') 
# plt.ylim(0.85, 1.0)
plt.xticks(ind,xlabels)
plt.tick_params(axis='x', which='both',length=0)

# %% [markdown]
# ## Plot Percentage of Runs Meeting Reliability Requirement

# %% [markdown]
# ### For MCS Adaptation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

RESULTS_ROOT = "/media/research-student/KingstonSSD/mcs_adaptation_results/MCS_Adaptation_Percentage_Results_100_Runs.csv"
RELIABILITY_TH = 999 # Either 90 or 99 or 999
UAV_SPEED = 26

results_df = pd.read_csv(RESULTS_ROOT)
results_df["Percentage_Maintained"] = results_df["Num_Maintained"] / results_df["Num_Runs"]

# results_df = results_df.loc[["_{}_".format(RELIABILITY_TH) in model for model in results_df["Model"]]]
results_df = results_df.loc[results_df["UAV_Speed"] == UAV_SPEED]

bn_results_df = results_df.loc[results_df["Model"] == "bn_proposed_{}_processed".format(RELIABILITY_TH)]
nn_results_df = results_df.loc[results_df["Model"] == "nn_proposed_{}_processed".format(RELIABILITY_TH)]
calnn_specificity_results_df = results_df.loc[results_df["Model"] == "nn_calibrated_specificity_{}_processed".format(RELIABILITY_TH)]
intel_mcs_results_df = results_df.loc[results_df["Model"] == "intel_mcs_scaling_{}_processed".format(RELIABILITY_TH)]
snr_max_pkt_results_df = results_df.loc[results_df["Model"] == "snr_based_max_pkt_size_{}_processed".format(RELIABILITY_TH)]
snr_min_pkt_results_df = results_df.loc[results_df["Model"] == "snr_based_min_pkt_size_{}_processed".format(RELIABILITY_TH)]

# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        if i == 1 or i == 2:
            plt.text(i, 100+6, "%.1f %%" % round(y[i], 1), ha = 'center')
        else:
            plt.text(i, y[i]+3, "%.1f %%" % round(y[i], 1), ha = 'center')

# PLOT RESULTS
# For x-ticks
ind = np.arange(6, dtype=float)  
width = 0.4
# percentages = [bn_results_df["Percentage_Maintained"].values[0], nn_results_df["Percentage_Maintained"].values[0], calnn_specificity_results_df["Percentage_Maintained"].values[0], 
#                intel_mcs_results_df["Percentage_Maintained"].values[0], snr_max_pkt_results_df["Percentage_Maintained"].values[0], snr_min_pkt_results_df["Percentage_Maintained"].values[0]]
percentages = [bn_results_df["Percentage_Maintained"].values[0], nn_results_df["Percentage_Maintained"].values[0], calnn_specificity_results_df["Percentage_Maintained"].values[0], 
               intel_mcs_results_df["Percentage_Maintained"].values[0], 0, 0]
xlabels = ["BN", "NN", "Specificity-Calibrated\nNN", "Packet-Loss-\nBased", "SNR-Based\n(Max Packet Size)", "SNR-Based\n(Min Packet Size)"]
# percentages = [bn_results_df["Percentage_Maintained"].values[0], nn_results_df["Percentage_Maintained"].values[0], calnn_specificity_results_df["Percentage_Maintained"].values[0]]
# xlabels = ["BN", "NN", "Cal. NN\n(Specificity)"]
# PLOT RELIABILITY REQUIREMENT CLASSIFICATION SPECIFICITY 
plt.figure(figsize=(14,4))
plt.rcParams.update({'font.size': 14})
bar_maintenance = plt.bar(ind, np.array(percentages)*100, width, edgecolor='black', color = '0.5')
addlabels(xlabels,np.array(percentages)*100) 
plt.ylabel('Success Rate (%)') 
plt.ylim(0, 100)
plt.xticks(ind,xlabels)
plt.text(-0.35, -25, "| ----------- Reliability-Classification-Based ----------- |")
# To add another label in x-ticks
# x = np.insert(ind, 2, 1.1) 
# xlabels = np.insert(xlabels, 2, "\n\nReliability-Based-Classification")
# plt.xticks(x,xlabels)
plt.tick_params(axis='x', which='both',length=0)

# Save as SVG
plt.savefig("/home/research-student/journal_2_fig/figA5_c.svg", format="svg", bbox_inches='tight')

# %% [markdown]
# ### For USI Adaptation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

RESULTS_ROOT = "/media/research-student/KingstonSSD/usi_adaptation_results/USI_Adaptation_Percentage_Results_100_Runs.csv"
UAV_SPEED = 26

results_df = pd.read_csv(RESULTS_ROOT)
results_df["Percentage_Maintained"] = results_df["Num_Maintained"] / results_df["Num_Runs"]

# results_df = results_df.loc[["_{}_".format(RELIABILITY_TH) in model for model in results_df["Model"]]]
results_df = results_df.loc[results_df["UAV_Speed"] == UAV_SPEED]

bn_results_90_df = results_df.loc[results_df["Model"] == "bn_proposed_{}_processed".format(90)]
bn_results_99_df = results_df.loc[results_df["Model"] == "bn_proposed_{}_processed".format(99)]
bn_results_999_df = results_df.loc[results_df["Model"] == "bn_proposed_{}_processed".format(999)]
bn_percentages = [bn_results_90_df["Percentage_Maintained"].values[0], bn_results_99_df["Percentage_Maintained"].values[0], bn_results_999_df["Percentage_Maintained"].values[0]]

nn_results_90_df = results_df.loc[results_df["Model"] == "nn_proposed_{}_processed".format(90)]
nn_results_99_df = results_df.loc[results_df["Model"] == "nn_proposed_{}_processed".format(99)]
nn_results_999_df = results_df.loc[results_df["Model"] == "nn_proposed_{}_processed".format(999)]
nn_percentages = [nn_results_90_df["Percentage_Maintained"].values[0], nn_results_99_df["Percentage_Maintained"].values[0], nn_results_999_df["Percentage_Maintained"].values[0]]

calnn_specificity_90_results_df = results_df.loc[results_df["Model"] == "nn_calibrated_specificity_{}_processed".format(90)]
calnn_specificity_99_results_df = results_df.loc[results_df["Model"] == "nn_calibrated_specificity_{}_processed".format(99)]
calnn_specificity_999_results_df = results_df.loc[results_df["Model"] == "nn_calibrated_specificity_{}_processed".format(999)]
cnn_percentages = [calnn_specificity_90_results_df["Percentage_Maintained"].values[0], calnn_specificity_99_results_df["Percentage_Maintained"].values[0], calnn_specificity_999_results_df["Percentage_Maintained"].values[0]]

# function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        if i == 0 or i == 3 or i == 6:
            plt.text(i, y[i]+3, "%.1f %%" % round(y[i], 1), ha = 'center')
        else:
            plt.text(i, 100+3, "%.1f %%" % round(y[i], 1), ha = 'center')

# PLOT RESULTS
# For x-ticks
ind = np.arange(3, dtype=float)  
width = 0.2
x = np.arange(9, dtype=float) 
x = np.insert(x, 2, 1.1) 
x = np.insert(x, 6, 4.1)
x = np.insert(x, 10, 7.1)

xlabels = ["BN", "NN", "Cal. NN\n(Specificity)"]
# PLOT RELIABILITY REQUIREMENT CLASSIFICATION SPECIFICITY 
plt.figure(figsize=(12,4))
# plt.subplot(1,2,1)
plt.rcParams.update({'font.size': 14})
bar_maintenance_90 = plt.bar(ind, np.array(bn_percentages)*100, width, edgecolor='black', color = '0.9')
bar_maintenance_99 = plt.bar(ind + width * 1.1, np.array(nn_percentages)*100, width, edgecolor='black', color = '0.6')
bar_maintenance_999 = plt.bar(ind + width * 2.2, np.array(cnn_percentages)*100, width, edgecolor='black', color = '0.0')
# addlabels(xlabels,np.array(bn_percentages + nn_percentages + cnn_percentages)*100) 
plt.ylabel('Success Rate (%)') 
plt.xlabel("Required Reliability Level (%)")
plt.ylim(0, 100)
plt.xticks(ind+width * 1.1,['90.0', '99.0', '99.9'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_maintenance_90, bar_maintenance_99, bar_maintenance_999), ('BN', 'NN', 'Specificity-Calibrated NN'), bbox_to_anchor=(0, 1.1, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 
# For bar labels
plt.rcParams['font.size'] = 12 # Changes font size for bar labels only
plt.bar_label(bar_maintenance_90, [math.floor(percentage * 1000)/10.0 for percentage in bn_percentages], padding=2)
plt.bar_label(bar_maintenance_99, [math.floor(percentage * 1000)/10.0 for percentage in nn_percentages], padding=2)
plt.bar_label(bar_maintenance_999, [math.floor(percentage * 1000)/10.0 for percentage in cnn_percentages], padding=2)

# plt.subplot(1,2,2)
# plt.rcParams.update({'font.size': 14})
# bar_maintenance = plt.bar(ind, np.array(percentages)*100, width, edgecolor='black', color = '0.5')
# addlabels(xlabels,np.array(percentages)*100) 
# plt.ylabel('Percentage (%)') 
# plt.ylim(0, 100)
# plt.xticks(ind,xlabels)
# plt.tick_params(axis='x', which='both',length=0)

# Save as SVG
plt.savefig("/home/research-student/journal_2_fig/figB5.svg", format="svg", bbox_inches='tight')
