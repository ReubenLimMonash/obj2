# %%
import numpy as np
# mcs_indexes = [7,6,5,4,3,2,1,0]
mcs_indexes = [0,1,2,3,4,5,6,7]
curr_MCS_index = 7
next_MCS_indexes = [x for _,x in sorted(zip(np.abs(np.arange(len(mcs_indexes))-curr_MCS_index), np.arange(len(mcs_indexes))))][1:]
next_MCS_indexes
# Out:
# [6, 5, 4, 3, 2, 1, 0]

# %%
curr_MCS_index = 6
[i for i in range(curr_MCS_index-1, -1, -1)]
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
import numpy as np
import itertools

mcs_indexes = [0,1,2,3,4,5,6,7]
usi_list = [10, 20, 66.7, 100]
all_combinations = list(itertools.product(usi_list, mcs_indexes))
mcs_zip = [mcs for _,mcs in all_combinations]
usi_zip = [usi for usi,_ in all_combinations]
mcs_zip, usi_zip
