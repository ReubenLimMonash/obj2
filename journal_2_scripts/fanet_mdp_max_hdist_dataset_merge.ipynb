# %%
import pandas as pd
dl_batch1 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch1_processed/Downlink_Reliability.csv")
ul_batch1 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch1_processed/Uplink_Reliability.csv")
vid_batch1 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch1_processed/Video_Reliability.csv")

dl_batch5 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed/Downlink_Reliability.csv")
ul_batch5 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed/Uplink_Reliability.csv")
vid_batch5 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed/Video_Reliability.csv")

dl_batch2 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed_/Downlink_Reliability.csv")
ul_batch2 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed_/Uplink_Reliability.csv")
vid_batch2 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed_/Video_Reliability.csv")

dl_batch3 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed__/Downlink_Reliability.csv")
ul_batch3 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed__/Uplink_Reliability.csv")
vid_batch3 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed__/Video_Reliability.csv")

dl_batch4 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed___/Downlink_Reliability.csv")
ul_batch4 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed___/Uplink_Reliability.csv")
vid_batch4 = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_batch2_processed___/Video_Reliability.csv")

dl_df = pd.concat([dl_batch1, dl_batch2, dl_batch3, dl_batch4, dl_batch5])
ul_df = pd.concat([ul_batch1, ul_batch2, ul_batch3, ul_batch4, ul_batch5])
vid_df = pd.concat([vid_batch1, vid_batch2, vid_batch3, vid_batch4, vid_batch5])

dl_df.sort_values(by=["UAV_Sending_Interval", "Bitrate", "Height", "Horizontal_Distance"], inplace=True)
ul_df.sort_values(by=["UAV_Sending_Interval", "Bitrate", "Height", "Horizontal_Distance"], inplace=True)
vid_df.sort_values(by=["UAV_Sending_Interval", "Bitrate", "Height", "Horizontal_Distance"], inplace=True)

dl_df.to_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_processed/Downlink_Reliability.csv")
ul_df.to_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_processed/Uplink_Reliability.csv")
vid_df.to_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_processed/Video_Reliability.csv")

# %%
import pandas as pd

dl_df_gw = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Downlink_GW_Reliability.csv")
dl_df_0 = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Downlink_UAV-0_Reliability.csv")
dl_df_1 = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Downlink_UAV-1_Reliability.csv")
dl_df_2 = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Downlink_UAV-2_Reliability.csv")
dl_df_3 = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Downlink_UAV-3_Reliability.csv")
dl_df_4 = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Downlink_UAV-4_Reliability.csv")
dl_df_5 = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Downlink_UAV-5_Reliability.csv")
dl_df_6 = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Downlink_UAV-6_Reliability.csv")
ul_df = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Uplink_Reliability.csv")
vid_df = pd.read_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_all_links/Video_Reliability.csv")

dl_df = dl_df_gw.copy()
dl_df["Num_Reliable"] = dl_df_gw["Num_Reliable"] + dl_df_0["Num_Reliable"] + dl_df_1["Num_Reliable"] + dl_df_2["Num_Reliable"] + dl_df_3["Num_Reliable"] + dl_df_4["Num_Reliable"] + dl_df_5["Num_Reliable"] + dl_df_6["Num_Reliable"]
dl_df["Num_Delay_Excd"] = dl_df_gw["Num_Delay_Excd"] + dl_df_0["Num_Delay_Excd"] + dl_df_1["Num_Delay_Excd"] + dl_df_2["Num_Delay_Excd"] + dl_df_3["Num_Delay_Excd"] + dl_df_4["Num_Delay_Excd"] + dl_df_5["Num_Delay_Excd"] + dl_df_6["Num_Delay_Excd"]
dl_df["Num_Fail_Other"] = dl_df_gw["Num_Fail_Other"] + dl_df_0["Num_Fail_Other"] + dl_df_1["Num_Fail_Other"] + dl_df_2["Num_Fail_Other"] + dl_df_3["Num_Fail_Other"] + dl_df_4["Num_Fail_Other"] + dl_df_5["Num_Fail_Other"] + dl_df_6["Num_Fail_Other"]

dl_df_other = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_processed/Downlink_Reliability.csv")
dl_df_other["Num_Fail_Other"] = dl_df_other["Num_Incr_Rcvd"] + dl_df_other["Num_Q_Overflow"]
dl_df_other.drop(columns=["Num_Sent", "Num_Incr_Rcvd", "Num_Q_Overflow"], inplace=True)
dl_df = pd.concat([dl_df, dl_df_other]) 

ul_df_other = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_processed/Uplink_Reliability.csv")
ul_df_other["Num_Fail_Other"] = ul_df_other["Num_Incr_Rcvd"] + ul_df_other["Num_Q_Overflow"]
ul_df_other.drop(columns=["Num_Sent", "Num_Incr_Rcvd", "Num_Q_Overflow"], inplace=True)
ul_df = pd.concat([ul_df, ul_df_other]) 

vid_df_other = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/mdp_max_hdist/data_processed/Video_Reliability.csv")
vid_df_other["Num_Fail_Other"] = vid_df_other["Num_Incr_Rcvd"] + vid_df_other["Num_Q_Overflow"]
vid_df_other.drop(columns=["Num_Sent", "Num_Incr_Rcvd", "Num_Q_Overflow"], inplace=True)
vid_df = pd.concat([vid_df, vid_df_other]) 

dl_df.sort_values(by=["UAV_Sending_Interval", "Bitrate", "Height", "Horizontal_Distance"], inplace=True)
ul_df.sort_values(by=["UAV_Sending_Interval", "Bitrate", "Height", "Horizontal_Distance"], inplace=True)
vid_df.sort_values(by=["UAV_Sending_Interval", "Bitrate", "Height", "Horizontal_Distance"], inplace=True)

dl_df.to_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_complete/Downlink_Reliability.csv")
ul_df.to_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_complete/Uplink_Reliability.csv")
vid_df.to_csv("/media/research-student/DataDrive/FANET_Dataset/complete_testing_dmax_dataset/data_processed_complete/Video_Reliability.csv")
