# %%
import pandas

df = pandas.read_csv("/media/research-student/One Touch/FANET Datasets/Dataset_NP10000_MultiModulation_Hovering_NoVideo/QPSK_processed/NumMember-7_InterUAVDistance-5_Height-90_Distance-420_Modulation-QPSK_UAVSendingInterval-1000_downlink.csv")

num_packets = len(df)
num_reliable = len(df.loc[df["Packet_State"] == "Reliable"])
num_incr_rcvd = len(df.loc[df["Packet_State"] == "RETRY_LIMIT_REACHED"])
num_queue_overflow = len(df.loc[df["Packet_State"] == "QUEUE_OVERFLOW"])
num_delay_excd = len(df.loc[df["Packet_State"] == "Delay_Exceeded"])
print("Full DF:")
print("Reliability: ", num_reliable/num_packets)
print("Incr Rcvd: ", num_incr_rcvd/num_packets)
print("Queue Overflow: ", num_queue_overflow/num_packets)
print("Delay Excd: ", num_delay_excd/num_packets)

df = df.head(100000)

num_packets = len(df)
num_reliable = len(df.loc[df["Packet_State"] == "Reliable"])
num_incr_rcvd = len(df.loc[df["Packet_State"] == "RETRY_LIMIT_REACHED"])
num_queue_overflow = len(df.loc[df["Packet_State"] == "QUEUE_OVERFLOW"])
num_delay_excd = len(df.loc[df["Packet_State"] == "Delay_Exceeded"])
print("Partial DF:")
print("Reliability: ", num_reliable/num_packets)
print("Incr Rcvd: ", num_incr_rcvd/num_packets)
print("Queue Overflow: ", num_queue_overflow/num_packets)
print("Delay Excd: ", num_delay_excd/num_packets)
# Out:
# Full DF:
# Reliability:  0.5118568971035365
# Incr Rcvd:  0.004750760121619459
# Queue Overflow:  0.4826847295567291
# Delay Excd:  0.0007076132181148984
# Partial DF:
# Reliability:  0.51126
# Incr Rcvd:  0.0046
# Queue Overflow:  0.48407
# Delay Excd:  7e-05

# %%
import glob

ul_list = glob.glob("/media/research-student/One Touch/FANET Datasets/Dataset_NP10000_MultiModulation_Hovering_NoVideo/BPSK_processed/*uplink.csv")
print(ul_list)
# Out:
# ['/media/research-student/One Touch/FANET Datasets/Dataset_NP10000_MultiModulation_Hovering_NoVideo/BPSK_processed/NumMember-7_InterUAVDistance-5_Height-90_Distance-400_Modulation-BPSK_UAVSendingInterval-20_uplink.csv', '/media/research-student/One Touch/FANET Datasets/Dataset_NP10000_MultiModulation_Hovering_NoVideo/BPSK_processed/NumMember-7_InterUAVDistance-5_Height-240_Distance-1000_Modulation-BPSK_UAVSendingInterval-20_uplink.csv', '/media/research-student/One Touch/FANET Datasets/Dataset_NP10000_MultiModulation_Hovering_NoVideo/BPSK_processed/NumMember-7_InterUAVDistance-5_Height-60_Distance-820_Modulation-BPSK_UAVSendingInterval-20_uplink.csv', '/media/research-student/One Touch/FANET Datasets/Dataset_NP10000_MultiModulation_Hovering_NoVideo/BPSK_processed/NumMember-7_InterUAVDistance-5_Height-90_Distance-840_Modulation-BPSK_UAVSendingInterval-20_uplink.csv', '/media/research-student/One Touch/FANET Datasets/Dataset_NP10000_MultiModulation_Hovering_NoVideo/BPSK_processed/NumMe
# ...
