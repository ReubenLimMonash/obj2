# %% [markdown]
# # To explore relationship between measured throughput and measured reliability <br>
# Date: 29/08/2024

# %% [markdown]
# # For Single Run of A Scenario

# %% [markdown]
# ## Plot Single Scenario

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import glob, os

DATA_PATH = "/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_uav_interference/uav_scenario_0_processed"
SCENARIO = "UAVSpeed-8_Height-255_BitRate-19.5_Modulation-QPSK_UAVSendingInterval-20_Distance-300_InterferenceBitRate-26_InterferenceUSI-100"
# DATA_PATH = "/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_2_processed"
# SCENARIO = "UAVSpeed-24_BitRate-13_Height-105_Distance-260_Modulation-QPSK_UAVSendingInterval-20_MANETNumNode-50_MANETBitRate-6.5"
RUN_NUM = 0
LINK = "Downlink"

# Load throughput files
df_list = []
if LINK == "Downlink":
    throughput_files = glob.glob(os.path.join(DATA_PATH, SCENARIO, "Run-{}_*_Downlink_Throughput.csv".format(RUN_NUM)))
elif LINK == "Uplink":
    throughput_files = glob.glob(os.path.join(DATA_PATH, SCENARIO, "Run-{}_Uplink_Throughput.csv".format(RUN_NUM)))
elif LINK == "Video":
    throughput_files = glob.glob(os.path.join(DATA_PATH, SCENARIO, "Run-{}_Video_Throughput.csv".format(RUN_NUM)))
for file in throughput_files:
    measured_df = pd.read_csv(file)
    df_list.append(measured_df)
df = pd.concat(df_list)

# Plot measured throughput vs hdist
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(df["Horizontal_Distance"], df["Throughput"], c="b", alpha=0.6)
plt.xlabel("Horizontal Distance (m)")
plt.ylabel("Throughput (bytes/sec)")
plt.legend(["Measured Throughput"])
plt.ylim(bottom=0)

# Plot measured reliability vs hdist (with dummy margin for alignment)
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(df["Horizontal_Distance"], df["Measured_Reliability"] * 1000, c="tab:orange", alpha=0.6)
plt.xlabel("Horizontal Distance (m)")
plt.ylabel("Measured Reliability (%)")
plt.legend(["Measured Reliability"])
plt.ylim(bottom=0)

# Plot measured reliability vs hdist 
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(df["Horizontal_Distance"], df["Measured_Reliability"] * 100, c="tab:orange", alpha=0.6)
plt.xlabel("Horizontal Distance (m)")
plt.ylabel("Measured Reliability (%)")
plt.legend(["Measured Reliability"])
plt.ylim(bottom=0)

# Plot normalised measured throughput vs measured reliability
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(df["Measured_Reliability"], df["Throughput"] / df["Throughput"].max(), c="k", alpha=0.6)
plt.xlabel("Throughput (bytes/sec)")
plt.ylabel("Measured Reliability (%)")
# Out:
# Text(0, 0.5, 'Measured Reliability (%)')

# %% [markdown]
# ## Plot Throughput No Interference

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import glob, os

DATA_PATH = "/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_test_processed" 
SCENARIO = "UAVSpeed-8_BitRate-13_Height-285_Distance-420_Modulation-QPSK_UAVSendingInterval-100"
RUN_NUM = 0
LINK = "Video"

# Load throughput files
df_list = []
if LINK == "Downlink":
    throughput_files = glob.glob(os.path.join(DATA_PATH, SCENARIO, "Run-{}_*_Downlink_Throughput.csv".format(RUN_NUM)))
elif LINK == "Uplink":
    throughput_files = glob.glob(os.path.join(DATA_PATH, SCENARIO, "Run-{}_Uplink_Throughput.csv".format(RUN_NUM)))
elif LINK == "Video":
    throughput_files = glob.glob(os.path.join(DATA_PATH, SCENARIO, "Run-{}_Video_Throughput.csv".format(RUN_NUM)))
for file in throughput_files:
    measured_df = pd.read_csv(file)
    df_list.append(measured_df)
df = pd.concat(df_list)

# Plot measured throughput vs hdist
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(df["Horizontal_Distance"], df["Throughput"], c="b", alpha=0.6)
plt.xlabel("Horizontal Distance (m)")
plt.ylabel("Throughput (bytes/sec)")
plt.legend(["Measured Throughput"])
plt.ylim(bottom=0)

# Plot measured reliability vs hdist 
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(df["Horizontal_Distance"], df["Measured_Reliability"] * 100, c="tab:orange", alpha=0.6)
plt.xlabel("Horizontal Distance (m)")
plt.ylabel("Measured Reliability (%)")
plt.legend(["Measured Reliability"])
plt.ylim(bottom=0)

# Plot normalised measured throughput vs measured reliability
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(df["Measured_Reliability"], df["Throughput"] / df["Throughput"].max(), c="k", alpha=0.6)
plt.xlabel("Throughput (bytes/sec)")
plt.ylabel("Measured Reliability (%)")
# Out:
# Text(0, 0.5, 'Measured Reliability (%)')

# %% [markdown]
# ## Plot the Correlation Betweenn Throughput and Measured Reliability

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import glob, os
from tqdm import tqdm

DATA_PATH = "/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_uav_interference/temp" 
SCENARIO = "UAVSpeed-12_Height-75_BitRate-19.5_Modulation-QPSK_UAVSendingInterval-100_Distance-240_InterferenceBitRate-13_InterferenceUSI-66.7"
# DATA_PATH = "/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_2_processed"
# SCENARIO = "UAVSpeed-24_BitRate-13_Height-105_Distance-260_Modulation-QPSK_UAVSendingInterval-20_MANETNumNode-50_MANETBitRate-6.5"

print("LOADING DL THROUGHPUT")
dl_df_list = []
dl_throughput_files = glob.glob(os.path.join(DATA_PATH, SCENARIO, "Run-*_Downlink_Throughput.csv"))
for file in tqdm(dl_throughput_files):
    measured_df = pd.read_csv(file)
    dl_df_list.append(measured_df)
dl_df = pd.concat(dl_df_list)

print("LOADING UL THROUGHPUT")
ul_df_list = []
ul_throughput_files = glob.glob(os.path.join(DATA_PATH, SCENARIO, "Run-*_Uplink_Throughput.csv"))
for file in tqdm(ul_throughput_files):
    measured_df = pd.read_csv(file)
    ul_df_list.append(measured_df)
ul_df = pd.concat(ul_df_list)

print("LOADING VID THROUGHPUT")
vid_df_list = []
vid_throughput_files = glob.glob(os.path.join(DATA_PATH, SCENARIO, "Run-*_Video_Throughput.csv"))
for file in tqdm(vid_throughput_files):
    measured_df = pd.read_csv(file)
    vid_df_list.append(measured_df)
vid_df = pd.concat(vid_df_list)

dl_df["Norm_Throughput"] = dl_df["Throughput"] / dl_df["Throughput"].max()
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(dl_df["Norm_Throughput"], dl_df["Measured_Reliability"], c="k", alpha=0.1)
plt.ylabel("Measured Reliability")
plt.xlabel("Normalized Throughput")
plt.xlim((0,1))
plt.ylim((0,1))

ul_df["Norm_Throughput"] = ul_df["Throughput"] / ul_df["Throughput"].max()
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(ul_df["Norm_Throughput"], ul_df["Measured_Reliability"], c="k", alpha=0.1)
plt.ylabel("Measured Reliability")
plt.xlabel("Normalized Throughput")
plt.xlim((0,1))
plt.ylim((0,1))

vid_df["Norm_Throughput"] = vid_df["Throughput"] / vid_df["Throughput"].max()
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(vid_df["Norm_Throughput"], vid_df["Measured_Reliability"], c="k", alpha=0.1)
plt.ylabel("Measured Reliability")
plt.xlabel("Normalized Throughput")
plt.xlim((0,1))
plt.ylim((0,1))
# Out:
# LOADING DL THROUGHPUT
# ...
# 100%|██████████| 800/800 [00:03<00:00, 259.39it/s]
# LOADING UL THROUGHPUT
# 100%|██████████| 100/100 [00:00<00:00, 243.74it/s]
# LOADING VID THROUGHPUT
# 100%|██████████| 100/100 [00:00<00:00, 272.26it/s]
# (0.0, 1.0)

# %% [markdown]
# # For All Runs in an Interference Scenario

# %% [markdown]
# ## Compile throughput data

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import glob, os
from tqdm import tqdm
from multiprocessing.pool import Pool

NUM_PROCS = 32
DATASET_PATH = "/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_2_processed" 
scenario_paths = glob.glob(DATASET_PATH + "/*")

# We normalize the throughput with different maximum based on USI
usi_max_throughput_dl = {10:2720, 20: 2720, 66.7: 2720, 100: 2720}
usi_max_throughput_ul = {10:513788, 20: 265043, 66.7: 106570, 100: 77140}
usi_max_throughput_vid = {10:261000, 20: 261000, 66.7: 262450, 100: 261000}

# Throughput threshold for filtering
usi_min_throughput_dl = {10: 600, 20: 600, 66.7: 600, 100: 600}
usi_min_throughput_ul = {10: 183200, 20: 88850, 66.7: 22810, 100: 14390}
usi_min_throughput_vid = {10:227166.66666666663, 20: 188500, 66.7: 188500, 100: 203000}

'''Without Filtering for Throughput Above Threshold'''
def load_throughput(scenario_path):
    '''Modified: Add the scenario parameters and run number so that DFs can be sorted for rows 
                 of each DF to correspond to the same time window of the same run
    '''
    scenario_name = scenario_path.split("/")[-1]
    params = scenario_name.split("_")
    usi = [x for x in params if "UAVSendingInterval" in x][0].split('-')[-1]
    speed = [x for x in params if "UAVSpeed" in x][0].split('-')[-1]
    height = [x for x in params if "Height" in x][0].split('-')[-1]
    bitrate = [x for x in params if "BitRate" in x][0].split('-')[-1]

    # Get Run Nums (Using UL files, since there's only one UL file per run)
    ul_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Uplink_Throughput.csv"))
    run_num = [int(f.split("Run-")[-1].split("_")[0]) for f in ul_throughput_files]
    # Load DL Throughput
    uav_df_list = []
    for run in run_num:
        dl_df_0 = pd.read_csv(os.path.join(scenario_path, "Run-{}_UAV-0_Downlink_Throughput.csv".format(run)))
        dl_df_1 = pd.read_csv(os.path.join(scenario_path, "Run-{}_UAV-1_Downlink_Throughput.csv".format(run)))
        dl_df_2 = pd.read_csv(os.path.join(scenario_path, "Run-{}_UAV-2_Downlink_Throughput.csv".format(run)))
        dl_df_3 = pd.read_csv(os.path.join(scenario_path, "Run-{}_UAV-3_Downlink_Throughput.csv".format(run)))
        dl_df_4 = pd.read_csv(os.path.join(scenario_path, "Run-{}_UAV-4_Downlink_Throughput.csv".format(run)))
        dl_df_5 = pd.read_csv(os.path.join(scenario_path, "Run-{}_UAV-5_Downlink_Throughput.csv".format(run)))
        dl_df_6 = pd.read_csv(os.path.join(scenario_path, "Run-{}_UAV-6_Downlink_Throughput.csv".format(run)))
        dl_df_7 = pd.read_csv(os.path.join(scenario_path, "Run-{}_UAV-7_Downlink_Throughput.csv".format(run)))
        for df in [dl_df_0, dl_df_1, dl_df_2, dl_df_3, dl_df_4, dl_df_5, dl_df_6, dl_df_7]:
            df["Run_Num"] = run
            df["USI"] = usi
            df["UAV_Speed"] = speed
            df["UAV_Height"] = height
            df["Bit_Rate"] = bitrate
        uav_df_list.append([dl_df_0, dl_df_1, dl_df_2, dl_df_3, dl_df_4, dl_df_5, dl_df_6, dl_df_7])
    dl_df_list = [pd.concat([uav_df_list[i][j] for i in range(len(run_num))]) for j in range(len(uav_df_list[0]))]
    
    # Load UL Throughput
    ul_df_list = []
    for run in run_num:
        measured_df = pd.read_csv(os.path.join(scenario_path, "Run-{}_Uplink_Throughput.csv".format(run)))
        measured_df["Run_Num"] = run
        ul_df_list.append(measured_df)
    ul_df = pd.concat(ul_df_list)
    ul_df["USI"] = usi
    ul_df["UAV_Speed"] = speed
    ul_df["UAV_Height"] = height
    ul_df["Bit_Rate"] = bitrate
    # Load Video Throughput
    vid_df_list = []
    for run in run_num:
        measured_df = pd.read_csv(os.path.join(scenario_path, "Run-{}_Video_Throughput.csv".format(run)))
        measured_df["Run_Num"] = run
        vid_df_list.append(measured_df)
    vid_df = pd.concat(vid_df_list)
    vid_df["USI"] = usi
    vid_df["UAV_Speed"] = speed
    vid_df["UAV_Height"] = height
    vid_df["Bit_Rate"] = bitrate

    return (dl_df_list, ul_df, vid_df)

# With Filtering of Throughput Above Threshold
# We also normalize by Using Throughput Threshold
# def load_throughput(scenario_path, min_throughput_dl, min_throughput_ul, min_throughput_vid):
#     # print(scenario_path.split("/")[-1])
#     # Load DL Throughput
#     dl_df_list = []
#     dl_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Downlink_Throughput.csv"))
#     for file in dl_throughput_files:
#         measured_df = pd.read_csv(file)
#         dl_df_list.append(measured_df)
#     dl_df = pd.concat(dl_df_list)
#     dl_df = dl_df.loc[dl_df["Throughput"] <= min_throughput_dl]
#     dl_df["Norm_Throughput"] = dl_df["Throughput"] / min_throughput_dl
#     # Load UL Throughput
#     ul_df_list = []
#     ul_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Uplink_Throughput.csv"))
#     for file in ul_throughput_files:
#         measured_df = pd.read_csv(file)
#         ul_df_list.append(measured_df)
#     ul_df = pd.concat(ul_df_list)
#     ul_df = ul_df.loc[ul_df["Throughput"] <= min_throughput_ul]
#     ul_df["Norm_Throughput"] = ul_df["Throughput"] / min_throughput_ul
#     # Load Video Throughput
#     vid_df_list = []
#     vid_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Video_Throughput.csv"))
#     for file in vid_throughput_files:
#         measured_df = pd.read_csv(file)
#         vid_df_list.append(measured_df)
#     vid_df = pd.concat(vid_df_list)
#     vid_df = vid_df.loc[vid_df["Throughput"] <= min_throughput_vid]
#     vid_df["Norm_Throughput"] = vid_df["Throughput"] / min_throughput_vid

#     return (dl_df, ul_df, vid_df)

# max_throughput_dl = []
# max_throughput_ul = []
# max_throughput_vid = []
# min_throughput_dl = []
# min_throughput_ul = []
# min_throughput_vid = []
# for scenario in scenario_paths:
#     scenario_params = scenario.split('_')
#     uav_sending_interval = float([param for param in scenario_params if "UAVSendingInterval-" in param][0].split('-')[-1])
#     max_throughput_dl.append(usi_max_throughput_dl[uav_sending_interval])
#     max_throughput_ul.append(usi_max_throughput_ul[uav_sending_interval])
#     max_throughput_vid.append(usi_max_throughput_vid[uav_sending_interval])
#     min_throughput_dl.append(usi_min_throughput_dl[uav_sending_interval])
#     min_throughput_ul.append(usi_min_throughput_ul[uav_sending_interval])
#     min_throughput_vid.append(usi_min_throughput_vid[uav_sending_interval])

# dl_throughput_df_list = []
# ul_throughput_df_list = []
# vid_throughput_df_list = []
# with Pool(NUM_PROCS) as pool:
#     # for result in pool.starmap(load_throughput, zip(scenario_paths, max_throughput_dl, max_throughput_ul, max_throughput_vid)):
#     # for result in pool.starmap(load_throughput, zip(scenario_paths, min_throughput_dl, min_throughput_ul, min_throughput_vid)):
#     for result in pool.starmap(load_throughput, zip(scenario_paths)):
#         dl_throughput_df_list.append(result[0])
#         ul_throughput_df_list.append(result[1])
#         vid_throughput_df_list.append(result[2])

# uavs_throughput_df = [pd.concat([dl_throughput_df_list[i][j] for i in range(len(dl_throughput_df_list))]) for j in range(len(dl_throughput_df_list[0]))]           
# uav_0_throughput_df = uavs_throughput_df[0]
# uav_1_throughput_df = uavs_throughput_df[1]
# uav_2_throughput_df = uavs_throughput_df[2]
# uav_3_throughput_df = uavs_throughput_df[3]
# uav_4_throughput_df = uavs_throughput_df[4]
# uav_5_throughput_df = uavs_throughput_df[5]
# uav_6_throughput_df = uavs_throughput_df[6]
# uav_7_throughput_df = uavs_throughput_df[7]
# ul_throughput_df = pd.concat(ul_throughput_df_list)
# vid_throughput_df = pd.concat(vid_throughput_df_list)

uav_0_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_UAV_0_processed.csv")
uav_1_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_UAV_1_processed.csv")
uav_2_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_UAV_2_processed.csv")
uav_3_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_UAV_3_processed.csv")
uav_4_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_UAV_4_processed.csv")
uav_5_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_UAV_5_processed.csv")
uav_6_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_UAV_6_processed.csv")
uav_7_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_UAV_7_processed.csv")
ul_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_ul_processed.csv")
vid_throughput_df = pd.read_csv("/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_manet_interference/manet_scenario_a_vid_processed.csv")

# There could be some datapoints with 0 throughput and nan measured reliability
uav_0_throughput_df.dropna(subset=["Measured_Reliability_1", "Throughput"], inplace=True)
uav_1_throughput_df.dropna(subset=["Measured_Reliability_1", "Throughput"], inplace=True)
uav_2_throughput_df.dropna(subset=["Measured_Reliability_1", "Throughput"], inplace=True)
uav_3_throughput_df.dropna(subset=["Measured_Reliability_1", "Throughput"], inplace=True)
uav_4_throughput_df.dropna(subset=["Measured_Reliability_1", "Throughput"], inplace=True)
uav_5_throughput_df.dropna(subset=["Measured_Reliability_1", "Throughput"], inplace=True)
uav_6_throughput_df.dropna(subset=["Measured_Reliability_1", "Throughput"], inplace=True)
uav_7_throughput_df.dropna(subset=["Measured_Reliability_1", "Throughput"], inplace=True)
ul_throughput_df.dropna(subset=["Measured_Reliability", "Throughput"], inplace=True)
vid_throughput_df.dropna(subset=["Measured_Reliability", "Throughput"], inplace=True)

# Filter samples with "Time" < 1
uav_0_throughput_df = uav_0_throughput_df.loc[uav_0_throughput_df["Time"] >= 1]
uav_1_throughput_df = uav_1_throughput_df.loc[uav_1_throughput_df["Time"] >= 1]
uav_2_throughput_df = uav_2_throughput_df.loc[uav_2_throughput_df["Time"] >= 1]
uav_3_throughput_df = uav_3_throughput_df.loc[uav_3_throughput_df["Time"] >= 1]
uav_4_throughput_df = uav_4_throughput_df.loc[uav_4_throughput_df["Time"] >= 1]
uav_5_throughput_df = uav_5_throughput_df.loc[uav_5_throughput_df["Time"] >= 1]
uav_6_throughput_df = uav_6_throughput_df.loc[uav_6_throughput_df["Time"] >= 1]
uav_7_throughput_df = uav_7_throughput_df.loc[uav_7_throughput_df["Time"] >= 1]
ul_throughput_df = ul_throughput_df.loc[ul_throughput_df["Time"] >= 1]
vid_throughput_df = vid_throughput_df.loc[vid_throughput_df["Time"] >= 1]

# %% [markdown]
# ## Calculate Correlation Metrics

# %% [markdown]
# ## Spearman Only, Individual USI and UAVs

# %%
from scipy import stats
# Calculate correlation
# Spearman Rho
spearmanr_uav_0 = stats.spearmanr(uav_0_throughput_df["Throughput"].values, uav_0_throughput_df["Measured_Reliability_1"].values)
spearmanr_uav_1 = stats.spearmanr(uav_1_throughput_df["Throughput"].values, uav_1_throughput_df["Measured_Reliability_1"].values)
spearmanr_uav_2 = stats.spearmanr(uav_2_throughput_df["Throughput"].values, uav_2_throughput_df["Measured_Reliability_1"].values)
spearmanr_uav_3 = stats.spearmanr(uav_3_throughput_df["Throughput"].values, uav_3_throughput_df["Measured_Reliability_1"].values)
spearmanr_uav_4 = stats.spearmanr(uav_4_throughput_df["Throughput"].values, uav_4_throughput_df["Measured_Reliability_1"].values)
spearmanr_uav_5 = stats.spearmanr(uav_5_throughput_df["Throughput"].values, uav_5_throughput_df["Measured_Reliability_1"].values)
spearmanr_uav_6 = stats.spearmanr(uav_6_throughput_df["Throughput"].values, uav_6_throughput_df["Measured_Reliability_1"].values)
spearmanr_uav_7 = stats.spearmanr(uav_7_throughput_df["Throughput"].values, uav_7_throughput_df["Measured_Reliability_1"].values)
ul_nr_usi_10_df = ul_throughput_df.loc[ul_throughput_df["USI"] == 10]
ul_nr_usi_20_df = ul_throughput_df.loc[ul_throughput_df["USI"] == 20]
ul_nr_usi_667_df = ul_throughput_df.loc[ul_throughput_df["USI"] == 66.7]
ul_nr_usi_100_df = ul_throughput_df.loc[ul_throughput_df["USI"] == 100]
spearmanr_ul_usi_10 = stats.spearmanr(ul_nr_usi_10_df["Throughput"].values, ul_nr_usi_10_df["Measured_Reliability_1"].values)
spearmanr_ul_usi_20 = stats.spearmanr(ul_nr_usi_20_df["Throughput"].values, ul_nr_usi_20_df["Measured_Reliability_1"].values)
spearmanr_ul_usi_667 = stats.spearmanr(ul_nr_usi_667_df["Throughput"].values, ul_nr_usi_667_df["Measured_Reliability_1"].values)
spearmanr_ul_usi_100 = stats.spearmanr(ul_nr_usi_100_df["Throughput"].values, ul_nr_usi_100_df["Measured_Reliability_1"].values)
spearmanr_vid = stats.spearmanr(vid_throughput_df["Throughput"].values, vid_throughput_df["Measured_Reliability_1"].values)

print("Spearman Correlation DL - UAV 0: {}, UAV 1: {}, UAV 2: {}, UAV 3: {}, UAV 4: {}, UAV 5: {}, UAV 6: {}, UAV 7: {},".format(
    spearmanr_uav_0.correlation, spearmanr_uav_1.correlation, spearmanr_uav_2.correlation, spearmanr_uav_3.correlation,
    spearmanr_uav_4.correlation, spearmanr_uav_5.correlation, spearmanr_uav_6.correlation, spearmanr_uav_7.correlation))
print("Spearman Correlation UL - USI 10: {}, USI 20: {}, USI 66.7: {}, USI 100: {}".format(spearmanr_ul_usi_10.correlation, spearmanr_ul_usi_20.correlation, 
                                                                                           spearmanr_ul_usi_667.correlation, spearmanr_ul_usi_100.correlation))
print("Spearman Correlation VID: {}".format(spearmanr_vid.correlation))

print("Spearman P Value DL - UAV 0: {}, UAV 1: {}, UAV 2: {}, UAV 3: {}, UAV 4: {}, UAV 5: {}, UAV 6: {}, UAV 7: {},".format(
    spearmanr_uav_0.pvalue, spearmanr_uav_1.pvalue, spearmanr_uav_2.pvalue, spearmanr_uav_3.pvalue,
    spearmanr_uav_4.pvalue, spearmanr_uav_5.pvalue, spearmanr_uav_6.pvalue, spearmanr_uav_7.pvalue))
print("Spearman P Value UL - USI 10: {}, USI 20: {}, USI 66.7: {}, USI 100: {}".format(spearmanr_ul_usi_10.pvalue, spearmanr_ul_usi_20.pvalue, 
                                                                                           spearmanr_ul_usi_667.pvalue, spearmanr_ul_usi_100.pvalue))
print("Spearman P Value VID: {}".format(spearmanr_vid.pvalue))
# Out:
# Spearman Correlation DL - UAV 0: 0.989174922505885, UAV 1: 0.9898918742941415, UAV 2: 0.9905364913247877, UAV 3: 0.9911219093616188, UAV 4: 0.9916666528687854, UAV 5: 0.9921682488470065, UAV 6: 0.9926376141129544, UAV 7: 0.9930735324413178,
# Spearman Correlation UL - USI 10: 0.999850863708958, USI 20: 0.9704314705686229, USI 66.7: 0.3216110711101867, USI 100: 0.22123174956163005
# Spearman Correlation VID: 0.6370394496253271
# Spearman P Value DL - UAV 0: 0.0, UAV 1: 0.0, UAV 2: 0.0, UAV 3: 0.0, UAV 4: 0.0, UAV 5: 0.0, UAV 6: 0.0, UAV 7: 0.0,
# Spearman P Value UL - USI 10: 0.0, USI 20: 0.0, USI 66.7: 0.0, USI 100: 0.0
# Spearman P Value VID: 0.0

# %% [markdown]
# ## With All Data

# %%
from scipy import stats

# Pearson Rho
pearsonr_dl = stats.pearsonr(dl_throughput_df["Norm_Throughput"].values, dl_throughput_df["Measured_Reliability"].values)
pearsonr_ul = stats.pearsonr(ul_throughput_df["Norm_Throughput"].values, ul_throughput_df["Measured_Reliability"].values)
pearsonr_vid = stats.pearsonr(vid_throughput_df["Norm_Throughput"].values, vid_throughput_df["Measured_Reliability"].values)

# Spearman Rho
spearmanr_dl = stats.spearmanr(dl_throughput_df["Norm_Throughput"].values, dl_throughput_df["Measured_Reliability"].values)
spearmanr_ul = stats.spearmanr(ul_throughput_df["Norm_Throughput"].values, ul_throughput_df["Measured_Reliability"].values)
spearmanr_vid = stats.spearmanr(vid_throughput_df["Norm_Throughput"].values, vid_throughput_df["Measured_Reliability"].values)

# Kendall Tau
kd_dl = stats.kendalltau(dl_throughput_df["Norm_Throughput"].values, dl_throughput_df["Measured_Reliability"].values)
kd_ul = stats.kendalltau(ul_throughput_df["Norm_Throughput"].values, ul_throughput_df["Measured_Reliability"].values)
kd_vid = stats.kendalltau(vid_throughput_df["Norm_Throughput"].values, vid_throughput_df["Measured_Reliability"].values)

print("Pearson Correlation - DL: {}, UL: {}, VID: {}".format(pearsonr_dl[0], pearsonr_ul[0], pearsonr_vid[0]))
print("Spearman Correlation - DL: {}, UL: {}, VID: {}".format(spearmanr_dl.correlation, spearmanr_ul.correlation, spearmanr_vid.correlation))
print("Kendall Tau Correlation - DL: {}, UL: {}, VID: {}".format(kd_dl.correlation, kd_ul.correlation, kd_vid.correlation))

print("Pearson P Value - DL: {}, UL: {}, VID: {}".format(pearsonr_dl[1], pearsonr_ul[1], pearsonr_vid[1]))
print("Spearman P Value - DL: {}, UL: {}, VID: {}".format(spearmanr_dl.pvalue, spearmanr_ul.pvalue, spearmanr_vid.pvalue))
print("Kendall Tau P Value - DL: {}, UL: {}, VID: {}".format(kd_dl.pvalue, kd_ul.pvalue, kd_vid.pvalue))
# Out:
# Pearson Correlation - DL: 0.9821231187224563, UL: 0.9770544349316131, VID: 0.6396062532770971
# Spearman Correlation - DL: 0.992794625706806, UL: 0.9796293432343072, VID: 0.6427711106575905
# Kendall Tau Correlation - DL: 0.9776435157427997, UL: 0.9675431744665816, VID: 0.48424221887762764
# Pearson P Value - DL: 0.0, UL: 0.0, VID: 0.0
# Spearman P Value - DL: 0.0, UL: 0.0, VID: 0.0
# Kendall Tau P Value - DL: 0.0, UL: 0.0, VID: 0.0
# /home/research-student/.local/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4868: RuntimeWarning: overflow encountered in long_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))

# %% [markdown]
# ## With Measured Reliability <= 0.90

# %%
from scipy import stats

dl_throughput_df_temp = dl_throughput_df.loc[dl_throughput_df["Measured_Reliability"] <= 0.9]
ul_throughput_df_temp = ul_throughput_df.loc[ul_throughput_df["Measured_Reliability"] <= 0.9]
vid_throughput_df_temp = vid_throughput_df.loc[vid_throughput_df["Measured_Reliability"] <= 0.9]

# Pearson Rho
pearsonr_dl = stats.pearsonr(dl_throughput_df_temp["Norm_Throughput"].values, dl_throughput_df_temp["Measured_Reliability"].values)
pearsonr_ul = stats.pearsonr(ul_throughput_df_temp["Norm_Throughput"].values, ul_throughput_df_temp["Measured_Reliability"].values)
pearsonr_vid = stats.pearsonr(vid_throughput_df_temp["Norm_Throughput"].values, vid_throughput_df_temp["Measured_Reliability"].values)

# Spearman Rho
spearmanr_dl = stats.spearmanr(dl_throughput_df_temp["Norm_Throughput"].values, dl_throughput_df_temp["Measured_Reliability"].values)
spearmanr_ul = stats.spearmanr(ul_throughput_df_temp["Norm_Throughput"].values, ul_throughput_df_temp["Measured_Reliability"].values)
spearmanr_vid = stats.spearmanr(vid_throughput_df_temp["Norm_Throughput"].values, vid_throughput_df_temp["Measured_Reliability"].values)

# Kendall Tau
kd_dl = stats.kendalltau(dl_throughput_df_temp["Norm_Throughput"].values, dl_throughput_df_temp["Measured_Reliability"].values)
kd_ul = stats.kendalltau(ul_throughput_df_temp["Norm_Throughput"].values, ul_throughput_df_temp["Measured_Reliability"].values)
kd_vid = stats.kendalltau(vid_throughput_df_temp["Norm_Throughput"].values, vid_throughput_df_temp["Measured_Reliability"].values)

print("Pearson Correlation - DL: {}, UL: {}, VID: {}".format(pearsonr_dl[0], pearsonr_ul[0], pearsonr_vid[0]))
print("Spearman Correlation - DL: {}, UL: {}, VID: {}".format(spearmanr_dl.correlation, spearmanr_ul.correlation, spearmanr_vid.correlation))
print("Kendall Tau Correlation - DL: {}, UL: {}, VID: {}".format(kd_dl.correlation, kd_ul.correlation, kd_vid.correlation))

print("Pearson P Value - DL: {}, UL: {}, VID: {}".format(pearsonr_dl[1], pearsonr_ul[1], pearsonr_vid[1]))
print("Spearman P Value - DL: {}, UL: {}, VID: {}".format(spearmanr_dl.pvalue, spearmanr_ul.pvalue, spearmanr_vid.pvalue))
print("Kendall Tau P Value - DL: {}, UL: {}, VID: {}".format(kd_dl.pvalue, kd_ul.pvalue, kd_vid.pvalue))

# %% [markdown]
# ## With less datapoints

# %%
from scipy import stats

seed = 10
dl_throughput_sample_df = dl_throughput_df.sample(n=1000, replace=False, random_state=seed)
ul_throughput_sample_df = ul_throughput_df.sample(n=1000, replace=False, random_state=seed)
vid_throughput_sample_df = vid_throughput_df.sample(n=1000, replace=False, random_state=seed)

dl_throughput_sample_df = dl_throughput_sample_df.loc[dl_throughput_sample_df["Measured_Reliability"] <= 0.9]
ul_throughput_sample_df = ul_throughput_sample_df.loc[ul_throughput_sample_df["Measured_Reliability"] <= 0.9]
vid_throughput_sample_df = vid_throughput_sample_df.loc[vid_throughput_sample_df["Measured_Reliability"] <= 0.9]

# Spearman Rho
spearmanr_dl = stats.spearmanr(dl_throughput_sample_df["Norm_Throughput"].values, dl_throughput_sample_df["Measured_Reliability"].values)
spearmanr_ul = stats.spearmanr(ul_throughput_sample_df["Norm_Throughput"].values, ul_throughput_sample_df["Measured_Reliability"].values)
spearmanr_vid = stats.spearmanr(vid_throughput_sample_df["Norm_Throughput"].values, vid_throughput_sample_df["Measured_Reliability"].values)

print("Spearman Correlation - DL: {}, UL: {}, VID: {}".format(spearmanr_dl.correlation, spearmanr_ul.correlation, spearmanr_vid.correlation))
print("Spearman P Value - DL: {}, UL: {}, VID: {}".format(spearmanr_dl.pvalue, spearmanr_ul.pvalue, spearmanr_vid.pvalue))

# %% [markdown]
# ## Plot Correlation

# %%
seed = 1
dl_throughput_sample_df = dl_throughput_df.sample(n=100000, replace=False, random_state=seed)
ul_throughput_sample_df = ul_throughput_df.sample(n=100000, replace=False, random_state=seed)
vid_throughput_sample_df = vid_throughput_df.sample(n=100000, replace=False, random_state=seed)

# %%
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(dl_throughput_sample_df["Norm_Throughput"], dl_throughput_sample_df["Measured_Reliability"], c="k", alpha=0.05, linewidths=1)
plt.ylabel("Time Window Reliability")
plt.xlabel("Normalized Throughput")
plt.xlim((0,1))
plt.ylim((0,1))

plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(ul_throughput_sample_df["Norm_Throughput"], ul_throughput_sample_df["Measured_Reliability"], c="k", alpha=0.05, linewidths=1)
plt.ylabel("Time Window Reliability")
plt.xlabel("Normalized Throughput")
plt.xlim((0,1))
plt.ylim((0,1))

plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(vid_throughput_sample_df["Norm_Throughput"], vid_throughput_sample_df["Measured_Reliability"], c="k", alpha=0.05, linewidths=1)
plt.ylabel("Time Window Reliability")
plt.xlabel("Normalized Throughput")
plt.xlim((0,1))
plt.ylim((0,1))
# Out:
# (0.0, 1.0)

# %%
seed = 1
NUM_SAMPLES = 10000
if (len(uav_0_throughput_df)>NUM_SAMPLES):
    uav_0_sample_df = uav_0_throughput_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    uav_0_sample_df = uav_0_throughput_df
if (len(uav_1_throughput_df)>NUM_SAMPLES):
    uav_1_sample_df = uav_1_throughput_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    uav_1_sample_df = uav_1_throughput_df
if (len(uav_2_throughput_df)>NUM_SAMPLES):
    uav_2_sample_df = uav_2_throughput_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    uav_2_sample_df = uav_2_throughput_df
if (len(uav_3_throughput_df)>NUM_SAMPLES):
    uav_3_sample_df = uav_3_throughput_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    uav_3_sample_df = uav_3_throughput_df
if (len(uav_4_throughput_df)>NUM_SAMPLES):
    uav_4_sample_df = uav_4_throughput_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    uav_4_sample_df = uav_4_throughput_df
if (len(uav_5_throughput_df)>NUM_SAMPLES):
    uav_5_sample_df = uav_5_throughput_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    uav_5_sample_df = uav_5_throughput_df
if (len(uav_6_throughput_df)>NUM_SAMPLES):
    uav_6_sample_df = uav_6_throughput_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    uav_6_sample_df = uav_6_throughput_df
if (len(uav_7_throughput_df)>NUM_SAMPLES):
    uav_7_sample_df = uav_7_throughput_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    uav_7_sample_df = uav_7_throughput_df

if (len(ul_nr_usi_10_df)>NUM_SAMPLES):
    ul_usi_10_sample_df = ul_nr_usi_10_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    ul_usi_10_sample_df = ul_nr_usi_10_df
if (len(ul_nr_usi_20_df)>NUM_SAMPLES):
    ul_usi_20_sample_df = ul_nr_usi_20_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    ul_usi_20_sample_df = ul_nr_usi_20_df
if (len(ul_nr_usi_667_df)>NUM_SAMPLES):
    ul_usi_667_sample_df = ul_nr_usi_667_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    ul_usi_667_sample_df = ul_nr_usi_667_df
if (len(ul_nr_usi_100_df)>NUM_SAMPLES):
    ul_usi_100_sample_df = ul_nr_usi_100_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    ul_usi_100_sample_df = ul_nr_usi_100_df

if (len(vid_throughput_df)>NUM_SAMPLES):
    vid_sample_df = vid_throughput_df.sample(n=NUM_SAMPLES, replace=False, random_state=seed)
else:
    vid_sample_df = vid_throughput_df

# %%
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 16})
plt.scatter(uav_0_sample_df["Throughput"], uav_0_sample_df["Measured_Reliability_1"], c="tab:blue", alpha=0.1, linewidths=1, label="Gateway")
plt.scatter(uav_1_sample_df["Throughput"], uav_1_sample_df["Measured_Reliability_1"], c="tab:orange", alpha=0.1, linewidths=1, label="UAV 1")
plt.scatter(uav_2_sample_df["Throughput"], uav_2_sample_df["Measured_Reliability_1"], c="tab:green", alpha=0.1, linewidths=1, label="UAV 2")
plt.scatter(uav_3_sample_df["Throughput"], uav_3_sample_df["Measured_Reliability_1"], c="tab:red", alpha=0.1, linewidths=1, label="UAV 3")
plt.scatter(uav_4_sample_df["Throughput"], uav_4_sample_df["Measured_Reliability_1"], c="tab:purple", alpha=0.1, linewidths=1, label="UAV 4")
plt.scatter(uav_5_sample_df["Throughput"], uav_5_sample_df["Measured_Reliability_1"], c="tab:brown", alpha=0.1, linewidths=1, label="UAV 5")
plt.scatter(uav_6_sample_df["Throughput"], uav_6_sample_df["Measured_Reliability_1"], c="tab:pink", alpha=0.1, linewidths=1, label="UAV 6")
plt.scatter(uav_7_sample_df["Throughput"], uav_7_sample_df["Measured_Reliability_1"], c="tab:gray", alpha=0.1, linewidths=1, label="UAV 7")
plt.ylabel("Reliability")
plt.xlabel("Throughput (bytes/s)")
plt.xlim(left=0)
plt.ylim((0,1.05))
plt.legend(fontsize=14)

plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 16})
plt.scatter(ul_usi_10_sample_df["Throughput"], ul_usi_10_sample_df["Measured_Reliability_1"], c="tab:blue", alpha=0.1, linewidths=1, label="UAV: 10 ms")
plt.scatter(ul_usi_20_sample_df["Throughput"], ul_usi_20_sample_df["Measured_Reliability_1"], c="tab:orange", alpha=0.1, linewidths=1, label="UAV: 20 ms")
plt.scatter(ul_usi_667_sample_df["Throughput"], ul_usi_667_sample_df["Measured_Reliability_1"], c="tab:green", alpha=0.1, linewidths=1, label="UAV: 66.7 ms")
plt.scatter(ul_usi_100_sample_df["Throughput"], ul_usi_100_sample_df["Measured_Reliability_1"], c="tab:red", alpha=0.1, linewidths=1, label="UAV: 100 ms")
plt.ylabel("Reliability")
plt.xlabel("Throughput (bytes/s)")
plt.xlim(left=0)
plt.ylim((0,1.05))
plt.legend(fontsize=14)

plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(vid_sample_df["Throughput"], vid_sample_df["Measured_Reliability_1"], c="k", alpha=0.1, linewidths=1)
plt.ylabel("Reliability")
plt.xlabel("Throughput (bytes/s)")
plt.xlim(left=0)
plt.ylim((0,1.05))
# Out:
# (0.0, 1.05)

# %% [markdown]
# # For All Runs in No Interference Scenario

# %% [markdown]
# ## Compile throughput data

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import glob, os
from tqdm import tqdm
from multiprocessing.pool import Pool

NUM_PROCS = 32
DATASET_PATH = "/media/research-student/KingstonSSD/FANET_Dataset/DJISpark_Measured_Throughput_100000_Samples/data_manual_throughput_no_int_test_processed" 
scenario_paths = glob.glob(DATASET_PATH + "/*")

# We normalize the throughput with different maximum based on USI
usi_max_throughput_dl = {10:2720, 20: 2720, 66.7: 2720, 100: 2720}
usi_max_throughput_ul = {10:513788, 20: 265043, 66.7: 106570, 100: 77140}
usi_max_throughput_vid = {10:261000, 20: 261000, 66.7: 262450, 100: 261000}

def load_throughput(scenario_path, max_throughput_dl, max_throughput_ul, max_throughput_vid):
    # print(scenario_path.split("/")[-1])
    # Load DL Throughput
    dl_df_list = []
    dl_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Downlink_Throughput.csv"))
    for file in dl_throughput_files:
        measured_df = pd.read_csv(file)
        dl_df_list.append(measured_df)
    dl_df = pd.concat(dl_df_list)
    dl_df["Norm_Throughput"] = dl_df["Throughput"] / max_throughput_dl
    # Load UL Throughput
    ul_df_list = []
    ul_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Uplink_Throughput.csv"))
    for file in ul_throughput_files:
        measured_df = pd.read_csv(file)
        ul_df_list.append(measured_df)
    ul_df = pd.concat(ul_df_list)
    ul_df["Norm_Throughput"] = ul_df["Throughput"] / max_throughput_ul
    # Load Video Throughput
    vid_df_list = []
    vid_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Video_Throughput.csv"))
    for file in vid_throughput_files:
        measured_df = pd.read_csv(file)
        vid_df_list.append(measured_df)
    vid_df = pd.concat(vid_df_list)
    vid_df["Norm_Throughput"] = vid_df["Throughput"] / max_throughput_vid

    return (dl_df, ul_df, vid_df)

def load_mean_throughput(scenario_path, max_throughput_dl, max_throughput_ul, max_throughput_vid):
    # Get the mean throughput from each run
    # Load DL Throughput Mean
    dl_mean_list = []
    dl_rel_list = []
    dl_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Downlink_Throughput.csv"))
    for file in dl_throughput_files:
        measured_df = pd.read_csv(file)
        dl_mean_list.append(measured_df["Throughput"].mean())
        dl_rel_list.append(measured_df["Measured_Reliability"].mean())
    dl_df = pd.DataFrame(data={'Throughput': dl_mean_list, 'Measured_Reliability': dl_rel_list})
    dl_df["Norm_Throughput"] = dl_df["Throughput"] / max_throughput_dl
    # Load UL Throughput Mean
    ul_mean_list = []
    ul_rel_list = []
    ul_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Uplink_Throughput.csv"))
    for file in ul_throughput_files:
        measured_df = pd.read_csv(file)
        ul_mean_list.append(measured_df["Throughput"].mean())
        ul_rel_list.append(measured_df["Measured_Reliability"].mean())
    ul_df = pd.DataFrame(data={'Throughput': ul_mean_list, 'Measured_Reliability': ul_rel_list})
    ul_df["Norm_Throughput"] = ul_df["Throughput"] / max_throughput_ul
    # Load Video Throughput Mean
    vid_mean_list = []
    vid_rel_list = []
    vid_throughput_files = glob.glob(os.path.join(scenario_path, "Run-*_Video_Throughput.csv"))
    for file in vid_throughput_files:
        measured_df = pd.read_csv(file)
        vid_mean_list.append(measured_df["Throughput"].mean())
        vid_rel_list.append(measured_df["Measured_Reliability"].mean())
    vid_df = pd.DataFrame(data={'Throughput': vid_mean_list, 'Measured_Reliability': vid_rel_list})
    vid_df["Norm_Throughput"] = vid_df["Throughput"] / max_throughput_vid

    return (dl_df, ul_df, vid_df)

max_throughput_dl = []
max_throughput_ul = []
max_throughput_vid = []
for scenario in scenario_paths:
    scenario_params = scenario.split('_')
    uav_sending_interval = float([param for param in scenario_params if "UAVSendingInterval-" in param][0].split('-')[-1])
    max_throughput_dl.append(usi_max_throughput_dl[uav_sending_interval])
    max_throughput_ul.append(usi_max_throughput_ul[uav_sending_interval])
    max_throughput_vid.append(usi_max_throughput_vid[uav_sending_interval])

dl_throughput_df_list = []
ul_throughput_df_list = []
vid_throughput_df_list = []
with Pool(NUM_PROCS) as pool:
    for result in pool.starmap(load_mean_throughput, zip(scenario_paths, max_throughput_dl, max_throughput_ul, max_throughput_vid)):
        dl_throughput_df_list.append(result[0])
        ul_throughput_df_list.append(result[1])
        vid_throughput_df_list.append(result[2])

dl_throughput_df = pd.concat(dl_throughput_df_list)
ul_throughput_df = pd.concat(ul_throughput_df_list)
vid_throughput_df = pd.concat(vid_throughput_df_list)

# There could be some datapoints with 0 throughput and nan measured reliability
dl_throughput_df["Measured_Reliability"].fillna(0, inplace=True)
ul_throughput_df["Measured_Reliability"].fillna(0, inplace=True)
vid_throughput_df["Measured_Reliability"].fillna(0, inplace=True)

# %%
ul_throughput_df["Norm_Throughput"].std()
# Out:
# 0.12097571387721633

# %%
len(ul_throughput_df)
# Out:
# 27800

# %% [markdown]
# ## Calculate Correlation Metrics

# %%
from scipy import stats

# Pearson Rho
pearsonr_dl = stats.pearsonr(dl_throughput_df["Norm_Throughput"].values, dl_throughput_df["Measured_Reliability"].values)
pearsonr_ul = stats.pearsonr(ul_throughput_df["Norm_Throughput"].values, ul_throughput_df["Measured_Reliability"].values)
pearsonr_vid = stats.pearsonr(vid_throughput_df["Norm_Throughput"].values, vid_throughput_df["Measured_Reliability"].values)

# Spearman Rho
spearmanr_dl = stats.spearmanr(dl_throughput_df["Norm_Throughput"].values, dl_throughput_df["Measured_Reliability"].values)
spearmanr_ul = stats.spearmanr(ul_throughput_df["Norm_Throughput"].values, ul_throughput_df["Measured_Reliability"].values)
spearmanr_vid = stats.spearmanr(vid_throughput_df["Norm_Throughput"].values, vid_throughput_df["Measured_Reliability"].values)

# Kendall Tau
kd_dl = stats.kendalltau(dl_throughput_df["Norm_Throughput"].values, dl_throughput_df["Measured_Reliability"].values)
kd_ul = stats.kendalltau(ul_throughput_df["Norm_Throughput"].values, ul_throughput_df["Measured_Reliability"].values)
kd_vid = stats.kendalltau(vid_throughput_df["Norm_Throughput"].values, vid_throughput_df["Measured_Reliability"].values)

print("Pearson Correlation - DL: {}, UL: {}, VID: {}".format(pearsonr_dl[0], pearsonr_ul[0], pearsonr_vid[0]))
print("Spearman Correlation - DL: {}, UL: {}, VID: {}".format(spearmanr_dl.correlation, spearmanr_ul.correlation, spearmanr_vid.correlation))
print("Kendall Tau Correlation - DL: {}, UL: {}, VID: {}".format(kd_dl.correlation, kd_ul.correlation, kd_vid.correlation))

print("Pearson P Value - DL: {}, UL: {}, VID: {}".format(pearsonr_dl[1], pearsonr_ul[1], pearsonr_vid[1]))
print("Spearman P Value - DL: {}, UL: {}, VID: {}".format(spearmanr_dl.pvalue, spearmanr_ul.pvalue, spearmanr_vid.pvalue))
print("Kendall Tau P Value - DL: {}, UL: {}, VID: {}".format(kd_dl.pvalue, kd_ul.pvalue, kd_vid.pvalue))
# Out:
# Pearson Correlation - DL: 0.003139432886666505, UL: -0.01035924914103659, VID: 0.02514930603590707
# Spearman Correlation - DL: 0.0069277688639902656, UL: -0.026780440988942257, VID: 0.030400425641470576
# Kendall Tau Correlation - DL: 0.005651938065214166, UL: -0.021854059567569677, VID: 0.024810321379833484
# Pearson P Value - DL: 0.13873184980392098, UL: 0.08413162932180197, VID: 2.7443848526922525e-05
# Spearman P Value - DL: 0.0010865204885493877, UL: 7.977310909589005e-06, VID: 3.984272572523511e-07
# Kendall Tau P Value - DL: 0.0010803603325066473, UL: 8.040429049849256e-06, VID: 3.986030739873562e-07

# %% [markdown]
# ## Plot Correlation

# %%
seed = 1
# dl_throughput_sample_df = dl_throughput_df.sample(n=10000, replace=False, random_state=seed)
# ul_throughput_sample_df = ul_throughput_df.sample(n=10000, replace=False, random_state=seed)
# vid_throughput_sample_df = vid_throughput_df.sample(n=10000, replace=False, random_state=seed)

dl_throughput_sample_df = dl_throughput_df
ul_throughput_sample_df = ul_throughput_df
vid_throughput_sample_df = vid_throughput_df

dl_throughput_sample_df = dl_throughput_sample_df.loc[dl_throughput_sample_df["Measured_Reliability"]>=0.999]
ul_throughput_sample_df = ul_throughput_sample_df.loc[ul_throughput_sample_df["Measured_Reliability"]>=0.999]
vid_throughput_sample_df = vid_throughput_sample_df.loc[vid_throughput_sample_df["Measured_Reliability"]>=0.999]

# %%
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(dl_throughput_sample_df["Norm_Throughput"], dl_throughput_sample_df["Measured_Reliability"], c="k", alpha=0.05, linewidths=1)
plt.ylabel("Measured Reliability")
plt.xlabel("Normalized Throughput")
plt.xlim((0,1))
plt.ylim((0,1))

plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(ul_throughput_sample_df["Norm_Throughput"], ul_throughput_sample_df["Measured_Reliability"], c="k", alpha=0.05, linewidths=1)
plt.ylabel("Measured Reliability")
plt.xlabel("Normalized Throughput")
plt.xlim((0,1))
plt.ylim((0,1))

plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 14})
plt.scatter(vid_throughput_sample_df["Norm_Throughput"], vid_throughput_sample_df["Measured_Reliability"], c="k", alpha=0.05, linewidths=1)
plt.ylabel("Measured Reliability")
plt.xlabel("Normalized Throughput")
plt.xlim((0,1))
plt.ylim((0,1))
# Out:
# (0.0, 1.0)
