# %%
import os

root = "/media/research-student/KingstonSSD/FANET_Dataset/PM_Finetune"
# dir_list = ["Manual_UAV_Interference", "Manual_MANET_Interference", "Waypoint_Only_UAV_Interference", "Waypoint_Only_MANET_Interference",
#             "Fixed_Prob_UAV_Interference", "Fixed_Prob_MANET_Interference"]
dir_list = ["PM_RL_500", "PM_RL_850"]

subdir_list = ["{}_scenario_0", "{}_scenario_1", "{}_scenario_2", "{}_scenario_0_processed", "{}_scenario_1_processed", "{}_scenario_2_processed"]

for direc in  dir_list:
    os.mkdir(os.path.join(root, direc))
    # if "UAV" in direc:
    #     subdirs = [sub.format("uav") for sub in subdir_list]
    # elif "MANET" in direc:
    #     subdirs = [sub.format("manet") for sub in subdir_list]
    # for subdir in subdirs:
    #     os.mkdir(os.path.join(root, direc, subdir))
    
    subdirs = [sub.format("uav") for sub in subdir_list]
    for subdir in subdirs:
        os.mkdir(os.path.join(root, direc, subdir))
    subdirs = [sub.format("manet") for sub in subdir_list]
    for subdir in subdirs:
        os.mkdir(os.path.join(root, direc, subdir))
