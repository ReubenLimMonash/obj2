# %% [markdown]
# ## Plot Sensitivity and Specificity of Detection

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Box Plots

# 500 runs ---------------------------------------------------------------------------------------------------------------------------
""" FOR ALL USI AGGREGATED 500 runs """
# dl_sensitivity_gamma = [0.813283648339704,0.969646841788508,0.99897896250154,0.851717440425474,0.966399652287089,0.987723174128837]
# dl_specificity_gamma = [0.999834300075629,0.995849367708066,0.954843004548984,0.990165750287417,0.97801319132005,0.97266460396727]
# dl_accuracy_gamma = [0.949231224952082,0.971836208398675,0.998955857582621,0.87718441075681,0.966752279723529,0.987565719927978]
# dl_sensitivity_th = [0.663646896518646,0.88656085043728,0.988205593135327,0.475597271944419,0.785249839585313,0.909003574988684]
# dl_specificity_th = [0.99999976089477,0.999992353549621,1,0.999990843048911,0.999977045266734,0.999938896696533]
# dl_accuracy_th = [0.90876186327467,0.896038682697334,0.988211767439159,0.572057210896207,0.791769704361967,0.909954405529418]

""" FOR USI 10 ms 500 runs """
# dl_sensitivity_gamma = [0.958610797377521,1,1,0.957888883042516,0.990676925919571,0.997959837417159]
# dl_specificity_gamma = [0.998048771951315,0.984533115917701,0.978700602813128,0.983379501385041] # No Negative Cases for UAV 2 and UAV 3
# dl_accuracy_gamma = [0.962550699300699,1,1,0.958860139860139,0.990598776223776,0.997941433566433]
# dl_sensitivity_th = [0.933755327940892,1,1,0.86823163971993,0.96382865463888,0.991801714751837]
# dl_specificity_th = [1,0.999976020334756,1,0.999307479224376] # No Negative Cases for UAV 2 and UAV 3
# dl_accuracy_th = [0.940373251748251,1,1,0.87303409090909,0.964064685314685,0.991811188811188]

""" FOR USI 20 ms 500 runs """
# dl_sensitivity_gamma = [0.854462260586215,0.995809111012678,0.999814863391024,0.93260031758178,0.982837807877872,0.993914446638999]
# dl_specificity_gamma = [0.999295654093535,0.96692607003891,0.953974895397489,0.984173816710188,0.973827851644506,0.967026294895147]
# dl_accuracy_gamma = [0.906730109204368,0.995734997399896,0.99981258450338,0.936396255850234,0.982703900156006,0.993794695787831]
# dl_sensitivity_th = [0.687748673173516,0.976614772716845,0.99775443854619,0.696232264009613,0.883233285121567,0.949013066827633]
# dl_specificity_th = [0.999998847224375,1,1,0.999968912854252,0.99997200839748,0.999953295035262]
# dl_accuracy_th = [0.800434321372854,0.976674778991159,0.997754550182007,0.71858803952158,0.884968278731149,0.949239937597503]

""" FOR USI 66.7 ms 500 runs """
# dl_sensitivity_gamma = [0.352974937822842,0.965717987940366,0.998623373536085,0.810254843747318,0.960050015434937,0.984864045427207]
# dl_specificity_gamma = [0.999937070192247,0.996022740210551,0.953190376569037,0.990488472818381,0.978505032030858,0.973490665158005]
# dl_accuracy_gamma = [0.9580958020327,0.968540874944763,0.998592664604507,0.851260980998674,0.960720636323464,0.984714803358373]
# dl_sensitivity_th = [0.0608324906392631,0.86616578020405,0.984605944875511,0.336154404992763,0.742249561025965,0.888469142232623]
# dl_specificity_th = [1,0.999992409809562,1,0.999993007943752,0.999975678922868,0.999973059619063]
# dl_accuracy_th = [0.939260804242156,0.878631727794962,0.984616349977905,0.487188687582854,0.751614847547503,0.889932302253645]

""" FOR USI 100 ms 500 runs """
# dl_sensitivity_gamma = [0.280051271138209,0.939910880920565,0.998412114830315,0.779925106602569,0.953209751700737,0.983132340404737]
# dl_specificity_gamma = [0.999944320475802,0.996144539190698,0.956161616161616,0.991472587234684,0.978822344399211,0.973194260219462]
# dl_accuracy_gamma = [0.974005706134094,0.948927960057061,0.998374821683309,0.83591547788873,0.954297967189728,0.982985378031383]
# dl_sensitivity_th = [0.0122437061708477,0.789515957080808,0.981237004845575,0.280137778243375,0.704690552411387,0.87797385372493]
# dl_specificity_th = [0.999999815018192,0.999992215683396,1,0.999994610152317,0.999979015402694,0.999915591462679]
# dl_accuracy_th = [0.964409771754636,0.823265870185449,0.981253566333808,0.470662624821683,0.717236626248216,0.879777104136947]

""" AVERAGE OVER ALL USI 500 runs """
# dl_sensitivity_gamma = [0.611524816731197,0.975359494968402,0.999212587939356,0.870167287743546,0.971693625,0.989967667472025]
# dl_specificity_gamma = [0.999306454178225,0.986364449813386,0.954442296042714,0.987666998170239,0.977463958,0.974272680414414]
# dl_accuracy_gamma = [0.950345579167965,0.97830095810043,0.999195017697799,0.895608213649444,0.97208032,0.989859077686005]
# dl_sensitivity_th = [0.42364504948113,0.908074127500426,0.990899347066819,0.54518902174142,0.823500513,0.926814444384256]
# dl_specificity_th = [0.999999665560642,0.999994875164319,1,0.999983137821269,0.999981676,0.999787356335345]
# dl_accuracy_th = [0.911119537279474,0.919643094242893,0.99090611662343,0.637368360708802,0.829471109,0.927690133199821]

# 100 runs ---------------------------------------------------------------------------------------------------------------------------
""" FOR ALL USI AGGREGATED 100 runs """
# dl_sensitivity_gamma = [0.812129528934891,0.969878512132468,0.999058967223064,0.840155997067342,0.965302189578041,0.988381043817558]
# dl_specificity_gamma = [0.999844000464814,0.995727908101319,0.957550452331245,0.991254250094446,0.979044536241566,0.973049304449719]
# dl_accuracy_gamma = [0.94911453795667,0.972036359412208,0.999041644885868,0.87035546262415,0.965726317012255,0.988232851251669]
# dl_sensitivity_th = [0.665643281766483,0.887844020490799,0.98871022146374,0.455417068939234,0.777013580843641,0.911669306361042]
# dl_specificity_th = [1,1,1,0.999997093952515,0.999990590272223,1]
# dl_accuracy_th = [0.909640762037521,0.897206540047627,0.988714932915142,0.564260324098275,0.783895277922983,0.912523087645931]

""" FOR USI 10 ms 100 runs """
# dl_sensitivity_gamma = [0.958192161697748,1,1,0.953280318091451,0.990437254660353,0.998341596180857]
# dl_specificity_gamma = [0.998244536118669,0.983775811209439,0.981457800511509,0.97752808988764] # No Negative Cases for UAV 2 and UAV 3
# dl_accuracy_gamma = [0.962180944055944,1,1,0.954545454545454,0.990375874125874,0.998317307692307]
# dl_sensitivity_th = [0.933256963119011,1,1,0.849968993379174,0.960217571159499,0.991528575741796]
# dl_specificity_th = [1,0.999894648124736,1,1] # No Negative Cases for UAV 2 and UAV 3
# dl_accuracy_th = [0.939903846153846,1,1,0.856188811188811,0.96048951048951,0.991538461538461]

""" FOR USI 20 ms 100 runs """
# dl_sensitivity_gamma = [0.853731108776133,0.996024406163265,0.999841904304259,0.926977417094287,0.982523240764395,0.994372677254401]
# dl_specificity_gamma = [0.999326680018944,0.96580483736447,0.947368421052631,0.985135487232933,0.975354585030192,0.967281225655673]
# dl_accuracy_gamma = [0.906806032241289,0.995949037961518,0.999838793551742,0.931620384815392,0.982417056682267,0.994264170566822]
# dl_sensitivity_th = [0.691128285198969,0.977124435148712,0.997891710689037,0.675370165246287,0.881651039104446,0.951538611746057]
# dl_specificity_th = [1,1,1,1,0.999929785142536,1]
# dl_accuracy_th = [0.803723348933957,0.97718148725949,0.997891835673427,0.701286531461258,0.883403016120644,0.951732709308372]

""" FOR USI 66.7 ms 100 runs """
# dl_sensitivity_gamma = [0.34640899122807,0.966031683897183,0.998676311817431,0.793575768248657,0.959296184022988,0.98603054063436]
# dl_specificity_gamma = [0.999941428760368,0.995762509206737,0.949033391915641,0.99160961658772,0.979163185908298,0.973359465737514]
# dl_accuracy_gamma = [0.957801148917366,0.968778612461334,0.998651347768449,0.842532920901458,0.960031816173221,0.985876270437472]
# dl_sensitivity_th = [0.0603207236842105,0.866904846064635,0.985113150139133,0.309545361157582,0.73213638361862,0.891551044801757]
# dl_specificity_th = [1,1,1,1,1,1]
# dl_accuracy_th = [0.939408749447635,0.879201944321696,0.985120636323464,0.480236853733981,0.742054794520547,0.89287140963323]

""" FOR USI 100 ms 100 runs """
# dl_sensitivity_gamma = [0.281822660098522,0.940106939370562,0.998581356526518,0.762659237362029,0.95087555799931,0.983511283109641]
# dl_specificity_gamma = [0.999950046253469,0.996105392618527,0.964241676942046,0.992623579100244,0.979946469013794,0.974137370849308]
# dl_accuracy_gamma = [0.973955064194008,0.949119115549215,0.99855652639087,0.828729493580599,0.952134450784593,0.983382667617689]
# dl_sensitivity_th = [0.0119704433497536,0.792437312319492,0.982158996920919,0.2591595494879,0.691414033158439,0.880983826774458]
# dl_specificity_th = [1,1,1,0.99999689675183,1,1]
# dl_accuracy_th = [0.964235021398002,0.825841654778887,0.982171897289586,0.472006954350927,0.704777104136947,0.882616797432239]

""" AVERAGE OVER ALL USI 100 runs """
# dl_sensitivity_gamma = [0.610038730450118,0.975540757357752,0.999274893162052,0.859123185199106,0.970783059361761,0.990564024294815]
# dl_specificity_gamma = [0.999365672787862,0.985890913063245,0.953547829970106,0.988286123532584,0.978980510115948,0.973076538032534]
# dl_accuracy_gamma = [0.950185797352152,0.978461691493017,0.999261666927765,0.889357063460726,0.971239799441489,0.990460104078573]
# dl_sensitivity_th = [0.424169103837986,0.90911664838321,0.991290964437272,0.523511017317736,0.816354756760251,0.928900514766017]
# dl_specificity_th = [1,1,1,0.999972886219141,0.999982446285634,1]
# dl_accuracy_th = [0.91181774148336,0.920556271590018,0.991296092321619,0.627429787683744,0.822681106316912,0.929689844478075]

dl_sensitivity_gamma = [0.471897378540356,0.965010716206148,0.999211857827433,0.870505038159645,0.97482201153503,0.990969164191584]
dl_specificity_gamma = [0.999670362418208,0.984878408974649,0.903636363636363,0.974875898757101,0.945398077810886,0.934836609188472]
dl_sensitivity_th = [0.533041675121125,0.948654803943971,0.997837963252157,0.807727619280418,0.948825732392503,0.980865219807169]
dl_specificity_th = [0.58870774853647,0.573554007588596,0.549898989898989,0.578373775157114,0.565136190036513,0.561738815868805]

dl_youden_gamma = np.array(dl_sensitivity_gamma) + np.array(dl_specificity_gamma) - 1
dl_youden_th = np.array(dl_sensitivity_th) + np.array(dl_specificity_th) - 1
'''For USI 10 ms, where UAV 2 and UAV 3 have no specificity'''
# dl_youden_gamma = np.delete(dl_sensitivity_gamma, [1,2]) + np.array(dl_specificity_gamma) - 1
# dl_youden_th = np.delete(dl_sensitivity_th, [1,2]) + np.array(dl_specificity_th) - 1

# PLOT SENSITIVITY
ind = np.arange(len(dl_sensitivity_th), dtype=float)  
width = 0.2
plt.figure(figsize=(14,5))
plt.rcParams.update({'font.size': 14})
bar_th = plt.bar(ind, np.array(dl_sensitivity_th)*100, width, edgecolor='black', color = '0.9') 
plt.bar_label(bar_th, fmt='%.1f', padding=3, fontsize=11)
bar_gamma = plt.bar(ind + width, np.array(dl_sensitivity_gamma)*100, width, edgecolor='black', color = '0.6') 
plt.bar_label(bar_gamma, fmt='%.1f', padding=3, fontsize=11)
plt.ylabel('Sensitivity (%)') 
plt.xlabel('Interference Scenario') 
# plt.title("Uplink")
# plt.ylim(0.95, 1.0)
plt.xticks(ind+0.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3']) 
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_th, bar_gamma), ('$\\tau$', '$\gamma$'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

# PLOT SPECIFICITY
ind = np.arange(len(dl_specificity_th), dtype=float)  
width = 0.2
plt.figure(figsize=(14,5))
plt.rcParams.update({'font.size': 14})
bar_th = plt.bar(ind, np.array(dl_specificity_th)*100, width, edgecolor='black', color = '0.9') 
plt.bar_label(bar_th, fmt='%.1f', padding=3, fontsize=11)
bar_gamma = plt.bar(ind + width, np.array(dl_specificity_gamma)*100, width, edgecolor='black', color = '0.6') 
plt.bar_label(bar_gamma, fmt='%.1f', padding=3, fontsize=11)
plt.ylabel('Specificity (%)') 
plt.xlabel('Interference Scenario') 
# plt.title("Uplink")
# plt.ylim(0.95, 1.0)
plt.xticks(ind+0.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3'])
# plt.xticks(ind+0.5*width,['UAV 1', 'MANET 1', 'MANET 2', 'MANET 3']) # For USI 10 ms, No Negative Cases for UAV 2 and UAV 3
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_th, bar_gamma), ('$\\tau$', '$\gamma$'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

# # PLOT ACCURACY
# ind = np.arange(len(dl_accuracy_th), dtype=float)  
# width = 0.2
# plt.figure(figsize=(14,5))
# plt.rcParams.update({'font.size': 14})
# bar_th = plt.bar(ind, np.array(dl_accuracy_th)*100, width, edgecolor='black', color = '0.9') 
# plt.bar_label(bar_th, fmt='%.1f', padding=3, fontsize=11)
# bar_gamma = plt.bar(ind + width, np.array(dl_accuracy_gamma)*100, width, edgecolor='black', color = '0.6') 
# plt.bar_label(bar_gamma, fmt='%.1f', padding=3, fontsize=11)
# plt.ylabel('Accuracy (%)') 
# plt.xlabel('Interference Scenario') 
# # plt.title("Uplink")
# # plt.ylim(0.95, 1.0)
# plt.xticks(ind+0.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3'])
# plt.tick_params(axis='x', which='both',length=0)
# plt.legend( (bar_th, bar_gamma), ('$\\tau$', '$\gamma$'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

# PLOT YOUDEN J STATISTICS
ind = np.arange(len(dl_youden_gamma), dtype=float)  
width = 0.2
plt.figure(figsize=(14,5))
plt.rcParams.update({'font.size': 14})
bar_th = plt.bar(ind, dl_youden_th, width, edgecolor='black', color = '0.9') 
plt.bar_label(bar_th, fmt='%.3f', padding=3, fontsize=11)
bar_gamma = plt.bar(ind + width, dl_youden_gamma, width, edgecolor='black', color = '0.6') 
plt.bar_label(bar_gamma, fmt='%.3f', padding=3, fontsize=11)
plt.ylabel('Youden J') 
plt.xlabel('Interference Scenario') 
# plt.title("Uplink")
plt.ylim(0, 1.0)
plt.xticks(ind+0.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3'])
# plt.xticks(ind+0.5*width,['UAV 1', 'MANET 1', 'MANET 2', 'MANET 3']) # For USI 10 ms, No Negative Cases for UAV 2 and UAV 3
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_th, bar_gamma), ('$\\tau$', '$\gamma$'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3)

# %% [markdown]
# ### Line Plot

# %%
# Line Plot

SCENARIO = "uav_scenario_2_{}_processed.csv"

gamma_results_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/num_reliable_failure_detection_overall_results_500_runs.csv")
th_results_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/throughput_failure_detection_overall_results_500_runs.csv")

gamma_results_df = gamma_results_df.loc[gamma_results_df["Scenario"]==SCENARIO]
th_results_df = th_results_df.loc[th_results_df["Scenario"]==SCENARIO]

gamma_sens = [gamma_results_df["Overall_USI_10_Sensitivity"].values[0], gamma_results_df["Overall_USI_20_Sensitivity"].values[0], gamma_results_df["Overall_USI_667_Sensitivity"].values[0], gamma_results_df["Overall_USI_100_Sensitivity"].values[0]]
gamma_spec = [gamma_results_df["Overall_USI_10_Specificity"].values[0], gamma_results_df["Overall_USI_20_Specificity"].values[0], gamma_results_df["Overall_USI_667_Specificity"].values[0], gamma_results_df["Overall_USI_100_Specificity"].values[0]]
th_sens = [th_results_df["Overall_USI_10_Sensitivity"].values[0], th_results_df["Overall_USI_20_Sensitivity"].values[0], th_results_df["Overall_USI_667_Sensitivity"].values[0], th_results_df["Overall_USI_100_Sensitivity"].values[0]]
th_spec = [th_results_df["Overall_USI_10_Specificity"].values[0], th_results_df["Overall_USI_20_Specificity"].values[0], th_results_df["Overall_USI_667_Specificity"].values[0], th_results_df["Overall_USI_100_Specificity"].values[0]]

plt.figure(figsize=(6,3))
plt.rcParams.update({'font.size': 16})
plt.plot(['10', '20', '66.7', '100'], gamma_sens, '-o', color='tab:blue')
plt.plot(['10', '20', '66.7', '100'], th_sens, '-o', color='tab:orange')
plt.xlabel("USI (ms)")
plt.ylabel("Sensitivity")
plt.ylim(0, 1.05)
# plt.legend(['$\gamma$','$\\tau$'], bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=2, fontsize=14)

plt.figure(figsize=(6,3))
plt.rcParams.update({'font.size': 16})
plt.plot(['10', '20', '66.7', '100'], gamma_spec, '-o', color='tab:blue')
plt.plot(['10', '20', '66.7', '100'], th_spec, '-o', color='tab:orange')
plt.xticks(ticks=[0,1,2,3], labels=['10', '20', '66.7', '100'])
plt.xlabel("USI (ms)")
plt.ylabel("Specificity")
plt.ylim(0, 1.05)
plt.xlim([-0.15,3.15])
# plt.legend(['$\gamma$','$\\tau$'], bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=2, fontsize=14)

# Youden J
if (SCENARIO == "uav_scenario_1_{}_processed.csv") or (SCENARIO == "uav_scenario_2_{}_processed.csv"):
    gamma_yj = np.array(gamma_sens[1:]) + np.array(gamma_spec[1:]) - 1
    th_yj = np.array(th_sens[1:]) + np.array(th_spec[1:]) - 1
    usi = ['20', '66.7', '100']
else:
    gamma_yj = np.array(gamma_sens) + np.array(gamma_spec) - 1
    th_yj = np.array(th_sens) + np.array(th_spec) - 1
    usi = ['10','20', '66.7', '100']
plt.figure(figsize=(6,3))
plt.rcParams.update({'font.size': 12})
plt.plot(usi, gamma_yj, '-o', color='tab:blue')
plt.plot(usi, th_yj, '-o', color='tab:orange')
plt.xlabel("USI (ms)")
plt.ylabel("Youden J")
plt.ylim(0, 1.05)
plt.legend(['$\gamma$','$\\tau$'], bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=2, fontsize=10)

# %%
# Plot average accuracy (averaged over all scenarios) vs USI 

avg_acc_gamma = [0.984954691142191,0.969147616571329,0.95353949035204,0.948723965763195]
avg_acc_th = [0.96095134032634,0.887682440630958,0.820280777728678,0.804024340228245]

plt.figure(figsize=(10,4))
plt.rcParams.update({'font.size': 14})
plt.plot(['10', '20', '66.7', '100'], np.array(avg_acc_gamma)*100, '-o', color='tab:orange')
plt.plot(['10', '20', '66.7', '100'], np.array(avg_acc_th)*100, '-o', color='tab:blue')
plt.xlabel("USI (ms)")
plt.ylabel("Accuracy (%)")
plt.ylim(70,100)
plt.legend(['$\gamma$','$\\tau$'])

# %% [markdown]
# ### Load FN Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

''' Load the data of a USI '''
USI = 10
# Load FN Cases for Gamma Thresholding
gamma_uav_0_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/num_reliable_failure_detection_uav_0_fn_500_runs.csv")
gamma_uav_1_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/num_reliable_failure_detection_uav_1_fn_500_runs.csv")
gamma_uav_2_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/num_reliable_failure_detection_uav_2_fn_500_runs.csv")
gamma_manet_1_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/num_reliable_failure_detection_manet_1_fn_500_runs.csv")
gamma_manet_a_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/num_reliable_failure_detection_manet_a_fn_500_runs.csv")
gamma_manet_2_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/num_reliable_failure_detection_manet_2_fn_500_runs.csv")

gamma_uav_0_fn_df = gamma_uav_0_fn_df.loc[gamma_uav_0_fn_df["USI"]==USI]
gamma_uav_1_fn_df = gamma_uav_1_fn_df.loc[gamma_uav_1_fn_df["USI"]==USI]
gamma_uav_2_fn_df = gamma_uav_2_fn_df.loc[gamma_uav_2_fn_df["USI"]==USI]
gamma_manet_1_fn_df = gamma_manet_1_fn_df.loc[gamma_manet_1_fn_df["USI"]==USI]
gamma_manet_a_fn_df = gamma_manet_a_fn_df.loc[gamma_manet_a_fn_df["USI"]==USI]
gamma_manet_2_fn_df = gamma_manet_2_fn_df.loc[gamma_manet_2_fn_df["USI"]==USI]

# Load FN Cases for Throughput Thresholding
throughput_uav_0_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/throughput_failure_detection_uav_0_fn_500_runs.csv")
throughput_uav_1_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/throughput_failure_detection_uav_1_fn_500_runs.csv")
throughput_uav_2_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/throughput_failure_detection_uav_2_fn_500_runs.csv")
throughput_manet_1_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/throughput_failure_detection_manet_1_fn_500_runs.csv")
throughput_manet_a_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/throughput_failure_detection_manet_a_fn_500_runs.csv")
throughput_manet_2_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/throughput_failure_detection_manet_2_fn_500_runs.csv")

throughput_uav_0_fn_df = throughput_uav_0_fn_df.loc[throughput_uav_0_fn_df["USI"]==USI]
throughput_uav_1_fn_df = throughput_uav_1_fn_df.loc[throughput_uav_1_fn_df["USI"]==USI]
throughput_uav_2_fn_df = throughput_uav_2_fn_df.loc[throughput_uav_2_fn_df["USI"]==USI]
throughput_manet_1_fn_df = throughput_manet_1_fn_df.loc[throughput_manet_1_fn_df["USI"]==USI]
throughput_manet_a_fn_df = throughput_manet_a_fn_df.loc[throughput_manet_a_fn_df["USI"]==USI]
throughput_manet_2_fn_df = throughput_manet_2_fn_df.loc[throughput_manet_2_fn_df["USI"]==USI]

# Load Conf Matrix For Data On Number of TP, TN, FP, FN
conf_mat_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/num_reliable_failure_detection_conf_matrix_500_runs.csv")

# %% [markdown]
# ### Get percentage of time window with at least one link reliability below 90%

# %%
# Run "Load FN Data" first!

RELIABILITY = 0.9

gamma_uav_0_fn_df["Below_90"] = (gamma_uav_0_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_0_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_0_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_0_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_0_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_0_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_0_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_0_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_0_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
gamma_uav_1_fn_df["Below_90"] = (gamma_uav_1_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_1_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_1_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_1_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_1_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_1_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_1_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_1_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_1_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
gamma_uav_2_fn_df["Below_90"] = (gamma_uav_2_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_2_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_2_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_2_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_2_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_2_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_2_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (gamma_uav_2_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                (gamma_uav_2_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
gamma_manet_1_fn_df["Below_90"] = (gamma_manet_1_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_1_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_1_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_1_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_1_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_1_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_1_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_1_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_1_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
gamma_manet_a_fn_df["Below_90"] = (gamma_manet_a_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_a_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_a_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_a_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_a_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_a_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_a_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_a_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_a_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
gamma_manet_2_fn_df["Below_90"] = (gamma_manet_2_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_2_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_2_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_2_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_2_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_2_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_2_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (gamma_manet_2_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                  (gamma_manet_2_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)

throughput_uav_0_fn_df["Below_90"] = (throughput_uav_0_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_0_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_0_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_0_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_0_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_0_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_0_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_0_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_0_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
throughput_uav_1_fn_df["Below_90"] = (throughput_uav_1_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_1_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_1_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_1_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_1_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_1_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_1_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_1_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_1_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
throughput_uav_2_fn_df["Below_90"] = (throughput_uav_2_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_2_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_2_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_2_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_2_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_2_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_2_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (throughput_uav_2_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                (throughput_uav_2_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
throughput_manet_1_fn_df["Below_90"] = (throughput_manet_1_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_1_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_1_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_1_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_1_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_1_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_1_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_1_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_1_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
throughput_manet_a_fn_df["Below_90"] = (throughput_manet_a_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_a_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_a_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_a_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_a_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_a_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_a_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_a_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_a_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)
throughput_manet_2_fn_df["Below_90"] = (throughput_manet_2_fn_df["UAV_0_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_2_fn_df["UAV_7_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_2_fn_df["UAV_1_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_2_fn_df["UAV_2_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_2_fn_df["UAV_3_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_2_fn_df["UAV_4_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_2_fn_df["UAV_5_Measured_Reliability_1"] < RELIABILITY) | (throughput_manet_2_fn_df["UAV_6_Measured_Reliability_1"] < RELIABILITY) | \
                                  (throughput_manet_2_fn_df["UL_Measured_Reliability_1"] < RELIABILITY)

# Count the number of positive GT labels for each scenario (for the given USI)
usi_dict = {10: "10", 20: "20", 66.7: "667", 100: "100"}
tmp_conf_mat = conf_mat_df.loc[conf_mat_df["Scenario"]=="uav_scenario_0_{}_processed.csv"]
uav_0_num_pos = tmp_conf_mat["Overall_USI_{}_TP".format(usi_dict[USI])].values[0] + tmp_conf_mat["Overall_USI_{}_FN".format(usi_dict[USI])].values[0]
tmp_conf_mat = conf_mat_df.loc[conf_mat_df["Scenario"]=="uav_scenario_1_{}_processed.csv"]
uav_1_num_pos = tmp_conf_mat["Overall_USI_{}_TP".format(usi_dict[USI])].values[0] + tmp_conf_mat["Overall_USI_{}_FN".format(usi_dict[USI])].values[0]
tmp_conf_mat = conf_mat_df.loc[conf_mat_df["Scenario"]=="uav_scenario_2_{}_processed.csv"]
uav_2_num_pos = tmp_conf_mat["Overall_USI_{}_TP".format(usi_dict[USI])].values[0] + tmp_conf_mat["Overall_USI_{}_FN".format(usi_dict[USI])].values[0]
tmp_conf_mat = conf_mat_df.loc[conf_mat_df["Scenario"]=="manet_scenario_1_{}_processed.csv"]
manet_1_num_pos = tmp_conf_mat["Overall_USI_{}_TP".format(usi_dict[USI])].values[0] + tmp_conf_mat["Overall_USI_{}_FN".format(usi_dict[USI])].values[0]
tmp_conf_mat = conf_mat_df.loc[conf_mat_df["Scenario"]=="manet_scenario_a_{}_processed.csv"]
manet_a_num_pos = tmp_conf_mat["Overall_USI_{}_TP".format(usi_dict[USI])].values[0] + tmp_conf_mat["Overall_USI_{}_FN".format(usi_dict[USI])].values[0]
tmp_conf_mat = conf_mat_df.loc[conf_mat_df["Scenario"]=="manet_scenario_2_{}_processed.csv"]
manet_2_num_pos = tmp_conf_mat["Overall_USI_{}_TP".format(usi_dict[USI])].values[0] + tmp_conf_mat["Overall_USI_{}_FN".format(usi_dict[USI])].values[0]

''' For USI 20, 66.7, 100'''
# Calc the percentage of FN where at least one link reliability is below 90 %
percent_gamma_uav_0 = len(gamma_uav_0_fn_df.loc[gamma_uav_0_fn_df["Below_90"]==True]) / uav_0_num_pos * 100
percent_gamma_uav_1 = len(gamma_uav_1_fn_df.loc[gamma_uav_1_fn_df["Below_90"]==True]) / uav_1_num_pos * 100
percent_gamma_uav_2 = len(gamma_uav_2_fn_df.loc[gamma_uav_2_fn_df["Below_90"]==True]) / uav_2_num_pos * 100
percent_gamma_manet_1 = len(gamma_manet_1_fn_df.loc[gamma_manet_1_fn_df["Below_90"]==True]) / manet_1_num_pos * 100
percent_gamma_manet_a = len(gamma_manet_a_fn_df.loc[gamma_manet_a_fn_df["Below_90"]==True]) / manet_a_num_pos * 100
percent_gamma_manet_2 = len(gamma_manet_2_fn_df.loc[gamma_manet_2_fn_df["Below_90"]==True]) / manet_2_num_pos * 100
percent_throughput_uav_0 = len(throughput_uav_0_fn_df.loc[throughput_uav_0_fn_df["Below_90"]==True]) / uav_0_num_pos * 100
percent_throughput_uav_1 = len(throughput_uav_1_fn_df.loc[throughput_uav_1_fn_df["Below_90"]==True]) / uav_1_num_pos * 100
percent_throughput_uav_2 = len(throughput_uav_2_fn_df.loc[throughput_uav_2_fn_df["Below_90"]==True]) / uav_2_num_pos * 100
percent_throughput_manet_1 = len(throughput_manet_1_fn_df.loc[throughput_manet_1_fn_df["Below_90"]==True]) / manet_1_num_pos * 100
percent_throughput_manet_a = len(throughput_manet_a_fn_df.loc[throughput_manet_a_fn_df["Below_90"]==True]) / manet_a_num_pos * 100
percent_throughput_manet_2 = len(throughput_manet_2_fn_df.loc[throughput_manet_2_fn_df["Below_90"]==True]) / manet_2_num_pos * 100
print([percent_gamma_uav_0, percent_gamma_uav_1, percent_gamma_uav_2, percent_gamma_manet_1, percent_gamma_manet_a, percent_gamma_manet_2])
print([percent_throughput_uav_0, percent_throughput_uav_1, percent_throughput_uav_2, percent_throughput_manet_1, percent_throughput_manet_a, percent_throughput_manet_2])

''' For USI 10'''
# # Calc the percentage of FN where at least one link reliability is below 90 %
# percent_gamma_uav_0 = len(gamma_uav_0_fn_df.loc[gamma_uav_0_fn_df["Below_90"]==True]) / uav_0_num_pos * 100
# percent_gamma_manet_1 = len(gamma_manet_1_fn_df.loc[gamma_manet_1_fn_df["Below_90"]==True]) / manet_1_num_pos * 100
# percent_gamma_manet_a = len(gamma_manet_a_fn_df.loc[gamma_manet_a_fn_df["Below_90"]==True]) / manet_a_num_pos * 100
# percent_gamma_manet_2 = len(gamma_manet_2_fn_df.loc[gamma_manet_2_fn_df["Below_90"]==True]) / manet_2_num_pos * 100
# percent_throughput_uav_0 = len(throughput_uav_0_fn_df.loc[throughput_uav_0_fn_df["Below_90"]==True]) / uav_0_num_pos * 100
# percent_throughput_manet_1 = len(throughput_manet_1_fn_df.loc[throughput_manet_1_fn_df["Below_90"]==True]) / manet_1_num_pos * 100
# percent_throughput_manet_a = len(throughput_manet_a_fn_df.loc[throughput_manet_a_fn_df["Below_90"]==True]) / manet_a_num_pos * 100
# percent_throughput_manet_2 = len(throughput_manet_2_fn_df.loc[throughput_manet_2_fn_df["Below_90"]==True]) / manet_2_num_pos * 100
# print([percent_gamma_uav_0, percent_gamma_manet_1, percent_gamma_manet_a, percent_gamma_manet_2])
# print([percent_throughput_uav_0, percent_throughput_manet_1, percent_throughput_manet_a, percent_throughput_manet_2])
# Out:
# [0.002136797794824676, 0.0, 0.0, 0.03576606091305125, 0.011966069155081135, 0.004551051861861573]
# [0.6888259073134818, 0.0, 0.0, 4.5947587288705645, 1.428977420203476, 0.35288155975049734]
# ' For USI 10'

# %% [markdown]
# ### Plot Percentage of Positive Cases That Are Predicted As False Negatives and with At Least One Link Having Reliability Below 90% / 95%

# %%
gamma_90 = [0.000119660691550811,0.000257664026384796,0.000493708926389485,0.000558129868272412]
th_90 = [0.0142897742020347,0.0760324301857208,0.16729485669415,0.189518704706653]
gamma_95 = [0.00122828180444803,0.00245942425184504,0.00517688025861467,0.00577032164445134]
th_95 = [0.0239374174583189,0.100871242329215,0.223100110446961,0.253982238918319]

usi = '10', '20', '66.7', '100'

plt.figure(figsize=(6,3))
plt.rcParams.update({'font.size': 16})
plt.plot(usi, gamma_95, ':o', color='tab:blue')
plt.plot(usi, gamma_90, '--o', color='tab:blue')
plt.plot(usi, th_95, ':o', color='tab:orange')
plt.plot(usi, th_90, '--o', color='tab:orange')
plt.xlabel("USI (ms)")
plt.ylabel("mFNR")
plt.ylim(0, 0.5)
# plt.legend(['$\gamma$, 95%','$\gamma$, 90%','$\\tau$, 95%', '$\\tau$, 90%'], bbox_to_anchor=(-0.05, 1.1, 1, 0.2), loc="lower center", columnspacing=0.6, borderaxespad=0, ncol=4, fontsize=14)
# Out:
# (0.0, 0.5)

# %% [markdown]
# ### For Box Plots. And to count percentage of data samples in FN with reliability below 90% (aggregated link time windows).

# %%
gamma_dl_uav_0_fn = np.hstack([gamma_uav_0_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), gamma_uav_0_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                              gamma_uav_0_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), gamma_uav_0_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                              gamma_uav_0_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), gamma_uav_0_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                              gamma_uav_0_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), gamma_uav_0_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
gamma_dl_uav_1_fn = np.hstack([gamma_uav_1_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), gamma_uav_1_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                              gamma_uav_1_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), gamma_uav_1_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                              gamma_uav_1_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), gamma_uav_1_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                              gamma_uav_1_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), gamma_uav_1_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
gamma_dl_uav_2_fn = np.hstack([gamma_uav_2_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), gamma_uav_2_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                              gamma_uav_2_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), gamma_uav_2_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                              gamma_uav_2_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), gamma_uav_2_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                              gamma_uav_2_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), gamma_uav_2_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
gamma_dl_manet_1_fn = np.hstack([gamma_manet_1_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), gamma_manet_1_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                                gamma_manet_1_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), gamma_manet_1_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                                gamma_manet_1_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), gamma_manet_1_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                                gamma_manet_1_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), gamma_manet_1_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
gamma_dl_manet_a_fn = np.hstack([gamma_manet_a_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), gamma_manet_a_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                                gamma_manet_a_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), gamma_manet_a_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                                gamma_manet_a_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), gamma_manet_a_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                                gamma_manet_a_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), gamma_manet_a_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
gamma_dl_manet_2_fn = np.hstack([gamma_manet_2_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), gamma_manet_2_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                                gamma_manet_2_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), gamma_manet_2_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                                gamma_manet_2_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), gamma_manet_2_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                                gamma_manet_2_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), gamma_manet_2_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])

gamma_ul_list = [gamma_uav_0_fn_df["UL_Measured_Reliability_1"].values*100, gamma_uav_1_fn_df["UL_Measured_Reliability_1"].values*100, gamma_uav_2_fn_df["UL_Measured_Reliability_1"].values*100, 
                   gamma_manet_1_fn_df["UL_Measured_Reliability_1"].values*100, gamma_manet_a_fn_df["UL_Measured_Reliability_1"].values*100, gamma_manet_2_fn_df["UL_Measured_Reliability_1"].values*100]
gamma_ul_list = [data for data in gamma_ul_list if data.any()]
gamma_dl_list = [gamma_dl_uav_0_fn*100, gamma_dl_uav_1_fn*100, gamma_dl_uav_2_fn*100, gamma_dl_manet_1_fn*100, gamma_dl_manet_a_fn*100, gamma_dl_manet_2_fn*100]
gamma_dl_list = [data for data in gamma_dl_list if data.any()]

throughput_dl_uav_0_fn = np.hstack([throughput_uav_0_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), throughput_uav_0_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                              throughput_uav_0_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), throughput_uav_0_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                              throughput_uav_0_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), throughput_uav_0_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                              throughput_uav_0_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), throughput_uav_0_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
throughput_dl_uav_1_fn = np.hstack([throughput_uav_1_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), throughput_uav_1_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                              throughput_uav_1_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), throughput_uav_1_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                              throughput_uav_1_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), throughput_uav_1_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                              throughput_uav_1_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), throughput_uav_1_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
throughput_dl_uav_2_fn = np.hstack([throughput_uav_2_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), throughput_uav_2_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                              throughput_uav_2_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), throughput_uav_2_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                              throughput_uav_2_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), throughput_uav_2_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                              throughput_uav_2_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), throughput_uav_2_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
throughput_dl_manet_1_fn = np.hstack([throughput_manet_1_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), throughput_manet_1_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                                throughput_manet_1_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), throughput_manet_1_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                                throughput_manet_1_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), throughput_manet_1_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                                throughput_manet_1_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), throughput_manet_1_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
throughput_dl_manet_a_fn = np.hstack([throughput_manet_a_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), throughput_manet_a_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                                throughput_manet_a_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), throughput_manet_a_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                                throughput_manet_a_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), throughput_manet_a_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                                throughput_manet_a_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), throughput_manet_a_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])
throughput_dl_manet_2_fn = np.hstack([throughput_manet_2_fn_df["UAV_0_Measured_Reliability_1"].to_numpy(), throughput_manet_2_fn_df["UAV_1_Measured_Reliability_1"].to_numpy(),
                                throughput_manet_2_fn_df["UAV_2_Measured_Reliability_1"].to_numpy(), throughput_manet_2_fn_df["UAV_3_Measured_Reliability_1"].to_numpy(),
                                throughput_manet_2_fn_df["UAV_4_Measured_Reliability_1"].to_numpy(), throughput_manet_2_fn_df["UAV_5_Measured_Reliability_1"].to_numpy(),
                                throughput_manet_2_fn_df["UAV_6_Measured_Reliability_1"].to_numpy(), throughput_manet_2_fn_df["UAV_7_Measured_Reliability_1"].to_numpy()])

throughput_ul_list = [throughput_uav_0_fn_df["UL_Measured_Reliability_1"].values*100, throughput_uav_1_fn_df["UL_Measured_Reliability_1"].values*100, throughput_uav_2_fn_df["UL_Measured_Reliability_1"].values*100, 
                   throughput_manet_1_fn_df["UL_Measured_Reliability_1"].values*100, throughput_manet_a_fn_df["UL_Measured_Reliability_1"].values*100, throughput_manet_2_fn_df["UL_Measured_Reliability_1"].values*100]
throughput_ul_list = [data for data in throughput_ul_list if data.any()]
throughput_dl_list = [throughput_dl_uav_0_fn*100, throughput_dl_uav_1_fn*100, throughput_dl_uav_2_fn*100, throughput_dl_manet_1_fn*100, throughput_dl_manet_a_fn*100, throughput_dl_manet_2_fn*100]
throughput_dl_list = [data for data in throughput_dl_list if data.any()]

# Get the percentage below 90%
gamma_ul_percent_outlier = []
for data in gamma_ul_list:
    if data.any():
        outliers = [x for x in data if x < 90] 
        percent_outlier = len(outliers) / len(data)
    else: 
        percent_outlier = 0
    gamma_ul_percent_outlier.append(percent_outlier)

gamma_dl_percent_outlier = []
for data in gamma_dl_list:
    if data.any():
        outliers = [x for x in data if x < 90]
        percent_outlier = len(outliers) / len(data)
    else: 
        percent_outlier = 0
    gamma_dl_percent_outlier.append(percent_outlier)

throughput_ul_percent_outlier = []
for data in throughput_ul_list:
    if data.any():
        outliers = [x for x in data if x < 90]
        percent_outlier = len(outliers) / len(data)
    else: 
        percent_outlier = 0
    throughput_ul_percent_outlier.append(percent_outlier)

throughput_dl_percent_outlier = []
for data in throughput_dl_list:
    if data.any():
        outliers = [x for x in data if x < 90]
        percent_outlier = len(outliers) / len(data)
    else: 
        percent_outlier = 0
    throughput_dl_percent_outlier.append(percent_outlier)

# print(np.round(gamma_ul_percent_outlier,2))
# print(np.round(gamma_dl_percent_outlier,2))
# print(np.round(throughput_ul_percent_outlier,2))
# print(np.round(throughput_dl_percent_outlier,2))
print(np.array(gamma_ul_percent_outlier)*100)
print(np.array(gamma_dl_percent_outlier)*100)
print(np.array(throughput_ul_percent_outlier)*100)
print(np.array(throughput_dl_percent_outlier)*100)

# %% [markdown]
# ### Box Plots of Reliability in FN

# %%
# Run previous code block first!

space = 0.07
box_params = dict(widths=0.15)
fig = plt.figure(figsize=(10, 4))
ind = np.arange(len(throughput_ul_list))
plt.rcParams.update({'font.size': 16})
box_th = plt.boxplot(throughput_ul_list, showmeans=True, labels=None,
            positions=ind-2*space, boxprops=dict(linestyle='--', linewidth=2,  color='0.6'), whiskerprops=dict(linestyle='--', linewidth=2, color='0.6'), 
            medianprops=dict(linestyle='--', color='0.6'), meanprops=dict(markerfacecolor="black", markeredgecolor="black"), flierprops=dict(marker='x', markeredgecolor='0.6', markersize=6), **box_params)
box_gamma = plt.boxplot(gamma_ul_list, showmeans=True, labels=None,
            positions=ind+2*space, boxprops=dict(linestyle='-', linewidth=2,  color='0.3'), whiskerprops=dict(linestyle='-', linewidth=2, color='0.3'), 
            medianprops=dict(linestyle='-', color='0.3'), meanprops=dict(markerfacecolor="black", markeredgecolor="black"), flierprops=dict(marker='o', markeredgecolor='0.3', markersize=6), **box_params)
plt.xticks(ind, ["UAV 1","UAV 2","UAV 3","MANET 1","MANET 2","MANET 3"])
# plt.xticks(ind, ["UAV 1","MANET 1","MANET 2","MANET 3"])
plt.xlabel("Interference Scenario")
plt.ylabel("Downlink Reliability (%)")
plt.ylim(0,100)
plt.legend((box_th["boxes"][0], box_gamma["boxes"][0]), ("$\\tau$", "$\\gamma$"), loc='lower left')

space = 0.07
box_params = dict(widths=0.15)
fig = plt.figure(figsize=(10, 4))
ind = np.arange(len(throughput_dl_list))
plt.rcParams.update({'font.size': 16})
box_th = plt.boxplot(throughput_dl_list, showmeans=True, labels=None,
            positions=ind-2*space, boxprops=dict(linestyle='--', linewidth=2,  color='0.6'), whiskerprops=dict(linestyle='--', linewidth=2, color='0.6'), 
            medianprops=dict(linestyle='--', color='0.6'), meanprops=dict(markerfacecolor="black", markeredgecolor="black"), flierprops=dict(marker='x', markeredgecolor='0.6', markersize=6), **box_params)
box_gamma = plt.boxplot(gamma_dl_list, showmeans=True, labels=None,
            positions=ind+2*space, boxprops=dict(linestyle='-', linewidth=2,  color='0.3'), whiskerprops=dict(linestyle='-', linewidth=2, color='0.3'), 
            medianprops=dict(linestyle='-', color='0.3'), meanprops=dict(markerfacecolor="black", markeredgecolor="black"), flierprops=dict(marker='o', markeredgecolor='0.3', markersize=6), **box_params)
plt.xticks(ind, ["UAV 1","UAV 2","UAV 3","MANET 1","MANET 2","MANET 3"])
# plt.xticks(ind, ["UAV 1","MANET 1","MANET 2","MANET 3"])
plt.xlabel("Interference Scenario")
plt.ylabel("Uplink Reliability (%)")
plt.ylim(0,100)
plt.legend((box_th["boxes"][0], box_gamma["boxes"][0]), ("$\\tau$", "$\\gamma$"), loc='lower left')
# Out:
# [0.00093712 0.00060696 0.02264493 0.00037453 0.00073965 0.00200417]
# [0.00093712 0.00462806 0.06793478 0.16469976 0.22337443 0.36175245]
# [0.50153065 4.55384727 7.53828593 0.23035079 0.12435897 0.09907995]
# [ 4.22743738 27.50663897 50.77772758 31.30810563 48.9284917  52.11533099]

# %%
gamma_uav_0_fn_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/num_reliable_failure_detection_uav_0_fn_500_runs.csv")

usi_10 = gamma_uav_0_fn_df.loc[gamma_uav_0_fn_df["USI"]==10]
usi_20 = gamma_uav_0_fn_df.loc[gamma_uav_0_fn_df["USI"]==20]
usi_667 = gamma_uav_0_fn_df.loc[gamma_uav_0_fn_df["USI"]==66.7]
usi_100 = gamma_uav_0_fn_df.loc[gamma_uav_0_fn_df["USI"]==100]

dl_usi_10 = np.hstack([usi_10["UAV_0_Measured_Reliability_1"].to_numpy(), usi_10["UAV_1_Measured_Reliability_1"].to_numpy(),
                        usi_10["UAV_2_Measured_Reliability_1"].to_numpy(), usi_10["UAV_3_Measured_Reliability_1"].to_numpy(),
                        usi_10["UAV_4_Measured_Reliability_1"].to_numpy(), usi_10["UAV_5_Measured_Reliability_1"].to_numpy(),
                        usi_10["UAV_6_Measured_Reliability_1"].to_numpy(), usi_10["UAV_7_Measured_Reliability_1"].to_numpy()])
dl_usi_20 = np.hstack([usi_20["UAV_0_Measured_Reliability_1"].to_numpy(), usi_20["UAV_1_Measured_Reliability_1"].to_numpy(),
                        usi_20["UAV_2_Measured_Reliability_1"].to_numpy(), usi_20["UAV_3_Measured_Reliability_1"].to_numpy(),
                        usi_20["UAV_4_Measured_Reliability_1"].to_numpy(), usi_20["UAV_5_Measured_Reliability_1"].to_numpy(),
                        usi_20["UAV_6_Measured_Reliability_1"].to_numpy(), usi_20["UAV_7_Measured_Reliability_1"].to_numpy()])
dl_usi_667 = np.hstack([usi_667["UAV_0_Measured_Reliability_1"].to_numpy(), usi_667["UAV_1_Measured_Reliability_1"].to_numpy(),
                        usi_667["UAV_2_Measured_Reliability_1"].to_numpy(), usi_667["UAV_3_Measured_Reliability_1"].to_numpy(),
                        usi_667["UAV_4_Measured_Reliability_1"].to_numpy(), usi_667["UAV_5_Measured_Reliability_1"].to_numpy(),
                        usi_667["UAV_6_Measured_Reliability_1"].to_numpy(), usi_667["UAV_7_Measured_Reliability_1"].to_numpy()])
dl_usi_100 = np.hstack([usi_100["UAV_0_Measured_Reliability_1"].to_numpy(), usi_100["UAV_1_Measured_Reliability_1"].to_numpy(),
                        usi_100["UAV_2_Measured_Reliability_1"].to_numpy(), usi_100["UAV_3_Measured_Reliability_1"].to_numpy(),
                        usi_100["UAV_4_Measured_Reliability_1"].to_numpy(), usi_100["UAV_5_Measured_Reliability_1"].to_numpy(),
                        usi_100["UAV_6_Measured_Reliability_1"].to_numpy(), usi_100["UAV_7_Measured_Reliability_1"].to_numpy()])


gamma_ul_list = [usi_10["UL_Measured_Reliability_1"].values*100, usi_20["UL_Measured_Reliability_1"].values*100, 
                 usi_667["UL_Measured_Reliability_1"].values*100, usi_100["UL_Measured_Reliability_1"].values*100]
gamma_dl_list = [dl_usi_10*100, dl_usi_20*100, dl_usi_667*100, dl_usi_100*100]

space = 0.1
box_params = dict(widths=0.25)
fig = plt.figure(figsize=(14, 6))
plt.rcParams.update({'font.size': 16})
box_ul = plt.boxplot(gamma_ul_list, showmeans=True, labels=None,
            positions=np.arange(4)-2*space, boxprops=dict(linestyle='--', linewidth=2,  color='0.6'), whiskerprops=dict(linestyle='--', linewidth=2, color='0.6'), 
            medianprops=dict(linestyle='--', color='0.6'), meanprops=dict(markerfacecolor="black", markeredgecolor="black"), flierprops=dict(marker='x', markeredgecolor='0.6', markersize=6), **box_params)
box_dl = plt.boxplot(gamma_dl_list, showmeans=True, labels=None,
            positions=np.arange(4)+2*space, boxprops=dict(linestyle='-', linewidth=2,  color='0.3'), whiskerprops=dict(linestyle='-', linewidth=2, color='0.3'), 
            medianprops=dict(linestyle='-', color='0.3'), meanprops=dict(markerfacecolor="black", markeredgecolor="black"), flierprops=dict(marker='o', markeredgecolor='0.3', markersize=6), **box_params)
plt.xticks(np.arange(4), ["10","20","66.7","100"])
plt.xlabel("USI (ms)")
plt.ylabel("Reliability (%)")
plt.ylim(0,100)
plt.legend((box_ul["boxes"][0], box_dl["boxes"][0]), ("Downlink", "Uplink"), loc='lower left')

# %% [markdown]
# ## Plot Correlation Metric

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Bar Chart Averages of DL and UL (For Gamma and Tau)

# %%
# DL Averaged Over All UAVs
# UL Averaged Over All USIs

dl_spearmanr_gamma = [0.955131840564532,0.949683418934619,0.946955683386341,0.918280979327208,0.931224114475253,0.931224114475253]
ul_spearmanr_gamma = [0.986684866531043,0.975458257068251,0.972777169268374,0.971557545253574,0.9720722010,0.969325999842772]

dl_spearmanr_tau = [0.92741951747629,0.917020441202811,0.93137506437708,0.88231585120863,0.884432471920588,0.894347865768116]
ul_spearmanr_tau = [0.599442873651721,0.943494506569762,0.961158050319937,0.780826761983915,0.854746941845665,0.899577181245139]

# For x-ticks
ind = np.arange(6, dtype=float)  
width = 0.2

# PLOT DL Rho
plt.figure(figsize=(14,5))
plt.rcParams.update({'font.size': 14})
bar_th = plt.bar(ind, np.array(dl_spearmanr_tau), width, edgecolor='black', color = '0.9') 
plt.bar_label(bar_th, fmt='%.2f', padding=3, fontsize=11)
bar_gamma = plt.bar(ind + width, np.array(dl_spearmanr_gamma), width, edgecolor='black', color = '0.6') 
plt.bar_label(bar_gamma, fmt='%.2f', padding=3, fontsize=11)
plt.ylabel('Spearman Correlation Coefficient') 
plt.xlabel('Interference Scenario') 
# plt.title("Uplink")
# plt.ylim(0.95, 1.0)
plt.xticks(ind+0.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_th, bar_gamma), ('$\\tau$', '$\gamma$'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3) 

# PLOT UL Rho
plt.figure(figsize=(14,5))
plt.rcParams.update({'font.size': 14})
bar_th = plt.bar(ind, np.array(ul_spearmanr_tau), width, edgecolor='black', color = '0.9') 
plt.bar_label(bar_th, fmt='%.2f', padding=3, fontsize=11)
bar_gamma = plt.bar(ind + width, np.array(ul_spearmanr_gamma), width, edgecolor='black', color = '0.6') 
plt.bar_label(bar_gamma, fmt='%.2f', padding=3, fontsize=11)
plt.ylabel('Spearman Correlation Coefficient') 
plt.xlabel('Interference Scenario') 
# plt.title("Downlink")
# plt.ylim(0.95, 1.0)
plt.xticks(ind+0.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_th, bar_gamma), ('$\\tau$', '$\gamma$'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=3)

# %% [markdown]
# ### Bar Chart For "Downlink" for Different USI (For Gamma and Tau)

# %%
usi_10_gamma = [0.998381460368932,0.999307317137737,0.999213280307,0.993713147489198,0.99459684950505,0.995855703711033]
usi_20_gamma = [0.994185967670598,0.990994270980443,0.994126252690756,0.986685075663915,0.986072127813839,0.985738782334299]
usi_667_gamma = [0.986088598735396,0.961061377313594,0.956096980837392,0.957811785412483,0.958579916879151,0.954879576634843]
usi_100_gamma = [0.968083439349246,0.950470062841231,0.941672163238348,0.9480201724487,0.949039909996653,0.940829936690911]

usi_10_tau = [0.958699184765847,0.986115830780464,0.977811737001702,0.981382846460405,0.994583210326613,0.99650178608639]
usi_20_tau = [0.89792154870785,0.978634615140226,0.994675376822989,0.943173791048793,0.961953741212739,0.971502328098672]
usi_667_tau = [0.364560734325606,0.915169118598654,0.944631672878012,0.651956317849091,0.774783313002277,0.837780415141434]
usi_100_tau = [0.176590026807582,0.894058461759704,0.927513414577045,0.546794092577372,0.687667502841033,0.792524195654061]

# For x-ticks
ind = np.arange(6, dtype=float)  
width = 0.1

# Plot for gamma
plt.figure(figsize=(14,5))
plt.rcParams.update({'font.size': 14})
bar_usi_10 = plt.bar(ind, np.array(usi_10_gamma), width, edgecolor='black', color = '0.9') 
# plt.bar_label(bar_usi_10, fmt='%.2f', padding=3, fontsize=11)
bar_usi_20 = plt.bar(ind + width, np.array(usi_20_gamma), width, edgecolor='black', color = '0.6') 
# plt.bar_label(bar_usi_20, fmt='%.2f', padding=3, fontsize=11)
bar_usi_667 = plt.bar(ind + 2*width, np.array(usi_667_gamma), width, edgecolor='black', color = '0.3') 
# plt.bar_label(bar_usi_667, fmt='%.2f', padding=3, fontsize=11)
bar_usi_100 = plt.bar(ind + 3*width, np.array(usi_100_gamma), width, edgecolor='black', color = '0.1') 
# plt.bar_label(bar_usi_100, fmt='%.2f', padding=3, fontsize=11)
plt.ylabel('Spearman $\\rho$') 
plt.xlabel('Interference Scenario') 
# plt.title("$\gamma$")
# plt.ylim(0.95, 1.0)
plt.xticks(ind+1.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_usi_10, bar_usi_20, bar_usi_667, bar_usi_100), ('USI: 10 ms', 'USI: 20 ms', 'USI: 66.7 ms', 'USI: 100 ms'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=4) 

# Plot for tau
plt.figure(figsize=(14,5))
plt.rcParams.update({'font.size': 14})
bar_usi_10 = plt.bar(ind, np.array(usi_10_tau), width, edgecolor='black', color = '0.9') 
# plt.bar_label(bar_usi_10, fmt='%.2f', padding=3, fontsize=11)
bar_usi_20 = plt.bar(ind + width, np.array(usi_20_tau), width, edgecolor='black', color = '0.6') 
# plt.bar_label(bar_usi_20, fmt='%.2f', padding=3, fontsize=11)
bar_usi_667 = plt.bar(ind + 2*width, np.array(usi_667_tau), width, edgecolor='black', color = '0.3') 
# plt.bar_label(bar_usi_667, fmt='%.2f', padding=3, fontsize=11)
bar_usi_100 = plt.bar(ind + 3*width, np.array(usi_100_tau), width, edgecolor='black', color = '0.1') 
# plt.bar_label(bar_usi_100, fmt='%.2f', padding=3, fontsize=11)
plt.ylabel('Spearman $\\rho$') 
plt.xlabel('Interference Scenario') 
# plt.title("$\tau$")
# plt.ylim(0.95, 1.0)
plt.xticks(ind+1.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_usi_10, bar_usi_20, bar_usi_667, bar_usi_100), ('USI: 10 ms', 'USI: 20 ms', 'USI: 66.7 ms', 'USI: 100 ms'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=4)

# %% [markdown]
# ### Bar Chart For "Uplink" for Different USI (For Gamma and Tau)

# %%
usi_10_gamma = [0.96475,0.965625,0.969125,0.95975,0.959375,0.959375]
usi_20_gamma = [0.964,0.963125,0.966125,0.95625,0.956875,0.95575]
usi_667_gamma = [0.981,0.963,0.963125,0.9535,0.956,0.9565]
usi_100_gamma = [0.977625,0.963375,0.963,0.952625,0.955,0.95675]

usi_10_tau = [0.936875,0.949625,0.964625,0.922875,0.932875,0.942375]
usi_20_tau = [0.936375,0.94275,0.9585,0.908625,0.91825,0.9265]
usi_667_tau = [0.865375,0.935625,0.94975,0.8995,0.90725,0.91775]
usi_100_tau = [0.642,0.934875,0.948,0.89825,0.905375,0.918125]

# For x-ticks
ind = np.arange(6, dtype=float)  
width = 0.1

# Plot for gamma
plt.figure(figsize=(14,5))
plt.rcParams.update({'font.size': 14})
bar_usi_10 = plt.bar(ind, np.array(usi_10_gamma), width, edgecolor='black', color = '0.9') 
# plt.bar_label(bar_usi_10, fmt='%.2f', padding=3, fontsize=11)
bar_usi_20 = plt.bar(ind + width, np.array(usi_20_gamma), width, edgecolor='black', color = '0.6') 
# plt.bar_label(bar_usi_20, fmt='%.2f', padding=3, fontsize=11)
bar_usi_667 = plt.bar(ind + 2*width, np.array(usi_667_gamma), width, edgecolor='black', color = '0.3') 
# plt.bar_label(bar_usi_667, fmt='%.2f', padding=3, fontsize=11)
bar_usi_100 = plt.bar(ind + 3*width, np.array(usi_100_gamma), width, edgecolor='black', color = '0.1') 
# plt.bar_label(bar_usi_100, fmt='%.2f', padding=3, fontsize=11)
plt.ylabel('Spearman $\\rho$') 
plt.xlabel('Interference Scenario') 
# plt.title("$\gamma$")
# plt.ylim(0.95, 1.0)
plt.xticks(ind+1.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_usi_10, bar_usi_20, bar_usi_667, bar_usi_100), ('USI: 10 ms', 'USI: 20 ms', 'USI: 66.7 ms', 'USI: 100 ms'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=4) 

# Plot for tau
plt.figure(figsize=(14,5))
plt.rcParams.update({'font.size': 14})
bar_usi_10 = plt.bar(ind, np.array(usi_10_tau), width, edgecolor='black', color = '0.9') 
# plt.bar_label(bar_usi_10, fmt='%.2f', padding=3, fontsize=11)
bar_usi_20 = plt.bar(ind + width, np.array(usi_20_tau), width, edgecolor='black', color = '0.6') 
# plt.bar_label(bar_usi_20, fmt='%.2f', padding=3, fontsize=11)
bar_usi_667 = plt.bar(ind + 2*width, np.array(usi_667_tau), width, edgecolor='black', color = '0.3') 
# plt.bar_label(bar_usi_667, fmt='%.2f', padding=3, fontsize=11)
bar_usi_100 = plt.bar(ind + 3*width, np.array(usi_100_tau), width, edgecolor='black', color = '0.1') 
# plt.bar_label(bar_usi_100, fmt='%.2f', padding=3, fontsize=11)
plt.ylabel('Spearman $\\rho$') 
plt.xlabel('Interference Scenario') 
# plt.title("$\tau$")
# plt.ylim(0.95, 1.0)
plt.xticks(ind+1.5*width,['UAV 1', 'UAV 2', 'UAV 3', 'MANET 1', 'MANET 2', 'MANET 3'])
plt.tick_params(axis='x', which='both',length=0)
plt.legend( (bar_usi_10, bar_usi_20, bar_usi_667, bar_usi_100), ('USI: 10 ms', 'USI: 20 ms', 'USI: 66.7 ms', 'USI: 100 ms'), bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=4)

# %% [markdown]
# ### Line Plots For "Uplink", "Downlink", and Average Over All Links

# %%
gamma_corr_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/Num_Reliability_Spearman_500_runs.csv")
th_corr_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/Throughput_Spearman_500_runs.csv")

scenario = "uav_scenario_2_{}_processed.csv"
gamma_corr_df = gamma_corr_df.loc[gamma_corr_df["Scenario"]==scenario]
th_corr_df = th_corr_df.loc[th_corr_df["Scenario"]==scenario]

# For "Downlink", get the Spearman rho for different USI
gamma_ul_corr = [*gamma_corr_df[["Spearman_UL_10","Spearman_UL_20","Spearman_UL_667","Spearman_UL_100"]].values][0]
th_ul_corr = [*th_corr_df[["Spearman_UL_10","Spearman_UL_20","Spearman_UL_667","Spearman_UL_100"]].values][0]

# Get the average Spearman rho for "Uplink" and for all links for different USI
gamma_dl_corr = []
th_dl_corr = []
gamma_avg_corr = []
th_avg_corr = []
for usi in ["10", "20", "667", "100"]:
    gamma_dl_corr.append(np.mean([*gamma_corr_df[["Spearman_UAV_0_{}".format(usi),"Spearman_UAV_1_{}".format(usi),"Spearman_UAV_2_{}".format(usi),"Spearman_UAV_3_{}".format(usi), \
                                                  "Spearman_UAV_4_{}".format(usi),"Spearman_UAV_5_{}".format(usi),"Spearman_UAV_6_{}".format(usi),"Spearman_UAV_7_{}".format(usi)]].values][0]))
    th_dl_corr.append(np.mean([*th_corr_df[["Spearman_UAV_0_{}".format(usi),"Spearman_UAV_1_{}".format(usi),"Spearman_UAV_2_{}".format(usi),"Spearman_UAV_3_{}".format(usi), \
                                                  "Spearman_UAV_4_{}".format(usi),"Spearman_UAV_5_{}".format(usi),"Spearman_UAV_6_{}".format(usi),"Spearman_UAV_7_{}".format(usi)]].values][0]))
    gamma_avg_corr.append(np.mean([*gamma_corr_df[["Spearman_UL_{}".format(usi),"Spearman_UAV_0_{}".format(usi),"Spearman_UAV_1_{}".format(usi),"Spearman_UAV_2_{}".format(usi),"Spearman_UAV_3_{}".format(usi), \
                                                  "Spearman_UAV_4_{}".format(usi),"Spearman_UAV_5_{}".format(usi),"Spearman_UAV_6_{}".format(usi),"Spearman_UAV_7_{}".format(usi)]].values][0]))
    th_avg_corr.append(np.mean([*th_corr_df[["Spearman_UL_{}".format(usi),"Spearman_UAV_0_{}".format(usi),"Spearman_UAV_1_{}".format(usi),"Spearman_UAV_2_{}".format(usi),"Spearman_UAV_3_{}".format(usi), \
                                                  "Spearman_UAV_4_{}".format(usi),"Spearman_UAV_5_{}".format(usi),"Spearman_UAV_6_{}".format(usi),"Spearman_UAV_7_{}".format(usi)]].values][0]))
gamma_dl_corr = np.array(gamma_dl_corr)
th_dl_corr = np.array(th_dl_corr)
gamma_avg_corr = np.array(gamma_avg_corr)
th_avg_corr = np.array(th_avg_corr)

plt.figure(figsize=(16,3))
plt.subplot(1,2,1)
plt.rcParams.update({'font.size': 16})
plt.plot(['10', '20', '66.7', '100'], gamma_ul_corr, 'o', linestyle='dashed', color='tab:blue')
plt.plot(['10', '20', '66.7', '100'], gamma_dl_corr, 'o', linestyle='dotted', color='tab:blue')
# plt.plot(['10', '20', '66.7', '100'], gamma_avg_corr, 'o', linestyle='dashdot', color='tab:blue')
plt.plot(['10', '20', '66.7', '100'], th_ul_corr, 'o', linestyle='dashed', color='tab:orange')
plt.plot(['10', '20', '66.7', '100'], th_dl_corr, 'o', linestyle='dotted', color='tab:orange')
# plt.plot(['10', '20', '66.7', '100'], th_avg_corr, 'o', linestyle='dashdot', color='tab:orange')
plt.xlabel("USI (ms)")
plt.ylabel("Correlation")
plt.ylim(0,1.05)
# plt.legend(['$\gamma$, Downlink','$\gamma$, Uplinks','$\\tau$, Downlink', '$\\tau$, Uplinks'], bbox_to_anchor=(0.55, 1.1, 1, 0.2), loc="lower center", columnspacing=1, handletextpad=1, borderaxespad=0, ncol=4, fontsize=16)

gamma_corr_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/Num_Reliability_Spearman_500_runs.csv")
th_corr_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results_new/Throughput_Spearman_500_runs.csv")
scenario = "manet_scenario_2_{}_processed.csv"
gamma_corr_df = gamma_corr_df.loc[gamma_corr_df["Scenario"]==scenario]
th_corr_df = th_corr_df.loc[th_corr_df["Scenario"]==scenario]

# For "Downlink", get the Spearman rho for different USI
gamma_ul_corr = [*gamma_corr_df[["Spearman_UL_10","Spearman_UL_20","Spearman_UL_667","Spearman_UL_100"]].values][0]
th_ul_corr = [*th_corr_df[["Spearman_UL_10","Spearman_UL_20","Spearman_UL_667","Spearman_UL_100"]].values][0]

# Get the average Spearman rho for "Uplink" and for all links for different USI
gamma_dl_corr = []
th_dl_corr = []
gamma_avg_corr = []
th_avg_corr = []
for usi in ["10", "20", "667", "100"]:
    gamma_dl_corr.append(np.mean([*gamma_corr_df[["Spearman_UAV_0_{}".format(usi),"Spearman_UAV_1_{}".format(usi),"Spearman_UAV_2_{}".format(usi),"Spearman_UAV_3_{}".format(usi), \
                                                  "Spearman_UAV_4_{}".format(usi),"Spearman_UAV_5_{}".format(usi),"Spearman_UAV_6_{}".format(usi),"Spearman_UAV_7_{}".format(usi)]].values][0]))
    th_dl_corr.append(np.mean([*th_corr_df[["Spearman_UAV_0_{}".format(usi),"Spearman_UAV_1_{}".format(usi),"Spearman_UAV_2_{}".format(usi),"Spearman_UAV_3_{}".format(usi), \
                                                  "Spearman_UAV_4_{}".format(usi),"Spearman_UAV_5_{}".format(usi),"Spearman_UAV_6_{}".format(usi),"Spearman_UAV_7_{}".format(usi)]].values][0]))
    gamma_avg_corr.append(np.mean([*gamma_corr_df[["Spearman_UL_{}".format(usi),"Spearman_UAV_0_{}".format(usi),"Spearman_UAV_1_{}".format(usi),"Spearman_UAV_2_{}".format(usi),"Spearman_UAV_3_{}".format(usi), \
                                                  "Spearman_UAV_4_{}".format(usi),"Spearman_UAV_5_{}".format(usi),"Spearman_UAV_6_{}".format(usi),"Spearman_UAV_7_{}".format(usi)]].values][0]))
    th_avg_corr.append(np.mean([*th_corr_df[["Spearman_UL_{}".format(usi),"Spearman_UAV_0_{}".format(usi),"Spearman_UAV_1_{}".format(usi),"Spearman_UAV_2_{}".format(usi),"Spearman_UAV_3_{}".format(usi), \
                                                  "Spearman_UAV_4_{}".format(usi),"Spearman_UAV_5_{}".format(usi),"Spearman_UAV_6_{}".format(usi),"Spearman_UAV_7_{}".format(usi)]].values][0]))
gamma_dl_corr = np.array(gamma_dl_corr)
th_dl_corr = np.array(th_dl_corr)
gamma_avg_corr = np.array(gamma_avg_corr)
th_avg_corr = np.array(th_avg_corr)

plt.subplot(1,2,2)
plt.rcParams.update({'font.size': 16})
plt.plot(['10', '20', '66.7', '100'], gamma_ul_corr, 'o', linestyle='dashed', color='tab:blue')
plt.plot(['10', '20', '66.7', '100'], gamma_dl_corr, 'o', linestyle='dotted', color='tab:blue')
# plt.plot(['10', '20', '66.7', '100'], gamma_avg_corr, 'o', linestyle='dashdot', color='tab:blue')
plt.plot(['10', '20', '66.7', '100'], th_ul_corr, 'o', linestyle='dashed', color='tab:orange')
plt.plot(['10', '20', '66.7', '100'], th_dl_corr, 'o', linestyle='dotted', color='tab:orange')
# plt.plot(['10', '20', '66.7', '100'], th_avg_corr, 'o', linestyle='dashdot', color='tab:orange')
plt.xlabel("USI (ms)")
plt.ylabel("Correlation")
plt.ylim(0,1.05)

plt.subplots_adjust(wspace=0.25)

# %% [markdown]
# ### Line Plots For All Links

# %%
gamma_corr_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Num_Reliability_Spearman_500_runs.csv")
th_corr_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Throughput_Spearman_500_runs.csv")

scenario = "manet_scenario_1_{}_processed.csv"
gamma_corr_df = gamma_corr_df.loc[gamma_corr_df["Scenario"]==scenario]
th_corr_df = th_corr_df.loc[th_corr_df["Scenario"]==scenario]

# For each link, get the Spearman rho for different USI
gamma_ul_corr = [*gamma_corr_df[["Spearman_UL_10","Spearman_UL_20","Spearman_UL_667","Spearman_UL_100"]].values][0]
th_ul_corr = [*th_corr_df[["Spearman_UL_10","Spearman_UL_20","Spearman_UL_667","Spearman_UL_100"]].values][0]
gamma_uav_0_corr = [*gamma_corr_df[["Spearman_UAV_0_10","Spearman_UAV_0_20","Spearman_UAV_0_667","Spearman_UAV_0_100"]].values][0]
th_uav_0_corr = [*th_corr_df[["Spearman_UAV_0_10","Spearman_UAV_0_20","Spearman_UAV_0_667","Spearman_UAV_0_100"]].values][0]
gamma_uav_1_corr = [*gamma_corr_df[["Spearman_UAV_1_10","Spearman_UAV_1_20","Spearman_UAV_1_667","Spearman_UAV_1_100"]].values][0]
th_uav_1_corr = [*th_corr_df[["Spearman_UAV_1_10","Spearman_UAV_1_20","Spearman_UAV_1_667","Spearman_UAV_1_100"]].values][0]
gamma_uav_2_corr = [*gamma_corr_df[["Spearman_UAV_2_10","Spearman_UAV_2_20","Spearman_UAV_2_667","Spearman_UAV_2_100"]].values][0]
th_uav_2_corr = [*th_corr_df[["Spearman_UAV_2_10","Spearman_UAV_2_20","Spearman_UAV_2_667","Spearman_UAV_2_100"]].values][0]
gamma_uav_3_corr = [*gamma_corr_df[["Spearman_UAV_3_10","Spearman_UAV_3_20","Spearman_UAV_3_667","Spearman_UAV_3_100"]].values][0]
th_uav_3_corr = [*th_corr_df[["Spearman_UAV_3_10","Spearman_UAV_3_20","Spearman_UAV_3_667","Spearman_UAV_3_100"]].values][0]
gamma_uav_4_corr = [*gamma_corr_df[["Spearman_UAV_4_10","Spearman_UAV_4_20","Spearman_UAV_4_667","Spearman_UAV_4_100"]].values][0]
th_uav_4_corr = [*th_corr_df[["Spearman_UAV_4_10","Spearman_UAV_4_20","Spearman_UAV_4_667","Spearman_UAV_4_100"]].values][0]
gamma_uav_5_corr = [*gamma_corr_df[["Spearman_UAV_5_10","Spearman_UAV_5_20","Spearman_UAV_5_667","Spearman_UAV_5_100"]].values][0]
th_uav_5_corr = [*th_corr_df[["Spearman_UAV_5_10","Spearman_UAV_5_20","Spearman_UAV_5_667","Spearman_UAV_5_100"]].values][0]
gamma_uav_6_corr = [*gamma_corr_df[["Spearman_UAV_6_10","Spearman_UAV_6_20","Spearman_UAV_6_667","Spearman_UAV_6_100"]].values][0]
th_uav_6_corr = [*th_corr_df[["Spearman_UAV_6_10","Spearman_UAV_6_20","Spearman_UAV_6_667","Spearman_UAV_6_100"]].values][0]
gamma_uav_7_corr = [*gamma_corr_df[["Spearman_UAV_7_10","Spearman_UAV_7_20","Spearman_UAV_7_667","Spearman_UAV_7_100"]].values][0]
th_uav_7_corr = [*th_corr_df[["Spearman_UAV_7_10","Spearman_UAV_7_20","Spearman_UAV_7_667","Spearman_UAV_7_100"]].values][0]

gamma_list = [gamma_ul_corr, gamma_uav_0_corr, gamma_uav_1_corr, gamma_uav_2_corr, gamma_uav_3_corr, gamma_uav_4_corr, gamma_uav_5_corr, gamma_uav_6_corr, gamma_uav_7_corr]
th_list = [th_ul_corr, th_uav_0_corr, th_uav_1_corr, th_uav_2_corr, th_uav_3_corr, th_uav_4_corr, th_uav_5_corr, th_uav_6_corr, th_uav_7_corr]
gamma_legends = ['$\gamma$, DL', '$\gamma$, UL Gateway', '$\gamma$, UL UAV 1', '$\gamma$, UL UAV 2', '$\gamma$, UL UAV 3', '$\gamma$, UL UAV 4', '$\gamma$, UL UAV 5', '$\gamma$, UL UAV 6', '$\gamma$, UL UAV 7']
th_legends = ['$\\tau$, DL', '$\\tau$, UL Gateway', '$\\tau$, UL UAV 1', '$\\tau$, UL UAV 2', '$\\tau$, UL UAV 3', '$\\tau$, UL UAV 4', '$\\tau$, UL UAV 5', '$\\tau$, UL UAV 6', '$\\tau$, UL UAV 7']
linestyles = ['dashed','dotted','dotted','dotted','dotted','dotted','dotted','dotted','dotted']
markers = ['o','1','2','3','4','+','x','|','_']
color_gamma = 'tab:orange'
color_th = 'tab:blue'

plt.figure(figsize=(8,3))
plt.rcParams.update({'font.size': 12})
for gamma_data, th_data, gamma_legend, th_legend, linestyle, marker in zip(gamma_list, th_list, gamma_legends, th_legends, linestyles, markers):
    plt.plot(['10', '20', '66.7', '100'], gamma_data, marker=marker, linestyle=linestyle, color=color_gamma, fillstyle='none', label=gamma_legend)
    plt.plot(['10', '20', '66.7', '100'], th_data, marker=marker, linestyle=linestyle, color=color_th, fillstyle='none', label=th_legend)

plt.xlabel("USI (ms)")
plt.ylabel("Spearman Rho")
plt.ylim(0,1.05)
# plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=6, fontsize=10)
# Out:
# (0.0, 1.05)

# %% [markdown]
# ## Plot Relation Between Youden J Statistics and Correlation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %% [markdown]
# ### Plot average Youden J (over all scenarios) vs USI

# %%
gamma_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/num_reliable_failure_detection_time_window_ul_dl_overall_results_500_runs.csv")
gamma_results = gamma_results.loc[gamma_results["Scenario"]!="manet_scenario_0_{}_processed.csv"]
gamma_results["Overall_USI_10_YoudenJ"] = gamma_results["Overall_USI_10_Sensitivity"] + gamma_results["Overall_USI_10_Specificity"] - 1
gamma_results.loc[gamma_results["Scenario"]=="uav_scenario_1_{}_processed.csv", "Overall_USI_10_YoudenJ"] = np.nan
gamma_results.loc[gamma_results["Scenario"]=="uav_scenario_2_{}_processed.csv", "Overall_USI_10_YoudenJ"] = np.nan
gamma_results["Overall_USI_20_YoudenJ"] = gamma_results["Overall_USI_20_Sensitivity"] + gamma_results["Overall_USI_20_Specificity"] - 1
gamma_results["Overall_USI_667_YoudenJ"] = gamma_results["Overall_USI_667_Sensitivity"] + gamma_results["Overall_USI_667_Specificity"] - 1
gamma_results["Overall_USI_100_YoudenJ"] = gamma_results["Overall_USI_100_Sensitivity"] + gamma_results["Overall_USI_100_Specificity"] - 1

throughput_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/throughput_failure_detection_time_window_ul_dl_overall_results_500_runs.csv")
throughput_results = throughput_results.loc[throughput_results["Scenario"]!="manet_scenario_0_{}_processed.csv"]
throughput_results["Overall_USI_10_YoudenJ"] = throughput_results["Overall_USI_10_Sensitivity"] + throughput_results["Overall_USI_10_Specificity"] - 1
throughput_results.loc[throughput_results["Scenario"]=="uav_scenario_1_{}_processed.csv", "Overall_USI_10_YoudenJ"] = np.nan
throughput_results.loc[throughput_results["Scenario"]=="uav_scenario_2_{}_processed.csv", "Overall_USI_10_YoudenJ"] = np.nan
throughput_results["Overall_USI_20_YoudenJ"] = throughput_results["Overall_USI_20_Sensitivity"] + throughput_results["Overall_USI_20_Specificity"] - 1
throughput_results["Overall_USI_667_YoudenJ"] = throughput_results["Overall_USI_667_Sensitivity"] + throughput_results["Overall_USI_667_Specificity"] - 1
throughput_results["Overall_USI_100_YoudenJ"] = throughput_results["Overall_USI_100_Sensitivity"] + throughput_results["Overall_USI_100_Specificity"] - 1

# Get average Youden J over different scenarios for different USI
avg_gamma_yj = np.array([gamma_results["Overall_USI_10_YoudenJ"].mean(), gamma_results["Overall_USI_20_YoudenJ"].mean(), gamma_results["Overall_USI_667_YoudenJ"].mean(), gamma_results["Overall_USI_100_YoudenJ"].mean()])
avg_th_yj = np.array([throughput_results["Overall_USI_10_YoudenJ"].mean(), throughput_results["Overall_USI_20_YoudenJ"].mean(), throughput_results["Overall_USI_667_YoudenJ"].mean(), throughput_results["Overall_USI_100_YoudenJ"].mean()])

plt.figure(figsize=(10,4))
plt.rcParams.update({'font.size': 14})
plt.plot(['10', '20', '66.7', '100'], avg_gamma_yj, '-o', color='tab:orange')
plt.plot(['10', '20', '66.7', '100'], avg_th_yj, '-o', color='tab:blue')
plt.xlabel("USI (ms)")
plt.ylabel("Average Youden J Stats")
plt.ylim(0,1)
plt.legend(['$\gamma$','$\\tau$'], loc='lower left')

# %% [markdown]
# ### Plot Youden J vs USI for Individual Scenarios

# %%
scenario = "manet_scenario_2_{}_processed.csv"
# gamma_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/num_reliable_failure_detection_time_window_ul_dl_overall_results_500_runs.csv")
gamma_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/num_reliable_failure_detection_overall_results_500_runs_manet0.csv")
gamma_results = gamma_results.loc[gamma_results["Scenario"] == scenario]
if scenario == "uav_scenario_1_{}_processed.csv" or scenario == "uav_scenario_2_{}_processed.csv":
    gamma_results["Overall_USI_10_YoudenJ"] = np.nan
else:
    gamma_results["Overall_USI_10_YoudenJ"] = gamma_results["Overall_USI_10_Sensitivity"] + gamma_results["Overall_USI_10_Specificity"] - 1
gamma_results["Overall_USI_20_YoudenJ"] = gamma_results["Overall_USI_20_Sensitivity"] + gamma_results["Overall_USI_20_Specificity"] - 1
gamma_results["Overall_USI_667_YoudenJ"] = gamma_results["Overall_USI_667_Sensitivity"] + gamma_results["Overall_USI_667_Specificity"] - 1
gamma_results["Overall_USI_100_YoudenJ"] = gamma_results["Overall_USI_100_Sensitivity"] + gamma_results["Overall_USI_100_Specificity"] - 1

# throughput_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/throughput_failure_detection_time_window_ul_dl_overall_results_500_runs.csv")
throughput_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/throughput_failure_detection_overall_results_500_runs_manet0.csv")
throughput_results = throughput_results.loc[throughput_results["Scenario"]== scenario]
if scenario == "uav_scenario_1_{}_processed.csv" or scenario == "uav_scenario_2_{}_processed.csv":
    throughput_results["Overall_USI_10_YoudenJ"] = np.nan
else:
    throughput_results["Overall_USI_10_YoudenJ"] = throughput_results["Overall_USI_10_Sensitivity"] + throughput_results["Overall_USI_10_Specificity"] - 1
throughput_results["Overall_USI_20_YoudenJ"] = throughput_results["Overall_USI_20_Sensitivity"] + throughput_results["Overall_USI_20_Specificity"] - 1
throughput_results["Overall_USI_667_YoudenJ"] = throughput_results["Overall_USI_667_Sensitivity"] + throughput_results["Overall_USI_667_Specificity"] - 1
throughput_results["Overall_USI_100_YoudenJ"] = throughput_results["Overall_USI_100_Sensitivity"] + throughput_results["Overall_USI_100_Specificity"] - 1

# Get average Youden J over different scenarios for different USI
gamma_yj = np.array([gamma_results["Overall_USI_10_YoudenJ"].values[0], gamma_results["Overall_USI_20_YoudenJ"].values[0], gamma_results["Overall_USI_667_YoudenJ"].values[0], gamma_results["Overall_USI_100_YoudenJ"].values[0]])
th_yj = np.array([throughput_results["Overall_USI_10_YoudenJ"].values[0], throughput_results["Overall_USI_20_YoudenJ"].values[0], throughput_results["Overall_USI_667_YoudenJ"].values[0], throughput_results["Overall_USI_100_YoudenJ"].values[0]])

plt.figure(figsize=(8,3))
plt.rcParams.update({'font.size': 12})
plt.plot(['10', '20', '66.7', '100'], gamma_yj, '-o', color='tab:orange')
plt.plot(['10', '20', '66.7', '100'], th_yj, '-o', color='tab:blue')
plt.xlabel("USI (ms)")
plt.ylabel("Youden J")
plt.ylim(0,1)
# plt.legend(['$\gamma$','$\\tau$'], loc='lower left')
plt.legend(['$\gamma$','$\\tau$'], bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=2, fontsize=10)

# %% [markdown]
# ### Plot Average Correlation (over all links) vs USI

# %%
scenario = "uav_scenario_2_{}_processed.csv"
gamma_corr = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Num_Reliability_Spearman_500_runs.csv")
gamma_corr = gamma_corr.loc[gamma_corr["Scenario"] == scenario]
gamma_corr["Average_Spearman_USI_10"] = np.min([gamma_corr["Spearman_UL_10"].values[0], gamma_corr["Spearman_UAV_0_10"].values[0], gamma_corr["Spearman_UAV_1_10"].values[0],
                                                gamma_corr["Spearman_UAV_2_10"].values[0], gamma_corr["Spearman_UAV_3_10"].values[0], gamma_corr["Spearman_UAV_4_10"].values[0],
                                                gamma_corr["Spearman_UAV_5_10"].values[0], gamma_corr["Spearman_UAV_6_10"].values[0], gamma_corr["Spearman_UAV_7_10"].values[0]])
gamma_corr["Average_Spearman_USI_20"] = np.min([gamma_corr["Spearman_UL_20"].values[0], gamma_corr["Spearman_UAV_0_20"].values[0], gamma_corr["Spearman_UAV_1_20"].values[0],
                                                gamma_corr["Spearman_UAV_2_20"].values[0], gamma_corr["Spearman_UAV_3_20"].values[0], gamma_corr["Spearman_UAV_4_20"].values[0],
                                                gamma_corr["Spearman_UAV_5_20"].values[0], gamma_corr["Spearman_UAV_6_20"].values[0], gamma_corr["Spearman_UAV_7_20"].values[0]])
gamma_corr["Average_Spearman_USI_667"] = np.min([gamma_corr["Spearman_UL_667"].values[0], gamma_corr["Spearman_UAV_0_667"].values[0], gamma_corr["Spearman_UAV_1_667"].values[0],
                                                gamma_corr["Spearman_UAV_2_667"].values[0], gamma_corr["Spearman_UAV_3_667"].values[0], gamma_corr["Spearman_UAV_4_667"].values[0],
                                                gamma_corr["Spearman_UAV_5_667"].values[0], gamma_corr["Spearman_UAV_6_667"].values[0], gamma_corr["Spearman_UAV_7_667"].values[0]])
gamma_corr["Average_Spearman_USI_100"] = np.min([gamma_corr["Spearman_UL_100"].values[0], gamma_corr["Spearman_UAV_0_100"].values[0], gamma_corr["Spearman_UAV_1_100"].values[0],
                                                gamma_corr["Spearman_UAV_2_100"].values[0], gamma_corr["Spearman_UAV_3_100"].values[0], gamma_corr["Spearman_UAV_4_100"].values[0],
                                                gamma_corr["Spearman_UAV_5_100"].values[0], gamma_corr["Spearman_UAV_6_100"].values[0], gamma_corr["Spearman_UAV_7_100"].values[0]])

throughput_corr = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Throughput_Spearman_500_runs.csv")
throughput_corr = throughput_corr.loc[throughput_corr["Scenario"]== scenario]
throughput_corr["Average_Spearman_USI_10"] = np.min([throughput_corr["Spearman_UL_10"].values[0], throughput_corr["Spearman_UAV_0_10"].values[0], throughput_corr["Spearman_UAV_1_10"].values[0],
                                                throughput_corr["Spearman_UAV_2_10"].values[0], throughput_corr["Spearman_UAV_3_10"].values[0], throughput_corr["Spearman_UAV_4_10"].values[0],
                                                throughput_corr["Spearman_UAV_5_10"].values[0], throughput_corr["Spearman_UAV_6_10"].values[0], throughput_corr["Spearman_UAV_7_10"].values[0]])
throughput_corr["Average_Spearman_USI_20"] = np.min([throughput_corr["Spearman_UL_20"].values[0], throughput_corr["Spearman_UAV_0_20"].values[0], throughput_corr["Spearman_UAV_1_20"].values[0],
                                                throughput_corr["Spearman_UAV_2_20"].values[0], throughput_corr["Spearman_UAV_3_20"].values[0], throughput_corr["Spearman_UAV_4_20"].values[0],
                                                throughput_corr["Spearman_UAV_5_20"].values[0], throughput_corr["Spearman_UAV_6_20"].values[0], throughput_corr["Spearman_UAV_7_20"].values[0]])
throughput_corr["Average_Spearman_USI_667"] = np.min([throughput_corr["Spearman_UL_667"].values[0], throughput_corr["Spearman_UAV_0_667"].values[0], throughput_corr["Spearman_UAV_1_667"].values[0],
                                                throughput_corr["Spearman_UAV_2_667"].values[0], throughput_corr["Spearman_UAV_3_667"].values[0], throughput_corr["Spearman_UAV_4_667"].values[0],
                                                throughput_corr["Spearman_UAV_5_667"].values[0], throughput_corr["Spearman_UAV_6_667"].values[0], throughput_corr["Spearman_UAV_7_667"].values[0]])
throughput_corr["Average_Spearman_USI_100"] = np.min([throughput_corr["Spearman_UL_100"].values[0], throughput_corr["Spearman_UAV_0_100"].values[0], throughput_corr["Spearman_UAV_1_100"].values[0],
                                                throughput_corr["Spearman_UAV_2_100"].values[0], throughput_corr["Spearman_UAV_3_100"].values[0], throughput_corr["Spearman_UAV_4_100"].values[0],
                                                throughput_corr["Spearman_UAV_5_100"].values[0], throughput_corr["Spearman_UAV_6_100"].values[0], throughput_corr["Spearman_UAV_7_100"].values[0]])

# Get average Youden J over different scenarios for different USI
gamma_avg_corr = np.array([gamma_corr["Average_Spearman_USI_10"].values[0], gamma_corr["Average_Spearman_USI_20"].values[0], gamma_corr["Average_Spearman_USI_667"].values[0], gamma_corr["Average_Spearman_USI_100"].values[0]])
th_avg_corr = np.array([throughput_corr["Average_Spearman_USI_10"].values[0], throughput_corr["Average_Spearman_USI_20"].values[0], throughput_corr["Average_Spearman_USI_667"].values[0], throughput_corr["Average_Spearman_USI_100"].values[0]])

plt.figure(figsize=(8,3))
plt.rcParams.update({'font.size': 12})
plt.plot(['10', '20', '66.7', '100'], gamma_avg_corr, '-o', color='tab:orange')
plt.plot(['10', '20', '66.7', '100'], th_avg_corr, '-o', color='tab:blue')
# plt.plot(['20', '66.7', '100'], gamma_avg_corr[1:], '-o', color='tab:orange')
# plt.plot(['20', '66.7', '100'], th_avg_corr[1:], '-o', color='tab:blue')
plt.xlabel("USI (ms)")
plt.ylabel("Minimum Spearman $\\rho$")
plt.ylim(0,1)
# plt.ylim(0.9,1)
# plt.legend(['$\gamma$','$\\tau$'], loc='lower left')
# plt.legend(['$\gamma$','$\\tau$'], bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=2, fontsize=10)
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Plot Correlation of Youden J and Spearman

# %%
# gamma_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/num_reliable_failure_detection_time_window_ul_dl_overall_results_500_runs.csv")
# throughput_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/throughput_failure_detection_time_window_ul_dl_overall_results_500_runs.csv")
gamma_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/num_reliable_failure_detection_youden_overall_results_500_runs.csv")
throughput_results = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/throughput_failure_detection_youden_overall_results_500_runs.csv")
gamma_corr = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Num_Reliability_Spearman_500_runs.csv")
throughput_corr = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Throughput_Spearman_500_runs.csv")

scenario_list = ["uav_scenario_0_{}_processed.csv", "uav_scenario_1_{}_processed.csv", "uav_scenario_2_{}_processed.csv",
                 "manet_scenario_1_{}_processed.csv", "manet_scenario_a_{}_processed.csv", "manet_scenario_2_{}_processed.csv"]

gamma_yj = np.array([])
th_yj = np.array([])
gamma_avg_corr = np.array([])
th_avg_corr = np.array([])

for scenario in scenario_list:
    
    gamma_results_tmp = gamma_results.loc[gamma_results["Scenario"] == scenario]
    if scenario == "uav_scenario_1_{}_processed.csv" or scenario == "uav_scenario_2_{}_processed.csv":
        gamma_results_tmp["Overall_USI_10_YoudenJ"] = np.nan
    else:
        gamma_results_tmp["Overall_USI_10_YoudenJ"] = gamma_results_tmp["Overall_USI_10_Sensitivity"] + gamma_results_tmp["Overall_USI_10_Specificity"] - 1
    gamma_results_tmp["Overall_USI_20_YoudenJ"] = gamma_results_tmp["Overall_USI_20_Sensitivity"] + gamma_results_tmp["Overall_USI_20_Specificity"] - 1
    gamma_results_tmp["Overall_USI_667_YoudenJ"] = gamma_results_tmp["Overall_USI_667_Sensitivity"] + gamma_results_tmp["Overall_USI_667_Specificity"] - 1
    gamma_results_tmp["Overall_USI_100_YoudenJ"] = gamma_results_tmp["Overall_USI_100_Sensitivity"] + gamma_results_tmp["Overall_USI_100_Specificity"] - 1

    throughput_results_tmp = throughput_results.loc[throughput_results["Scenario"]== scenario]
    if scenario == "uav_scenario_1_{}_processed.csv" or scenario == "uav_scenario_2_{}_processed.csv":
        throughput_results_tmp["Overall_USI_10_YoudenJ"] = np.nan
    else:
        throughput_results_tmp["Overall_USI_10_YoudenJ"] = throughput_results_tmp["Overall_USI_10_Sensitivity"] + throughput_results_tmp["Overall_USI_10_Specificity"] - 1
    throughput_results_tmp["Overall_USI_20_YoudenJ"] = throughput_results_tmp["Overall_USI_20_Sensitivity"] + throughput_results_tmp["Overall_USI_20_Specificity"] - 1
    throughput_results_tmp["Overall_USI_667_YoudenJ"] = throughput_results_tmp["Overall_USI_667_Sensitivity"] + throughput_results_tmp["Overall_USI_667_Specificity"] - 1
    throughput_results_tmp["Overall_USI_100_YoudenJ"] = throughput_results_tmp["Overall_USI_100_Sensitivity"] + throughput_results_tmp["Overall_USI_100_Specificity"] - 1

    # Get Youden J over different scenarios for different USI
    gamma_yj = np.append(gamma_yj, [gamma_results_tmp["Overall_USI_10_YoudenJ"].values[0], gamma_results_tmp["Overall_USI_20_YoudenJ"].values[0], gamma_results_tmp["Overall_USI_667_YoudenJ"].values[0], gamma_results_tmp["Overall_USI_100_YoudenJ"].values[0]])
    th_yj = np.append(th_yj, [throughput_results_tmp["Overall_USI_10_YoudenJ"].values[0], throughput_results_tmp["Overall_USI_20_YoudenJ"].values[0], throughput_results_tmp["Overall_USI_667_YoudenJ"].values[0], throughput_results_tmp["Overall_USI_100_YoudenJ"].values[0]])

    gamma_corr_tmp = gamma_corr.loc[gamma_corr["Scenario"] == scenario]
    gamma_corr_tmp["Average_Spearman_USI_10"] = np.mean([gamma_corr_tmp["Spearman_UL_10"].values[0], gamma_corr_tmp["Spearman_UAV_0_10"].values[0], gamma_corr_tmp["Spearman_UAV_1_10"].values[0],
                                                    gamma_corr_tmp["Spearman_UAV_2_10"].values[0], gamma_corr_tmp["Spearman_UAV_3_10"].values[0], gamma_corr_tmp["Spearman_UAV_4_10"].values[0],
                                                    gamma_corr_tmp["Spearman_UAV_5_10"].values[0], gamma_corr_tmp["Spearman_UAV_6_10"].values[0], gamma_corr_tmp["Spearman_UAV_7_10"].values[0]])
    gamma_corr_tmp["Average_Spearman_USI_20"] = np.mean([gamma_corr_tmp["Spearman_UL_20"].values[0], gamma_corr_tmp["Spearman_UAV_0_20"].values[0], gamma_corr_tmp["Spearman_UAV_1_20"].values[0],
                                                    gamma_corr_tmp["Spearman_UAV_2_20"].values[0], gamma_corr_tmp["Spearman_UAV_3_20"].values[0], gamma_corr_tmp["Spearman_UAV_4_20"].values[0],
                                                    gamma_corr_tmp["Spearman_UAV_5_20"].values[0], gamma_corr_tmp["Spearman_UAV_6_20"].values[0], gamma_corr_tmp["Spearman_UAV_7_20"].values[0]])
    gamma_corr_tmp["Average_Spearman_USI_667"] = np.mean([gamma_corr_tmp["Spearman_UL_667"].values[0], gamma_corr_tmp["Spearman_UAV_0_667"].values[0], gamma_corr_tmp["Spearman_UAV_1_667"].values[0],
                                                    gamma_corr_tmp["Spearman_UAV_2_667"].values[0], gamma_corr_tmp["Spearman_UAV_3_667"].values[0], gamma_corr_tmp["Spearman_UAV_4_667"].values[0],
                                                    gamma_corr_tmp["Spearman_UAV_5_667"].values[0], gamma_corr_tmp["Spearman_UAV_6_667"].values[0], gamma_corr_tmp["Spearman_UAV_7_667"].values[0]])
    gamma_corr_tmp["Average_Spearman_USI_100"] = np.mean([gamma_corr_tmp["Spearman_UL_100"].values[0], gamma_corr_tmp["Spearman_UAV_0_100"].values[0], gamma_corr_tmp["Spearman_UAV_1_100"].values[0],
                                                    gamma_corr_tmp["Spearman_UAV_2_100"].values[0], gamma_corr_tmp["Spearman_UAV_3_100"].values[0], gamma_corr_tmp["Spearman_UAV_4_100"].values[0],
                                                    gamma_corr_tmp["Spearman_UAV_5_100"].values[0], gamma_corr_tmp["Spearman_UAV_6_100"].values[0], gamma_corr_tmp["Spearman_UAV_7_100"].values[0]])

    throughput_corr_tmp = throughput_corr.loc[throughput_corr["Scenario"]== scenario]
    throughput_corr_tmp["Average_Spearman_USI_10"] = np.mean([throughput_corr_tmp["Spearman_UL_10"].values[0], throughput_corr_tmp["Spearman_UAV_0_10"].values[0], throughput_corr_tmp["Spearman_UAV_1_10"].values[0],
                                                    throughput_corr_tmp["Spearman_UAV_2_10"].values[0], throughput_corr_tmp["Spearman_UAV_3_10"].values[0], throughput_corr_tmp["Spearman_UAV_4_10"].values[0],
                                                    throughput_corr_tmp["Spearman_UAV_5_10"].values[0], throughput_corr_tmp["Spearman_UAV_6_10"].values[0], throughput_corr_tmp["Spearman_UAV_7_10"].values[0]])
    throughput_corr_tmp["Average_Spearman_USI_20"] = np.mean([throughput_corr_tmp["Spearman_UL_20"].values[0], throughput_corr_tmp["Spearman_UAV_0_20"].values[0], throughput_corr_tmp["Spearman_UAV_1_20"].values[0],
                                                    throughput_corr_tmp["Spearman_UAV_2_20"].values[0], throughput_corr_tmp["Spearman_UAV_3_20"].values[0], throughput_corr_tmp["Spearman_UAV_4_20"].values[0],
                                                    throughput_corr_tmp["Spearman_UAV_5_20"].values[0], throughput_corr_tmp["Spearman_UAV_6_20"].values[0], throughput_corr_tmp["Spearman_UAV_7_20"].values[0]])
    throughput_corr_tmp["Average_Spearman_USI_667"] = np.mean([throughput_corr_tmp["Spearman_UL_667"].values[0], throughput_corr_tmp["Spearman_UAV_0_667"].values[0], throughput_corr_tmp["Spearman_UAV_1_667"].values[0],
                                                    throughput_corr_tmp["Spearman_UAV_2_667"].values[0], throughput_corr_tmp["Spearman_UAV_3_667"].values[0], throughput_corr_tmp["Spearman_UAV_4_667"].values[0],
                                                    throughput_corr_tmp["Spearman_UAV_5_667"].values[0], throughput_corr_tmp["Spearman_UAV_6_667"].values[0], throughput_corr_tmp["Spearman_UAV_7_667"].values[0]])
    throughput_corr_tmp["Average_Spearman_USI_100"] = np.mean([throughput_corr_tmp["Spearman_UL_100"].values[0], throughput_corr_tmp["Spearman_UAV_0_100"].values[0], throughput_corr_tmp["Spearman_UAV_1_100"].values[0],
                                                    throughput_corr_tmp["Spearman_UAV_2_100"].values[0], throughput_corr_tmp["Spearman_UAV_3_100"].values[0], throughput_corr_tmp["Spearman_UAV_4_100"].values[0],
                                                    throughput_corr_tmp["Spearman_UAV_5_100"].values[0], throughput_corr_tmp["Spearman_UAV_6_100"].values[0], throughput_corr_tmp["Spearman_UAV_7_100"].values[0]])

    # Get mean / min Spearman rho over different scenarios for different USI
    gamma_avg_corr = np.append(gamma_avg_corr, [gamma_corr_tmp["Average_Spearman_USI_10"].values[0], gamma_corr_tmp["Average_Spearman_USI_20"].values[0], gamma_corr_tmp["Average_Spearman_USI_667"].values[0], gamma_corr_tmp["Average_Spearman_USI_100"].values[0]])
    th_avg_corr = np.append(th_avg_corr, [throughput_corr_tmp["Average_Spearman_USI_10"].values[0], throughput_corr_tmp["Average_Spearman_USI_20"].values[0], throughput_corr_tmp["Average_Spearman_USI_667"].values[0], throughput_corr_tmp["Average_Spearman_USI_100"].values[0]])

plt.figure(figsize=(10,4))
plt.rcParams.update({'font.size': 12})
plt.scatter(gamma_avg_corr, gamma_yj, color='tab:orange')
plt.scatter(th_avg_corr, th_yj, color='tab:blue')
plt.xlabel("Average Spearman $\\rho$")
plt.ylabel("Youden J")
plt.ylim(0,1)
# plt.xlim(0,1)
plt.legend(['$\gamma$','$\\tau$'], bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=2, fontsize=10)

gamma_yj = np.delete(gamma_yj, [2,3])
gamma_avg_corr = np.delete(gamma_avg_corr, [2,3])

gamma_yj_ = gamma_yj[~(np.isnan(gamma_yj))] # Remove data where gamma_yi is NaN
th_yj_ = th_yj[~(np.isnan(th_yj))] # Remove data where gamma_yi is NaN
gamma_avg_corr_ = gamma_avg_corr[~(np.isnan(gamma_yj))] # Remove data where gamma_yi is NaN
th_avg_corr_ = th_avg_corr[~(np.isnan(th_yj))] # Remove data where gamma_yi is NaN
spearman_gamma = stats.spearmanr(gamma_avg_corr_, gamma_yj_)
spearman_throughput = stats.spearmanr(th_avg_corr_, th_yj_)
print("Spearman Rho - Gamma: {}, Throughput: {}".format(spearman_gamma, spearman_throughput))
# Out:
# Spearman Rho - Gamma: SpearmanrResult(correlation=0.6526315789473683, pvalue=0.0018136097760447342), Throughput: SpearmanrResult(correlation=0.9186900056465275, pvalue=1.624556477811128e-09)
# /tmp/ipykernel_805890/1041229408.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gamma_results_tmp["Overall_USI_10_YoudenJ"] = gamma_results_tmp["Overall_USI_10_Sensitivity"] + gamma_results_tmp["Overall_USI_10_Specificity"] - 1
# /tmp/ipykernel_805890/1041229408.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## Plot Relation Between ROC AUC and Spearman Correlation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %% [markdown]
# ### Plot Youden Index vs Spearman for UL

# %%
scenario = "uav_scenario_0_{}_processed.csv"
roc_auc_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/roc_auc_analysis.csv")
gamma_corr = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Num_Reliability_Spearman_500_runs.csv")
throughput_corr = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Throughput_Spearman_500_runs.csv")

gamma_auc = roc_auc_df.loc[(roc_auc_df["Scenario"]==scenario) & (roc_auc_df["Metric"]=="Gamma_Youden_Index")]
gamma_auc.sort_values(by=["USI"])

throughput_auc = roc_auc_df.loc[(roc_auc_df["Scenario"]==scenario) & (roc_auc_df["Metric"]=="Throughput_Youden_Index")]
throughput_auc.sort_values(by=["USI"])

gamma_corr_tmp = gamma_corr.loc[gamma_corr["Scenario"] == scenario]
throughput_corr_tmp = throughput_corr.loc[throughput_corr["Scenario"]== scenario]

gamma_corr_ul = [gamma_corr_tmp["Spearman_UL_10"].values[0], gamma_corr_tmp["Spearman_UL_20"].values[0], gamma_corr_tmp["Spearman_UL_667"].values[0], gamma_corr_tmp["Spearman_UL_100"].values[0]]
throughput_corr_ul = [throughput_corr_tmp["Spearman_UL_10"].values[0], throughput_corr_tmp["Spearman_UL_20"].values[0], throughput_corr_tmp["Spearman_UL_667"].values[0], throughput_corr_tmp["Spearman_UL_100"].values[0]]

# Plot ROC AUC of UL for different USI for this scenario
plt.figure(figsize=(8,3))
plt.rcParams.update({'font.size': 14})
plt.plot(['10', '20', '66.7', '100'], gamma_auc["UL"].values, '-o', color='tab:orange')
plt.plot(['10', '20', '66.7', '100'], throughput_auc["UL"].values, '-o', color='tab:blue')
plt.xlabel("USI (ms)")
plt.ylabel("Max Youden J")
plt.ylim(0,1.05)
plt.legend(['$\gamma$','$\\tau$'], bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=2, fontsize=10)

# Plot Spearman Rho of UL for different USI for this scenario
plt.figure(figsize=(8,3))
plt.rcParams.update({'font.size': 14})
plt.plot(['10', '20', '66.7', '100'], gamma_corr_ul, '-o', color='tab:orange')
plt.plot(['10', '20', '66.7', '100'], throughput_corr_ul, '-o', color='tab:blue')
# plt.plot(['20', '66.7', '100'], gamma_corr_ul[1:], '-o', color='tab:orange')
# plt.plot(['20', '66.7', '100'], throughput_corr_ul[1:], '-o', color='tab:blue')
plt.xlabel("USI (ms)")
plt.ylabel("Spearman $\\rho$")
plt.ylim(0,1.05)
plt.legend(['$\gamma$','$\\tau$'], bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=2, fontsize=10)
# Out:
# (0.0, 1.05)

# %% [markdown]
# ### Plot Scatter for ROC AUC vs Spearman for All Links

# %%
roc_auc_df = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/roc_auc_analysis.csv")
gamma_corr = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Num_Reliability_Spearman_500_runs.csv")
throughput_corr = pd.read_csv("/home/research-student/omnet-fanet/data-processing-scripts/journal_3_scripts/results/Throughput_Spearman_500_runs.csv")

scenario_list = ["uav_scenario_0_{}_processed.csv", "uav_scenario_1_{}_processed.csv", "uav_scenario_2_{}_processed.csv",
                 "manet_scenario_1_{}_processed.csv", "manet_scenario_a_{}_processed.csv", "manet_scenario_2_{}_processed.csv"]

gamma_yi = np.array([])
th_yi = np.array([])
gamma_corr_arr = np.array([])
th_corr_arr = np.array([])

for scenario in scenario_list:
    
    gamma_auc_tmp = roc_auc_df.loc[(roc_auc_df["Scenario"]==scenario) & (roc_auc_df["Metric"]=="Gamma_Youden_Index")]
    for usi in [10, 20, 66.7, 100]:
        tmp_df = gamma_auc_tmp.loc[gamma_auc_tmp["USI"]==usi]
        gamma_yi = np.append(gamma_yi, tmp_df[["UL", "UAV_0", "UAV_1", "UAV_2", "UAV_3", "UAV_4", "UAV_5", "UAV_6", "UAV_7"]].values[0])

    throughput_auc_tmp = roc_auc_df.loc[(roc_auc_df["Scenario"]==scenario) & (roc_auc_df["Metric"]=="Throughput_Youden_Index")]
    for usi in [10, 20, 66.7, 100]:
        tmp_df = throughput_auc_tmp.loc[throughput_auc_tmp["USI"]==usi]
        th_yi = np.append(th_yi, tmp_df[["UL", "UAV_0", "UAV_1", "UAV_2", "UAV_3", "UAV_4", "UAV_5", "UAV_6", "UAV_7"]].values[0])

    gamma_corr_tmp = gamma_corr.loc[gamma_corr["Scenario"] == scenario]
    throughput_corr_tmp = throughput_corr.loc[throughput_corr["Scenario"]== scenario]
    usi_dict = {10: "10", 20: "20", 66.7: "667", 100: "100"}
    for usi in [10, 20, 66.7, 100]:
        gamma_corr_arr = np.append(gamma_corr_arr, gamma_corr_tmp[["Spearman_UL_{}".format(usi_dict[usi]), "Spearman_UAV_0_{}".format(usi_dict[usi]), "Spearman_UAV_1_{}".format(usi_dict[usi]),
                                                              "Spearman_UAV_2_{}".format(usi_dict[usi]), "Spearman_UAV_3_{}".format(usi_dict[usi]), "Spearman_UAV_4_{}".format(usi_dict[usi]),
                                                              "Spearman_UAV_5_{}".format(usi_dict[usi]), "Spearman_UAV_6_{}".format(usi_dict[usi]), "Spearman_UAV_7_{}".format(usi_dict[usi])]])
        th_corr_arr = np.append(th_corr_arr, throughput_corr_tmp[["Spearman_UL_{}".format(usi_dict[usi]), "Spearman_UAV_0_{}".format(usi_dict[usi]), "Spearman_UAV_1_{}".format(usi_dict[usi]),
                                                              "Spearman_UAV_2_{}".format(usi_dict[usi]), "Spearman_UAV_3_{}".format(usi_dict[usi]), "Spearman_UAV_4_{}".format(usi_dict[usi]),
                                                              "Spearman_UAV_5_{}".format(usi_dict[usi]), "Spearman_UAV_6_{}".format(usi_dict[usi]), "Spearman_UAV_7_{}".format(usi_dict[usi])]])

plt.figure(figsize=(10,4))
plt.rcParams.update({'font.size': 12})
plt.scatter(gamma_corr_arr, gamma_yi, color='tab:orange', alpha=0.5)
plt.scatter(th_corr_arr, th_yi, color='tab:blue', alpha=0.5)
plt.xlabel("Spearman $\\rho$")
plt.ylabel("Max Youden J")
plt.ylim(0,1)
# plt.xlim(0,1)
plt.legend(['$\gamma$','$\\tau$'], bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower center", borderaxespad=0, ncol=2, fontsize=10)

# Calculate the monotonicity between Spearman and Max Youden Index
gamma_yi_ = gamma_yi[~(np.isnan(gamma_yi))] # Remove data where gamma_yi is NaN
th_yi_ = th_yi[~(np.isnan(th_yi))] # Remove data where gamma_yi is NaN
gamma_corr_arr_ = gamma_corr_arr[~(np.isnan(gamma_yi))] # Remove data where gamma_yi is NaN
th_corr_arr_ = th_corr_arr[~(np.isnan(th_yi))] # Remove data where gamma_yi is NaN
spearman_gamma = stats.spearmanr(gamma_corr_arr_, gamma_yi_)
spearman_throughput = stats.spearmanr(th_corr_arr_, th_yi_)
print("Spearman Rho - Gamma: {}, Throughput: {}".format(spearman_gamma, spearman_throughput))
# Out:
# Spearman Rho - Gamma: SpearmanrResult(correlation=0.4186775073391883, pvalue=1.718656763944955e-10), Throughput: SpearmanrResult(correlation=0.8103694542827492, pvalue=4.074986892657148e-51)
